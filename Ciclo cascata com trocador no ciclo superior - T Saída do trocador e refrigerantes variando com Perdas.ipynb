# %%
#Bibliotecas
from CoolProp.CoolProp import PropsSI as COOLPROP
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import get_test_data

#Listas
registro_fluidos = []
COP_lista = []
lista_T3 = []
Wcomp_total_lista = []
cont = []

#Lista de Temperaturas
for T3 in range (-3000 + 27315, 400 + 27315, 100):
    T3 = T3 / 100
    cont.append(T3)

#características para as curvas do gráfico
lista_cor = ['r','g','b', 'c', 'm']
lista_ls = ['-', '-.', ':']
caracteristicas = []
for ls in lista_ls:
    for cor in lista_cor:
        caracteristicas.append((cor, ls))

#Parâmetros
Pfrig = 120 * 1000 #[W]
T1 = -80 + 273.15 #[K]
T8 = 28 + 273.15 #[K]
N = 0.7 #Eficiência isentrópica
fluid_high_lista = ['R134a', 'R717', 'R290', 'R600', 'R404a']
fluid_low_lista = ['R23', 'R170', 'NitrousOxide']
drop_suc = 12000 #[Pa]
drop_desc = 24000 #[Pa]
efet = 0.7 #efetividade do trocador intermediário
DeltaT = 4 #[°C]

#Variação dos refrigerantes e do da Pressão de saída do compressor
for fluid_low in fluid_low_lista:
    #Ciclo do compressor de baixa pressão
    P1 = COOLPROP('P', 'T', T1, 'Q', 1, fluid_low) 
    h1 = COOLPROP('H', 'T', T1, 'Q', 1, fluid_low)
    ha = h1
    Pa = P1 - drop_suc
    Ta = COOLPROP('T', 'H', ha, 'P', Pa, fluid_low)
    Pb = Pa
    Tb = Ta + DeltaT
    hb = COOLPROP('H', 'T', Tb, 'P', Pb, fluid_low)
    Sb = COOLPROP('S', 'T', Tb, 'P', Pb, fluid_low)

    for fluid_high in fluid_high_lista:
        if fluid_low == 'NitrousOxide':
            par_fluido = ('Óxido nitroso', fluid_high)    
        else:
            par_fluido = (fluid_low, fluid_high)
        registro_fluidos.append(par_fluido)
         #Temperatura T3
        for T3 in cont:
            P3 = COOLPROP('P', 'T', T3, 'Q', 0 , fluid_low)
            P2 = P3
            h3 = COOLPROP('H', 'T', T3, 'Q', 0, fluid_low)
    
            Pc = P2 + drop_desc
            Sc_ideal = Sb     
            hc_ideal = COOLPROP('H', 'S', Sc_ideal , 'P', Pc, fluid_low)
            hc_real = (hc_ideal - hb)/N + hb
            h2 = hc_real
        
            h4 = h3
            m_flow_low = Pfrig / (h1 - h4)
        
            w_low = hc_real - hb
            Wcomp_low = m_flow_low * w_low

            #Pressão crítica do fluido do ciclo de alta pressão
            P_crit_high = COOLPROP('PCRIT', fluid_high)
            h8 = COOLPROP('H', 'T', T8, 'Q', 0, fluid_high)
            P8 = COOLPROP('P', 'T', T8, 'Q', 0, fluid_high)

            T10 = T3 - 5
            #Q<>0, mas como o refrigerante se encontra em uma fase saturada a pressão é a mesma para qualquer Q com T=T10
            P10 = COOLPROP('P', 'Q', 0, 'T', T10, fluid_high) 
            P5 = P10
            T5 = COOLPROP('T', 'P', P5, 'Q', 1, fluid_high)
            P8 = COOLPROP('P', 'T', T8, 'Q', 0, fluid_high)
            cp5 = COOLPROP('CP0MASS', 'T', T5, 'Q', 1, fluid_high)
            cp8 = COOLPROP('CP0MASS', 'T', T8, 'Q', 0, fluid_high)
            h5 = COOLPROP('H', 'T', T5, 'Q', 1, fluid_high)
            h8 = COOLPROP('H', 'T', T8, 'Q', 0, fluid_high)
            P6 = P5
            P9 = P8

        #Comparação entre os calores específicos nos pontos 8 e 5
            if cp5 < cp8:
                T6 = efet * (T8 - T5) + T5
                h6 = COOLPROP('H', 'T', T6, 'P', P6, fluid_high)
                hw = h6
                Pw = P6 - drop_suc
                Tw = COOLPROP('T', 'H', hw, 'P', Pw, fluid_high)
                Px = Pw
                Tx = Tw + DeltaT
                hx = COOLPROP('H', 'P', Px, 'T', Tx, fluid_high)
                sx = COOLPROP('S', 'P', Px, 'T', Tx, fluid_high)
            
                P7 = P8
                Py = P7 + drop_desc
                sy_ideal = sx
                hy_ideal = COOLPROP('H', 'P', Py, 'S', sy_ideal, fluid_high)
                hy_real = (hy_ideal - hx)/N + hx
                h7 = hy_real
            
                h9 = h8 + h5 - h6
                T9 = COOLPROP('T', 'H', h9, 'P', P9, fluid_high)
                h10 = h9
            else:
                T9 = T8 - efet * (T8 - T5)
                h9 = COOLPROP('H', 'T', T9, 'P', P9, fluid_high)
                h6 = h8 + h5 - h9
                T6 = COOLPROP('T', 'H', h6, 'P', P6, fluid_high)
                hw = h6
                Pw = P6 - drop_suc
                Tw = COOLPROP('T', 'H', hw, 'P', Pw, fluid_high)
                Px = Pw
                Tx = Tw + DeltaT
                hx = COOLPROP('H', 'P', Px, 'T', Tx, fluid_high)
                sx = COOLPROP('S', 'P', Px, 'T', Tx, fluid_high)
            
                P7 = P8
                Py = P7 + drop_desc
                sy_ideal = sx
                hy_ideal = COOLPROP('H', 'P', Py, 'S', sy_ideal, fluid_high)
                hy_real = (hy_ideal - hx)/N + hx
                h7 = hy_real
            
                h10 = h9
            
            #Registro dos graus de subresfriamento e superaquecimento
            grau_subresf = T8 - T9
            grau_superaq = T6 - T5
            #print('O grau de subresfriamento ({}, {}) é igual a {:0.2f}°C.'.format(fluid_low,fluid_high,grau_subresf))
            #print('O grau de superaquecimento ({}, {}) é igual a {:0.2f}°C.'.format(fluid_low,fluid_high,grau_superaq))

            #Calor trocado no trocador central
            Qcond_low =  m_flow_low * (h2 - h3)
            #Ciclo de alta pressão
            Qevap_high = Qcond_low
            m_flow_high = Qevap_high / (h5 - h10)
            #Verificação da pressão crítica
            if P_crit_high > P7:
                lista_T3.append(T3)
                #Trabalho específico do compressor do ciclo de alta pressão
                w_high = hy_real - hx
                #Trabalho no compressor do ciclo de alta pressão
                Wcomp_high = m_flow_high * w_high
                #Trabalho total do ciclo
                Wcomp_total = Wcomp_low + Wcomp_high
                Wcomp_total_lista.append(Wcomp_total / 1000)
                #COP
                COP = Pfrig / Wcomp_total
                COP_lista.append(COP)
                print("A", fluid_high)
                print("B", fluid_low)
                print("T3", T3)
                print("C", COP)
            else:
                print ('A pressão P7 = {:0.2f} kPa (T3 = {}, fluido inf = {}, fluido sup = {}) é maior do que a ' 
               'pressão crítica do {} logo o ponto não foi incluído no gráfico'.format(P7 / 1000,T3,fluid_low,
                                                                                               fluid_high, fluid_high))

if len(lista_T3) != 0:
    plt.rc('xtick', labelsize = 13)
    plt.rc('ytick', labelsize = 13)
    plt.figure(figsize = [13, 13], dpi = 300)
 
    for i in range (0, len(COP_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T3[j])
            eixo_y.append(COP_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1], 
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T3', size = 13)
        plt.ylabel('COP', size = 13)
    plt.legend(prop={'size' : 13})
    plt.show()
else:
    print('Todos os pontos são inválidos')
# Out:
# A R134a
# B R23
# T3 243.15
# C 0.7148343584401812
# A R134a
# B R23
# T3 244.15
# C 0.7157957933317941
# A R134a
# B R23
# T3 245.15
# C 0.7164786665138358
# A R134a
# B R23
# T3 246.15
# C 0.716889404486169
# A R134a
# B R23
# T3 247.15
# C 0.7170337208717649
# A R134a
# B R23
# T3 248.15
# C 0.7169166916175922
# A R134a
# B R23
# T3 249.15
# C 0.7165428197139858
# A R134a
# B R23
# T3 250.15
# C 0.7159160910166356
# A R134a
# B R23
# T3 251.15
# C 0.7150400224636726
# A R134a
# B R23
# T3 252.15
# C 0.7139177037312917
# A R134a
# B R23
# T3 253.15
# C 0.7125518331820699
# A R134a
# B R23
# T3 254.15
# C 0.7109447488071736
# A R134a
# B R23
# T3 255.15
# C 0.709098454725819
# A R134a
# B R23
# T3 256.15
# C 0.7070146437018167
# A R134a
# B R23
# T3 257.15
# C 0.7046947160436414
# A R134a
# B R23
# T3 258.15
# C 0.702139795180741
# A R134a
# B R23
# T3 259.15
# C 0.6993507400882822
# A R134a
# B R23
# T3 260.15
# C 0.69632815483693
# A R134a
# B R23
# T3 261.15
# C 0.6930723951824928
# A R134a
# B R23
# T3 262.15
# C 0.6895835723776355
# A R134a
# B R23
# T3 263.15
# C 0.685861554125172
# A R134a
# B R23
# T3 264.15
# C 0.6819059626016638
# A R134a
# B R23
# T3 265.15
# C 0.6777161694141457
# A R134a
# B R23
# T3 266.15
# C 0.6732912872742883
# A R134a
# B R23
# T3 267.15
# C 0.6686301581009582
# A R134a
# B R23
# T3 268.15
# C 0.6637313371648583
# A R134a
# B R23
# T3 269.15
# C 0.6585930727773494
# A R134a
# B R23
# T3 270.15
# C 0.6532132808824876
# A R134a
# B R23
# T3 271.15
# C 0.6475895137906587
# A R134a
# B R23
# T3 272.15
# C 0.6417189219164631
# A R134a
# B R23
# T3 273.15
# C 0.635598207406891
# A R134a
# B R23
# T3 274.15
# C 0.6292235678659159
# A R134a
# B R23
# T3 275.15
# C 0.6225906281300636
# A R134a
# B R23
# T3 276.15
# C 0.6156943574379543
# A R717
# B R23
# T3 243.15
# C 0.6851196425549902
# A R717
# B R23
# T3 244.15
# C 0.6872998642497411
# A R717
# B R23
# T3 245.15
# C 0.6892001355165057
# A R717
# B R23
# T3 246.15
# C 0.6908233789730459
# A R717
# B R23
# T3 247.15
# C 0.6921721394516516
# A R717
# B R23
# T3 248.15
# C 0.6932486232200945
# A R717
# B R23
# T3 249.15
# C 0.6940547321701344
# A R717
# B R23
# T3 250.15
# C 0.694592093600105
# A R717
# B R23
# T3 251.15
# C 0.6948620860955562
# A R717
# B R23
# T3 252.15
# C 0.6948658619513746
# A R717
# B R23
# T3 253.15
# C 0.6946043664666167
# A R717
# B R23
# T3 254.15
# C 0.6940783543931295
# A R717
# B R23
# T3 255.15
# C 0.6932884037789373
# A R717
# B R23
# T3 256.15
# C 0.6922349273575753
# A R717
# B R23
# T3 257.15
# C 0.6909181816348684
# A R717
# B R23
# T3 258.15
# C 0.6893382737572079
# A R717
# B R23
# T3 259.15
# C 0.6874951662081806
# A R717
# B R23
# T3 260.15
# C 0.6853886793489313
# A R717
# B R23
# T3 261.15
# C 0.6830184917870544
# A R717
# B R23
# T3 262.15
# C 0.6803841385002468
# A R717
# B R23
# T3 263.15
# C 0.6774850066189428
# A R717
# B R23
# T3 264.15
# C 0.6743203287078402
# A R717
# B R23
# T3 265.15
# C 0.670889173342479
# A R717
# B R23
# T3 266.15
# C 0.6671904327258373
# A R717
# B R23
# T3 267.15
# C 0.6632228069918928
# A R717
# B R23
# T3 268.15
# C 0.6589847847723687
# A R717
# B R23
# T3 269.15
# C 0.6544746195033033
# A R717
# B R23
# T3 270.15
# C 0.6496903007751521
# A R717
# B R23
# T3 271.15
# C 0.6446295199619139
# A R717
# B R23
# T3 272.15
# C 0.6392896289455822
# A R717
# B R23
# T3 273.15
# C 0.6336675908030475
# A R717
# B R23
# T3 274.15
# C 0.6277599206387801
# A R717
# B R23
# T3 275.15
# C 0.6215626145050085
# A R717
# B R23
# T3 276.15
# C 0.6150710636568619
# A R290
# B R23
# T3 243.15
# C 0.7331089300041012
# A R290
# B R23
# T3 244.15
# C 0.7328045408970583
# A R290
# B R23
# T3 245.15
# C 0.7323049152128343
# A R290
# B R23
# T3 246.15
# C 0.7316104479671597
# A R290
# B R23
# T3 247.15
# C 0.7307213872902432
# A R290
# B R23
# T3 248.15
# C 0.7296378427117772
# A R290
# B R23
# T3 249.15
# C 0.7283597923339357
# A R290
# B R23
# T3 250.15
# C 0.7268870889482442
# A R290
# B R23
# T3 251.15
# C 0.7252194651398548
# A R290
# B R23
# T3 252.15
# C 0.7233565374098727
# A R290
# B R23
# T3 253.15
# C 0.7212978093276812
# A R290
# B R23
# T3 254.15
# C 0.7190426737184058
# A R290
# B R23
# T3 255.15
# C 0.716590413873165
# A R290
# B R23
# T3 256.15
# C 0.713940203757062
# A R290
# B R23
# T3 257.15
# C 0.7110911071726709
# A R290
# B R23
# T3 258.15
# C 0.7080420758274135
# A R290
# B R23
# T3 259.15
# C 0.7047919462242418
# A R290
# B R23
# T3 260.15
# C 0.7013394352912002
# A R290
# B R23
# T3 261.15
# C 0.6976831346178488
# A R290
# B R23
# T3 262.15
# C 0.693821503171735
# A R290
# B R23
# T3 263.15
# C 0.6897528583046055
# A R290
# B R23
# T3 264.15
# C 0.6854753648445053
# A R290
# B R23
# T3 265.15
# C 0.6809870220099445
# A R290
# B R23
# T3 266.15
# C 0.6762856478365201
# A R290
# B R23
# T3 267.15
# C 0.6713688607311299
# A R290
# B R23
# T3 268.15
# C 0.6662340576961726
# A R290
# B R23
# T3 269.15
# C 0.6608783886526994
# A R290
# B R23
# T3 270.15
# C 0.6552987261627427
# A R290
# B R23
# T3 271.15
# C 0.6494916297363594
# A R290
# B R23
# T3 272.15
# C 0.6434533035362368
# A R290
# B R23
# T3 273.15
# C 0.6371795463218675
# A R290
# B R23
# T3 274.15
# C 0.6306656918036873
# A R290
# B R23
# T3 275.15
# C 0.6239065373346376
# A R290
# B R23
# T3 276.15
# C 0.6168962581771853
# A R600
# B R23
# T3 243.15
# C 0.6392434182179281
# A R600
# B R23
# T3 244.15
# C 0.6460759816381811
# A R600
# B R23
# T3 245.15
# C 0.6519944204807065
# A R600
# B R23
# T3 246.15
# C 0.6570966399870742
# A R600
# B R23
# T3 247.15
# C 0.6614621432753616
# A R600
# B R23
# T3 248.15
# C 0.6651564396687493
# A R600
# B R23
# T3 249.15
# C 0.6682341826111963
# A R600
# B R23
# T3 250.15
# C 0.6707414562569953
# A R600
# B R23
# T3 251.15
# C 0.6727174762739909
# A R600
# B R23
# T3 252.15
# C 0.6741958776654263
# A R600
# B R23
# T3 253.15
# C 0.6752057053009718
# A R600
# B R23
# T3 254.15
# C 0.6757721865757188
# A R600
# B R23
# T3 255.15
# C 0.6759173414085228
# A R600
# B R23
# T3 256.15
# C 0.6756604691622702
# A R600
# B R23
# T3 257.15
# C 0.6750185409670875
# A R600
# B R23
# T3 258.15
# C 0.6740065184008749
# A R600
# B R23
# T3 259.15
# C 0.672637614181552
# A R600
# B R23
# T3 260.15
# C 0.6709235065113959
# A R600
# B R23
# T3 261.15
# C 0.6688745160721115
# A R600
# B R23
# T3 262.15
# C 0.6664997524644133
# A R600
# B R23
# T3 263.15
# C 0.6638072353459442
# A R600
# B R23
# T3 264.15
# C 0.6608039943343544
# A R600
# B R23
# T3 265.15
# C 0.6574961508302213
# A R600
# B R23
# T3 266.15
# C 0.6538889841437582
# A R600
# B R23
# T3 267.15
# C 0.6499869837463604
# A R600
# B R23
# T3 268.15
# C 0.645793888954826
# A R600
# B R23
# T3 269.15
# C 0.6413127169513682
# A R600
# B R23
# T3 270.15
# C 0.6365457796349875
# A R600
# B R23
# T3 271.15
# C 0.6314946894696489
# A R600
# B R23
# T3 272.15
# C 0.6261603540669717
# A R600
# B R23
# T3 273.15
# C 0.6205429588676258
# A R600
# B R23
# T3 274.15
# C 0.6146419369310377
# A R600
# B R23
# T3 275.15
# C 0.608455924123491
# A R600
# B R23
# T3 276.15
# C 0.6019826974657267
# A R404a
# B R23
# T3 243.15
# C 0.7160218013668997
# A R404a
# B R23
# T3 244.15
# C 0.7160704313360733
# A R404a
# B R23
# T3 245.15
# C 0.7159312864292043
# A R404a
# B R23
# T3 246.15
# C 0.7156040463984998
# A R404a
# B R23
# T3 247.15
# C 0.7150882689736702
# A R404a
# B R23
# T3 248.15
# C 0.7143833965552698
# A R404a
# B R23
# T3 249.15
# C 0.7134887619581288
# A R404a
# B R23
# T3 250.15
# C 0.7124035932481609
# A R404a
# B R23
# T3 251.15
# C 0.7111270176937867
# A R404a
# B R23
# T3 252.15
# C 0.709658064851031
# A R404a
# B R23
# T3 253.15
# C 0.7079956687831863
# A R404a
# B R23
# T3 254.15
# C 0.7061386694075048
# A R404a
# B R23
# T3 255.15
# C 0.7040858129465642
# A R404a
# B R23
# T3 256.15
# C 0.7018357514513379
# A R404a
# B R23
# T3 257.15
# C 0.6993870413478597
# A R404a
# B R23
# T3 258.15
# C 0.6967381409440557
# A R404a
# B R23
# T3 259.15
# C 0.6938874068173138
# A R404a
# B R23
# T3 260.15
# C 0.6908330889820086
# A R404a
# B R23
# T3 261.15
# C 0.6875733247155881
# A R404a
# B R23
# T3 262.15
# C 0.6841061308937058
# A R404a
# B R23
# T3 263.15
# C 0.6804293946550991
# A R404a
# B R23
# T3 264.15
# C 0.6765408621782749
# A R404a
# B R23
# T3 265.15
# C 0.6724381253047893
# A R404a
# B R23
# T3 266.15
# C 0.6681186057118681
# A R404a
# B R23
# T3 267.15
# C 0.6635795362015874
# A R404a
# B R23
# T3 268.15
# C 0.6588179387037
# A R404a
# B R23
# T3 269.15
# C 0.6538305983753882
# A R404a
# B R23
# T3 270.15
# C 0.6486140331112807
# A R404a
# B R23
# T3 271.15
# C 0.6431644576401379
# A R404a
# B R23
# T3 272.15
# C 0.6374777410212334
# A R404a
# B R23
# T3 273.15
# C 0.6315493563740353
# A R404a
# B R23
# T3 274.15
# C 0.6253743210072988
# A R404a
# B R23
# T3 275.15
# C 0.6189471248683072
# A R404a
# B R23
# T3 276.15
# C 0.6122616445470599
# A R134a
# B R170
# T3 243.15
# C 0.7268179284147075
# A R134a
# B R170
# T3 244.15
# C 0.7280566593839788
# A R134a
# B R170
# T3 245.15
# C 0.7290139641169714
# A R134a
# B R170
# T3 246.15
# C 0.7296960871707149
# A R134a
# B R170
# T3 247.15
# C 0.7301085716273228
# A R134a
# B R170
# T3 248.15
# C 0.7302563359817781
# A R134a
# B R170
# T3 249.15
# C 0.7301437405637301
# A R134a
# B R170
# T3 250.15
# C 0.7297746451101809
# A R134a
# B R170
# T3 251.15
# C 0.7291524588117675
# A R134a
# B R170
# T3 252.15
# C 0.7282801839076869
# A R134a
# B R170
# T3 253.15
# C 0.7271604537150615
# A R134a
# B R170
# T3 254.15
# C 0.7257955658259887
# A R134a
# B R170
# T3 255.15
# C 0.7241875110630864
# A R134a
# B R170
# T3 256.15
# C 0.7223379987479486
# A R134a
# B R170
# T3 257.15
# C 0.7202484785277037
# A R134a
# B R170
# T3 258.15
# C 0.7179201593444781
# A R134a
# B R170
# T3 259.15
# C 0.7153540255593842
# A R134a
# B R170
# T3 260.15
# C 0.7125508506723652
# A R134a
# B R170
# T3 261.15
# C 0.7095112086005377
# A R134a
# B R170
# T3 262.15
# C 0.7062354827944847
# A R134a
# B R170
# T3 263.15
# C 0.7027238732038721
# A R134a
# B R170
# T3 264.15
# C 0.6989764011897392
# A R134a
# B R170
# T3 265.15
# C 0.6949929123978629
# A R134a
# B R170
# T3 266.15
# C 0.6907730774891888
# A R134a
# B R170
# T3 267.15
# C 0.6863163909487563
# A R134a
# B R170
# T3 268.15
# C 0.6816221675994734
# A R134a
# B R170
# T3 269.15
# C 0.6766895369187537
# A R134a
# B R170
# T3 270.15
# C 0.6715174349348125
# A R134a
# B R170
# T3 271.15
# C 0.6661045935098332
# A R134a
# B R170
# T3 272.15
# C 0.6604495267354492
# A R134a
# B R170
# T3 273.15
# C 0.6545505140856456
# A R134a
# B R170
# T3 274.15
# C 0.6484055798599991
# A R134a
# B R170
# T3 275.15
# C 0.6420124683117752
# A R134a
# B R170
# T3 276.15
# C 0.6353686137705542
# A R717
# B R170
# T3 243.15
# C 0.6963856702271974
# A R717
# B R170
# T3 244.15
# C 0.6988571638601087
# A R717
# B R170
# T3 245.15
# C 0.7010470810787024
# A R717
# B R170
# T3 246.15
# C 0.7029580784621895
# A R717
# B R170
# T3 247.15
# C 0.7045924461623501
# A R717
# B R170
# T3 248.15
# C 0.7059521488310402
# A R717
# B R170
# T3 249.15
# C 0.7070388615828765
# A R717
# B R170
# T3 250.15
# C 0.7078540016419131
# A R717
# B R170
# T3 251.15
# C 0.7083987561975671
# A R717
# B R170
# T3 252.15
# C 0.7086741069384684
# A R717
# B R170
# T3 253.15
# C 0.7086808516209827
# A R717
# B R170
# T3 254.15
# C 0.7084196229807025
# A R717
# B R170
# T3 255.15
# C 0.7078909052522351
# A R717
# B R170
# T3 256.15
# C 0.7070950485372465
# A R717
# B R170
# T3 257.15
# C 0.7060322810541267
# A R717
# B R170
# T3 258.15
# C 0.7047027196348565
# A R717
# B R170
# T3 259.15
# C 0.7031063783616497
# A R717
# B R170
# T3 260.15
# C 0.7012431755145978
# A R717
# B R170
# T3 261.15
# C 0.6991129388683056
# A R717
# B R170
# T3 262.15
# C 0.6967154093546984
# A R717
# B R170
# T3 263.15
# C 0.6940502430896642
# A R717
# B R170
# T3 264.15
# C 0.6911170117701217
# A R717
# B R170
# T3 265.15
# C 0.6879152013890656
# A R717
# B R170
# T3 266.15
# C 0.6844442091268598
# A R717
# B R170
# T3 267.15
# C 0.6807033385720173
# A R717
# B R170
# T3 268.15
# C 0.6766917928659297
# A R717
# B R170
# T3 269.15
# C 0.6724086658427016
# A R717
# B R170
# T3 270.15
# C 0.6678529308878827
# A R717
# B R170
# T3 271.15
# C 0.6630234273245703
# A R717
# B R170
# T3 272.15
# C 0.6579188440082754
# A R717
# B R170
# T3 273.15
# C 0.6525376997635681
# A R717
# B R170
# T3 274.15
# C 0.6468783201780542
# A R717
# B R170
# T3 275.15
# C 0.6409388101447926
# A R717
# B R170
# T3 276.15
# C 0.6347170213747024
# A R290
# B R170
# T3 243.15
# C 0.7455433138083452
# A R290
# B R170
# T3 244.15
# C 0.7454939362319585
# A R290
# B R170
# T3 245.15
# C 0.7452472973042922
# A R290
# B R170
# T3 246.15
# C 0.7448035764495177
# A R290
# B R170
# T3 247.15
# C 0.7441628215755324
# A R290
# B R170
# T3 248.15
# C 0.74332495844535
# A R290
# B R170
# T3 249.15
# C 0.7422897990398659
# A R290
# B R170
# T3 250.15
# C 0.7410570489863284
# A R290
# B R170
# T3 251.15
# C 0.7396263141144472
# A R290
# B R170
# T3 252.15
# C 0.7379971061930316
# A R290
# B R170
# T3 253.15
# C 0.7361688478828027
# A R290
# B R170
# T3 254.15
# C 0.7341408769360311
# A R290
# B R170
# T3 255.15
# C 0.7319124496526985
# A R290
# B R170
# T3 256.15
# C 0.7294827436590955
# A R290
# B R170
# T3 257.15
# C 0.7268508598390919
# A R290
# B R170
# T3 258.15
# C 0.7240158236592559
# A R290
# B R170
# T3 259.15
# C 0.7209765856420456
# A R290
# B R170
# T3 260.15
# C 0.7177320210631774
# A R290
# B R170
# T3 261.15
# C 0.7142809287922806
# A R290
# B R170
# T3 262.15
# C 0.7106220292418347
# A R290
# B R170
# T3 263.15
# C 0.7067539613262069
# A R290
# B R170
# T3 264.15
# C 0.702675278395156
# A R290
# B R170
# T3 265.15
# C 0.6983844430284444
# A R290
# B R170
# T3 266.15
# C 0.6938798204928938
# A R290
# B R170
# T3 267.15
# C 0.68915967098886
# A R290
# B R170
# T3 268.15
# C 0.6842221402391597
# A R290
# B R170
# T3 269.15
# C 0.6790652484468322
# A R290
# B R170
# T3 270.15
# C 0.6736868773396109
# A R290
# B R170
# T3 271.15
# C 0.6680847550560037
# A R290
# B R170
# T3 272.15
# C 0.6622564385499996
# A R290
# B R170
# T3 273.15
# C 0.6561992931158906
# A R290
# B R170
# T3 274.15
# C 0.6499104685330602
# A R290
# B R170
# T3 275.15
# C 0.6433868712007103
# A R290
# B R170
# T3 276.15
# C 0.636625131467532
# A R600
# B R170
# T3 243.15
# C 0.6494392663298043
# A R600
# B R170
# T3 244.15
# C 0.6566473001648182
# A R600
# B R170
# T3 245.15
# C 0.6629296417351028
# A R600
# B R170
# T3 246.15
# C 0.6683851410337721
# A R600
# B R170
# T3 247.15
# C 0.6730940367633229
# A R600
# B R170
# T3 248.15
# C 0.6771224214647522
# A R600
# B R170
# T3 249.15
# C 0.6805254201254795
# A R600
# B R170
# T3 250.15
# C 0.6833495067264014
# A R600
# B R170
# T3 251.15
# C 0.6856342276844196
# A R600
# B R170
# T3 252.15
# C 0.6874135072246605
# A R600
# B R170
# T3 253.15
# C 0.6887166518741482
# A R600
# B R170
# T3 254.15
# C 0.6895691345378389
# A R600
# B R170
# T3 255.15
# C 0.6899932140926878
# A R600
# B R170
# T3 256.15
# C 0.6900084306754561
# A R600
# B R170
# T3 257.15
# C 0.6896320053930111
# A R600
# B R170
# T3 258.15
# C 0.6888791659482972
# A R600
# B R170
# T3 259.15
# C 0.6877634138891014
# A R600
# B R170
# T3 260.15
# C 0.6862967454177966
# A R600
# B R170
# T3 261.15
# C 0.6844898349294565
# A R600
# B R170
# T3 262.15
# C 0.6823521882482374
# A R600
# B R170
# T3 263.15
# C 0.6798922709751508
# A R600
# B R170
# T3 264.15
# C 0.677117616230736
# A R600
# B R170
# T3 265.15
# C 0.6740349151384097
# A R600
# B R170
# T3 266.15
# C 0.6706500925763181
# A R600
# B R170
# T3 267.15
# C 0.6669683705398155
# A R600
# B R170
# T3 268.15
# C 0.6629943204629464
# A R600
# B R170
# T3 269.15
# C 0.6587319059989616
# A R600
# B R170
# T3 270.15
# C 0.6541845171804633
# A R600
# B R170
# T3 271.15
# C 0.6493549966934908
# A R600
# B R170
# T3 272.15
# C 0.6442456588599521
# A R600
# B R170
# T3 273.15
# C 0.6388583014401382
# A R600
# B R170
# T3 274.15
# C 0.633194210578946
# A R600
# B R170
# T3 275.15
# C 0.6272541585979531
# A R600
# B R170
# T3 276.15
# C 0.6210383943257056
# A R404a
# B R170
# T3 243.15
# C 0.7280344438295593
# A R404a
# B R170
# T3 244.15
# C 0.7283381658180985
# A R404a
# B R170
# T3 245.15
# C 0.7284526057400722
# A R404a
# B R170
# T3 246.15
# C 0.7283772245817255
# A R404a
# B R170
# T3 247.15
# C 0.7281113752472996
# A R404a
# B R170
# T3 248.15
# C 0.7276543103701402
# A R404a
# B R170
# T3 249.15
# C 0.7270051892815896
# A R404a
# B R170
# T3 250.15
# C 0.72616308419911
# A R404a
# B R170
# T3 251.15
# C 0.7251269856727989
# A R404a
# B R170
# T3 252.15
# C 0.7238958073313563
# A R404a
# B R170
# T3 253.15
# C 0.7224683899519208
# A R404a
# B R170
# T3 254.15
# C 0.7208435048715663
# A R404a
# B R170
# T3 255.15
# C 0.7190198567402416
# A R404a
# B R170
# T3 256.15
# C 0.7169960856716712
# A R404a
# B R170
# T3 257.15
# C 0.714770768620825
# A R404a
# B R170
# T3 258.15
# C 0.712342420210928
# A R404a
# B R170
# T3 259.15
# C 0.7097094927711738
# A R404a
# B R170
# T3 260.15
# C 0.7068703756421083
# A R404a
# B R170
# T3 261.15
# C 0.7038233936795745
# A R404a
# B R170
# T3 262.15
# C 0.7005668048989692
# A R404a
# B R170
# T3 263.15
# C 0.6970987971735605
# A R404a
# B R170
# T3 264.15
# C 0.6934174839361977
# A R404a
# B R170
# T3 265.15
# C 0.6895208987701914
# A R404a
# B R170
# T3 266.15
# C 0.685406988705409
# A R404a
# B R170
# T3 267.15
# C 0.6810736062925005
# A R404a
# B R170
# T3 268.15
# C 0.6765185000709957
# A R404a
# B R170
# T3 269.15
# C 0.6717393034070687
# A R404a
# B R170
# T3 270.15
# C 0.6667335214345368
# A R404a
# B R170
# T3 271.15
# C 0.6614985158461303
# A R404a
# B R170
# T3 272.15
# C 0.6560314872121509
# A R404a
# B R170
# T3 273.15
# C 0.6503294544241635
# A R404a
# B R170
# T3 274.15
# C 0.6443892307598044
# A R404a
# B R170
# T3 275.15
# C 0.6382073959364618
# A R404a
# B R170
# T3 276.15
# C 0.6317802633599784
# A R134a
# B NitrousOxide
# T3 243.15
# C 0.7211096769675192
# A R134a
# B NitrousOxide
# T3 244.15
# C 0.7222652632919436
# A R134a
# B NitrousOxide
# T3 245.15
# C 0.7231673559670622
# A R134a
# B NitrousOxide
# T3 246.15
# C 0.7238236998024926
# A R134a
# B NitrousOxide
# T3 247.15
# C 0.7242413333896821
# A R134a
# B NitrousOxide
# T3 248.15
# C 0.7244266664991682
# A R134a
# B NitrousOxide
# T3 249.15
# C 0.724385546981908
# A R134a
# B NitrousOxide
# T3 250.15
# C 0.7241233188095229
# A R134a
# B NitrousOxide
# T3 251.15
# C 0.7236448725918965
# A R134a
# B NitrousOxide
# T3 252.15
# C 0.7229546896642668
# A R134a
# B NitrousOxide
# T3 253.15
# C 0.7220568806465043
# A R134a
# B NitrousOxide
# T3 254.15
# C 0.7209552192265161
# A R134a
# B NitrousOxide
# T3 255.15
# C 0.7196531717875926
# A R134a
# B NitrousOxide
# T3 256.15
# C 0.7181539233992248
# A R134a
# B NitrousOxide
# T3 257.15
# C 0.7164604006056041
# A R134a
# B NitrousOxide
# T3 258.15
# C 0.7145752913812425
# A R134a
# B NitrousOxide
# T3 259.15
# C 0.7125010625108364
# A R134a
# B NitrousOxide
# T3 260.15
# C 0.7102399747740098
# A R134a
# B NitrousOxide
# T3 261.15
# C 0.7077940959609551
# A R134a
# B NitrousOxide
# T3 262.15
# C 0.7051653120413731
# A R134a
# B NitrousOxide
# T3 263.15
# C 0.7023553365644631
# A R134a
# B NitrousOxide
# T3 264.15
# C 0.6993657184095936
# A R134a
# B NitrousOxide
# T3 265.15
# C 0.6961978479769958
# A R134a
# B NitrousOxide
# T3 266.15
# C 0.6928529618753752
# A R134a
# B NitrousOxide
# T3 267.15
# C 0.6893321461461445
# A R134a
# B NitrousOxide
# T3 268.15
# C 0.6856363380376499
# A R134a
# B NitrousOxide
# T3 269.15
# C 0.6817663263205098
# A R134a
# B NitrousOxide
# T3 270.15
# C 0.6777227501111109
# A R134a
# B NitrousOxide
# T3 271.15
# C 0.6735060961452412
# A R134a
# B NitrousOxide
# T3 272.15
# C 0.6691166944138368
# A R134a
# B NitrousOxide
# T3 273.15
# C 0.6645547120445884
# A R134a
# B NitrousOxide
# T3 274.15
# C 0.6598201452712238
# A R134a
# B NitrousOxide
# T3 275.15
# C 0.6549128092826085
# A R134a
# B NitrousOxide
# T3 276.15
# C 0.6498323257746103
# A R717
# B NitrousOxide
# T3 243.15
# C 0.6910741817345213
# A R717
# B NitrousOxide
# T3 244.15
# C 0.6934517092505758
# A R717
# B NitrousOxide
# T3 245.15
# C 0.6955737530763877
# A R717
# B NitrousOxide
# T3 246.15
# C 0.6974446291666542
# A R717
# B NitrousOxide
# T3 247.15
# C 0.6990682897085863
# A R717
# B NitrousOxide
# T3 248.15
# C 0.7004483633141512
# A R717
# B NitrousOxide
# T3 249.15
# C 0.7015881902538722
# A R717
# B NitrousOxide
# T3 250.15
# C 0.7024908533962981
# A R717
# B NitrousOxide
# T3 251.15
# C 0.7031592053927891
# A R717
# B NitrousOxide
# T3 252.15
# C 0.7035958925921809
# A R717
# B NitrousOxide
# T3 253.15
# C 0.7038033760589603
# A R717
# B NitrousOxide
# T3 254.15
# C 0.703783950022205
# A R717
# B NitrousOxide
# T3 255.15
# C 0.7035397580497073
# A R717
# B NitrousOxide
# T3 256.15
# C 0.7030728071554359
# A R717
# B NitrousOxide
# T3 257.15
# C 0.7023849800583835
# A R717
# B NitrousOxide
# T3 258.15
# C 0.7014780457524505
# A R717
# B NitrousOxide
# T3 259.15
# C 0.7003536685197391
# A R717
# B NitrousOxide
# T3 260.15
# C 0.6990134155039003
# A R717
# B NitrousOxide
# T3 261.15
# C 0.6974587629442843
# A R717
# B NitrousOxide
# T3 262.15
# C 0.6956911011346006
# A R717
# B NitrousOxide
# T3 263.15
# C 0.6937117381712136
# A R717
# B NitrousOxide
# T3 264.15
# C 0.6915219025228855
# A R717
# B NitrousOxide
# T3 265.15
# C 0.6891227444461285
# A R717
# B NitrousOxide
# T3 266.15
# C 0.686515336266092
# A R717
# B NitrousOxide
# T3 267.15
# C 0.6837006715003558
# A R717
# B NitrousOxide
# T3 268.15
# C 0.6806796628041092
# A R717
# B NitrousOxide
# T3 269.15
# C 0.6774531387057618
# A R717
# B NitrousOxide
# T3 270.15
# C 0.6740218390470977
# A R717
# B NitrousOxide
# T3 271.15
# C 0.6703864090725599
# A R717
# B NitrousOxide
# T3 272.15
# C 0.6665473920363623
# A R717
# B NitrousOxide
# T3 273.15
# C 0.6625052201998649
# A R717
# B NitrousOxide
# T3 274.15
# C 0.6582602040444534
# A R717
# B NitrousOxide
# T3 275.15
# C 0.6538125194899609
# A R717
# B NitrousOxide
# T3 276.15
# C 0.6491621928530721
# A R290
# B NitrousOxide
# T3 243.15
# C 0.7395841149199233
# A R290
# B NitrousOxide
# T3 244.15
# C 0.7394659752645155
# A R290
# B NitrousOxide
# T3 245.15
# C 0.7391785979079287
# A R290
# B NitrousOxide
# T3 246.15
# C 0.7387235747174822
# A R290
# B NitrousOxide
# T3 247.15
# C 0.7381023691562235
# A R290
# B NitrousOxide
# T3 248.15
# C 0.7373163256413158
# A R290
# B NitrousOxide
# T3 249.15
# C 0.7363666779306127
# A R290
# B NitrousOxide
# T3 250.15
# C 0.7352545566195977
# A R290
# B NitrousOxide
# T3 251.15
# C 0.733980995817919
# A R290
# B NitrousOxide
# T3 252.15
# C 0.7325469390683096
# A R290
# B NitrousOxide
# T3 253.15
# C 0.7309532445544514
# A R290
# B NitrousOxide
# T3 254.15
# C 0.7292006896420082
# A R290
# B NitrousOxide
# T3 255.15
# C 0.7272899747872347
# A R290
# B NitrousOxide
# T3 256.15
# C 0.7252217268395293
# A R290
# B NitrousOxide
# T3 257.15
# C 0.7229965017564279
# A R290
# B NitrousOxide
# T3 258.15
# C 0.7206147867501748
# A R290
# B NitrousOxide
# T3 259.15
# C 0.7180770018660464
# A R290
# B NitrousOxide
# T3 260.15
# C 0.7153835010051345
# A R290
# B NitrousOxide
# T3 261.15
# C 0.7125345723707999
# A R290
# B NitrousOxide
# T3 262.15
# C 0.709530438346255
# A R290
# B NitrousOxide
# T3 263.15
# C 0.7063712547695398
# A R290
# B NitrousOxide
# T3 264.15
# C 0.7030571095908767
# A R290
# B NitrousOxide
# T3 265.15
# C 0.6995880208730296
# A R290
# B NitrousOxide
# T3 266.15
# C 0.6959639340964536
# A R290
# B NitrousOxide
# T3 267.15
# C 0.6921847187118167
# A R290
# B NitrousOxide
# T3 268.15
# C 0.6882501638814658
# A R290
# B NitrousOxide
# T3 269.15
# C 0.6841599733273055
# A R290
# B NitrousOxide
# T3 270.15
# C 0.6799137591934105
# A R290
# B NitrousOxide
# T3 271.15
# C 0.6755110348127942
# A R290
# B NitrousOxide
# T3 272.15
# C 0.6709512062419012
# A R290
# B NitrousOxide
# T3 273.15
# C 0.666233562403108
# A R290
# B NitrousOxide
# T3 274.15
# C 0.6613572636444071
# A R290
# B NitrousOxide
# T3 275.15
# C 0.6563213284847134
# A R290
# B NitrousOxide
# T3 276.15
# C 0.6511246182620439
# A R600
# B NitrousOxide
# T3 243.15
# C 0.6447129360072953
# A R600
# B NitrousOxide
# T3 244.15
# C 0.6517771649386505
# A R600
# B NitrousOxide
# T3 245.15
# C 0.65794603093155
# A R600
# B NitrousOxide
# T3 246.15
# C 0.6633196790957046
# A R600
# B NitrousOxide
# T3 247.15
# C 0.6679796819250586
# A R600
# B NitrousOxide
# T3 248.15
# C 0.6719934898918206
# A R600
# B NitrousOxide
# T3 249.15
# C 0.6754176004187971
# A R600
# B NitrousOxide
# T3 250.15
# C 0.6782998679976292
# A R600
# B NitrousOxide
# T3 251.15
# C 0.680681223357155
# A R600
# B NitrousOxide
# T3 252.15
# C 0.6825969760538795
# A R600
# B NitrousOxide
# T3 253.15
# C 0.6840778172469895
# A R600
# B NitrousOxide
# T3 254.15
# C 0.6851506028357717
# A R600
# B NitrousOxide
# T3 255.15
# C 0.6858389727207967
# A R600
# B NitrousOxide
# T3 256.15
# C 0.6861638461888562
# A R600
# B NitrousOxide
# T3 257.15
# C 0.6861438222280913
# A R600
# B NitrousOxide
# T3 258.15
# C 0.6857955059948473
# A R600
# B NitrousOxide
# T3 259.15
# C 0.6851337773164582
# A R600
# B NitrousOxide
# T3 260.15
# C 0.6841720130770579
# A R600
# B NitrousOxide
# T3 261.15
# C 0.6829222726839183
# A R600
# B NitrousOxide
# T3 262.15
# C 0.681395453606922
# A R600
# B NitrousOxide
# T3 263.15
# C 0.6796014224523699
# A R600
# B NitrousOxide
# T3 264.15
# C 0.6775491258653581
# A R600
# B NitrousOxide
# T3 265.15
# C 0.6752466846701534
# A R600
# B NitrousOxide
# T3 266.15
# C 0.6727014739251819
# A R600
# B NitrousOxide
# T3 267.15
# C 0.6699201910571806
# A R600
# B NitrousOxide
# T3 268.15
# C 0.6669089137909371
# A R600
# B NitrousOxide
# T3 269.15
# C 0.6636731492716248
# A R600
# B NitrousOxide
# T3 270.15
# C 0.6602178754827072
# A R600
# B NitrousOxide
# T3 271.15
# C 0.6565475758240887
# A R600
# B NitrousOxide
# T3 272.15
# C 0.6526662676273767
# A R600
# B NitrousOxide
# T3 273.15
# C 0.6485775249508842
# A R600
# B NitrousOxide
# T3 274.15
# C 0.6442844962828653
# A R600
# B NitrousOxide
# T3 275.15
# C 0.6397899172432456
# A R600
# B NitrousOxide
# T3 276.15
# C 0.6350961184782958
# A R404a
# B NitrousOxide
# T3 243.15
# C 0.7223100469332726
# A R404a
# B NitrousOxide
# T3 244.15
# C 0.7225429867906378
# A R404a
# B NitrousOxide
# T3 245.15
# C 0.722613606418989
# A R404a
# B NitrousOxide
# T3 246.15
# C 0.7225227969423126
# A R404a
# B NitrousOxide
# T3 247.15
# C 0.7222713492818571
# A R404a
# B NitrousOxide
# T3 248.15
# C 0.7218599618279349
# A R404a
# B NitrousOxide
# T3 249.15
# C 0.7212892472998259
# A R404a
# B NitrousOxide
# T3 250.15
# C 0.7205597388630014
# A R404a
# B NitrousOxide
# T3 251.15
# C 0.7196718955503073
# A R404a
# B NitrousOxide
# T3 252.15
# C 0.7186261070380809
# A R404a
# B NitrousOxide
# T3 253.15
# C 0.7174226978125842
# A R404a
# B NitrousOxide
# T3 254.15
# C 0.7160619307582173
# A R404a
# B NitrousOxide
# T3 255.15
# C 0.7145440101918443
# A R404a
# B NitrousOxide
# T3 256.15
# C 0.7128690843617377
# A R404a
# B NitrousOxide
# T3 257.15
# C 0.7110372474238945
# A R404a
# B NitrousOxide
# T3 258.15
# C 0.709048540903062
# A R404a
# B NitrousOxide
# T3 259.15
# C 0.7069029546401738
# A R404a
# B NitrousOxide
# T3 260.15
# C 0.7046004272225387
# A R404a
# B NitrousOxide
# T3 261.15
# C 0.7021408458873211
# A R404a
# B NitrousOxide
# T3 262.15
# C 0.6995240458830081
# A R404a
# B NitrousOxide
# T3 263.15
# C 0.6967498092669887
# A R404a
# B NitrousOxide
# T3 264.15
# C 0.693817863110427
# A R404a
# B NitrousOxide
# T3 265.15
# C 0.690727877070352
# A R404a
# B NitrousOxide
# T3 266.15
# C 0.6874794603044649
# A R404a
# B NitrousOxide
# T3 267.15
# C 0.6840721576226596
# A R404a
# B NitrousOxide
# T3 268.15
# C 0.6805054448746204
# A R404a
# B NitrousOxide
# T3 269.15
# C 0.6767787234450866
# A R404a
# B NitrousOxide
# T3 270.15
# C 0.6728913137802232
# A R404a
# B NitrousOxide
# T3 271.15
# C 0.6688424478276221
# A R404a
# B NitrousOxide
# T3 272.15
# C 0.6646312602542918
# A R404a
# B NitrousOxide
# T3 273.15
# C 0.6602567782796761
# A R404a
# B NitrousOxide
# T3 274.15
# C 0.6557179099296413
# A R404a
# B NitrousOxide
# T3 275.15
# C 0.6510134304781963
# A R404a
# B NitrousOxide
# T3 276.15
# C 0.6461419667961263
