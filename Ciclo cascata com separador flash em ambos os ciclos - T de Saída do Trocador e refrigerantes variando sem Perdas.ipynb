# %%
from CoolProp.CoolProp import PropsSI as COOLPROP
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import get_test_data

#Listas
registro_fluidos = []
COP_lista = []
lista_T5 = []
Wcomp_total_lista = []
cont = []

#Lista de Temperaturas
for T5 in range (-3000 + 27315, 400 + 27315, 100):
    T5 = T5 / 100
    cont.append(T5)

#Lista de características para as curvas do gráfico
lista_cor = ['r','g','b', 'c', 'm']
lista_ls = ['-', '-.', ':']
caracteristicas = []
for ls in lista_ls:
    for cor in lista_cor:
        caracteristicas.append((cor, ls))   
    
#Parâmetros
Pfrig = 120 * 1000
T1 = -80 + 273.15
T13 = 28 + 273.15
N = 0.7 #Eficiência isentrópica
fluid_high_lista = ['R134a', 'R717', 'R290', 'R600', 'R404a']
fluid_low_lista = ['R23', 'R170', 'NitrousOxide']
drop_suc = 0 #[Pa]
drop_desc = 0 #[Pa]
DeltaT = 0 #[°C]

#Loop nos dois ciclos - variação dos refrigerantes e do coeficiente politrópico
for fluid_low in fluid_low_lista:
    for fluid_high in fluid_high_lista:
        if fluid_low == 'NitrousOxide':
            par_fluido = ('Óxido nitroso', fluid_high)    
        else:
            par_fluido = (fluid_low, fluid_high)
        registro_fluidos.append(par_fluido)
         #Temperatura T5
        for T5 in cont:
            #Pressão crítica do fluido superior
            P_crit_high = COOLPROP('PCRIT', fluid_high)
            #Ciclo inferior
            P1 = COOLPROP('P', 'T', T1, 'Q', 1, fluid_low)
            P5 = COOLPROP('P', 'T', T5, 'Q', 0, fluid_low)
            h5 = COOLPROP('H', 'T', T5, 'Q', 0, fluid_low)
            h6 = h5
            #Pressão intermediária
            P_int =  (P1 * P5) ** 0.5
            P6 = P_int
            P3 = P_int
            P7 = P_int
            P2 = P_int
            h7 = COOLPROP('H', 'P', P7, 'Q', 0, fluid_low)
            h8 = h7
            h3 = COOLPROP('H', 'P', P3, 'Q', 1, fluid_low)
            h1 = COOLPROP('H', 'T', T1, 'Q', 1, fluid_low)
            S1 = COOLPROP('S', 'T', T1, 'Q', 1, fluid_low)
            #CBP
            S2_ideal = S1    
            h2_ideal = COOLPROP('H', 'S', S2_ideal , 'P', P2, fluid_low)
            h2_real = (h2_ideal - h1)/N + h1
            
            m_CBP_inf = Pfrig / (h1 - h8)
            #CAP
            s3 = COOLPROP('S', 'P', P3, 'H', h3, fluid_low)
            P4 = P5
            s4_ideal = s3
            h4_ideal = COOLPROP('H', 'P', P4, 'S', s4_ideal, fluid_low)
            h4_real = (h4_ideal - h3)/N + h3
            
            #Ciclo superior
            T16 = T5 - 5
            P16 = COOLPROP('P', 'T', T16, 'Q', 0, fluid_high)
            P9 = P16
            T9 = COOLPROP('T', 'P', P9, 'Q', 1, fluid_high)
            P13 = COOLPROP('P', 'T', T13, 'Q', 0, fluid_high)
            h13 = COOLPROP('H', 'T', T13, 'Q', 0, fluid_high)
            h14 = h13
            P12 = P13
            #Pressão intermediária Superior
            P_int_sup = (P9 * P13) ** 0.5
            P10 = P_int_sup
            P11 = P_int_sup
            P14 = P_int_sup
            P15 = P_int_sup
            h15 = COOLPROP('H', 'P', P15, 'Q', 0, fluid_high)
            h16 = h15
            h11 = COOLPROP('H', 'P', P7, 'Q', 1, fluid_high)
            h9 = COOLPROP('H', 'T', T9, 'Q', 1, fluid_high)
            #CBP_sup
            s9 = COOLPROP('S', 'Q', 1, 'T', T9, fluid_high)
            s10_ideal = s9
            h10_ideal = COOLPROP('H', 'P', P10, 'S', s10_ideal, fluid_high)
            h10_real = (h10_ideal - h9)/N + h9
            
            #CAP_sup
            s11 = COOLPROP('S', 'P', P11, 'H', h11, fluid_high)
            s12_ideal = s11
            h12_ideal = COOLPROP('H', 'P', P12, 'S', s12_ideal, fluid_high)
            h12_real = (h12_ideal - h11)/N + h11
       
            #Ciclo de baixa pressão
            #Trabalho específico do CBP_inf
            w_CBP_inf = h2_real - h1
            #Trabalho do CBP_inf
            W_CBP_inf = m_CBP_inf * w_CBP_inf
            #CAP_inf
            m_CAP_inf = m_CBP_inf * (h7 - h2_real) / (h6 - h3)
            #Trabalho específico do CAP
            w_CAP_inf = h4_real - h3
            #Trabalho do CAP_inf
            W_CAP_inf = m_CAP_inf * w_CAP_inf
            #Trabalho total no ciclo de baixa pressão
            W_low_total = W_CAP_inf + W_CBP_inf
            #Calor trocado no trocador central
            Qcond_low =  m_CAP_inf * (h4_real - h5)
         
            #Ciclo de alta pressão
            Qevap_high = Qcond_low
            #CBP_sup
            m_CBP_sup = Qevap_high / (h9 - h16)
            #Trabalho específico do CBP_sup
            w_CBP_sup = h10_real - h9
            #Trabalho do CBP_sup
            W_CBP_sup = w_CBP_sup * m_CBP_sup
            #CAP_sup
            m_CAP_sup = m_CBP_sup * (h15 - h10_real) / (h14 - h11)
            if P_crit_high > P12:
                lista_T5.append(T5)
                #Trabalho específico do CAP_sup
                w_CAP_sup = h12_real - h11
                #Trabalho do CAP_sup
                W_CAP_sup = m_CAP_sup * w_CAP_sup
                #Trabalho total do ciclo de alta pressão
                W_high_total = W_CAP_sup + W_CBP_sup
                #Trabalho total do ciclo
                Wcomp_total = W_low_total + W_high_total
                Wcomp_total_lista.append(Wcomp_total / 1000)
                #COP
                COP = Pfrig / Wcomp_total
                COP_lista.append(COP)
                print("A", fluid_high)
                print("B", fluid_low)
                print("T5", T5)
                print("C", COP)
            else:
                print ('A pressão P12 = {:0.2f} kPa (T5 = {}, fluido inf = {}, fluido sup = {}) é maior do que a ' 
               'pressão crítica do {} logo o ponto não foi incluído no gráfico'.format(P12 / 1000,T5,fluid_low,
                                                                                               fluid_high, fluid_high))       
 
    
if len(lista_T5) != 0:
    plt.figure(figsize = [15, 15], dpi = 300)
    for i in range (0, len(COP_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T5[j])
            eixo_y.append(COP_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1], 
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T5', size = 15)
        plt.ylabel('COP', size = 15)
    plt.legend(prop={'size' : 15})
    plt.show()
else:
    print('Todos os pontos são inválidos')
# Out:
# A R134a
# B R23
# T5 243.15
# C 0.919225725304649
# A R134a
# B R23
# T5 244.15
# C 0.9186741945283121
# A R134a
# B R23
# T5 245.15
# C 0.9180032386493026
# A R134a
# B R23
# T5 246.15
# C 0.9172113009790437
# A R134a
# B R23
# T5 247.15
# C 0.9162967572306008
# A R134a
# B R23
# T5 248.15
# C 0.9152579122007783
# A R134a
# B R23
# T5 249.15
# C 0.9140929961503717
# A R134a
# B R23
# T5 250.15
# C 0.9128001608669788
# A R134a
# B R23
# T5 251.15
# C 0.9113774753242878
# A R134a
# B R23
# T5 252.15
# C 0.9098229209548436
# A R134a
# B R23
# T5 253.15
# C 0.9081343864503673
# A R134a
# B R23
# T5 254.15
# C 0.9063096620148051
# A R134a
# B R23
# T5 255.15
# C 0.9043464330503895
# A R134a
# B R23
# T5 256.15
# C 0.9022422731619072
# A R134a
# B R23
# T5 257.15
# C 0.8999946364067654
# A R134a
# B R23
# T5 258.15
# C 0.8976008487097589
# A R134a
# B R23
# T5 259.15
# C 0.8950580981661447
# A R134a
# B R23
# T5 260.15
# C 0.8923634245243688
# A R134a
# B R23
# T5 261.15
# C 0.8895137070685236
# A R134a
# B R23
# T5 262.15
# C 0.8865056512131286
# A R134a
# B R23
# T5 263.15
# C 0.8833357733721874
# A R134a
# B R23
# T5 264.15
# C 0.8800003838735634
# A R134a
# B R23
# T5 265.15
# C 0.8764955676105658
# A R134a
# B R23
# T5 266.15
# C 0.8728171620514923
# A R134a
# B R23
# T5 267.15
# C 0.8689607321608753
# A R134a
# B R23
# T5 268.15
# C 0.8649215416886042
# A R134a
# B R23
# T5 269.15
# C 0.8606945201556442
# A R134a
# B R23
# T5 270.15
# C 0.8562742247929944
# A R134a
# B R23
# T5 271.15
# C 0.8516547963556215
# A R134a
# B R23
# T5 272.15
# C 0.8468299075270973
# A R134a
# B R23
# T5 273.15
# C 0.8417927027386978
# A R134a
# B R23
# T5 274.15
# C 0.8365357270008758
# A R134a
# B R23
# T5 275.15
# C 0.8310508415872787
# A R134a
# B R23
# T5 276.15
# C 0.8253291236083155
# A R717
# B R23
# T5 243.15
# C 0.9222905596833734
# A R717
# B R23
# T5 244.15
# C 0.9220219897902447
# A R717
# B R23
# T5 245.15
# C 0.9216125106584233
# A R717
# B R23
# T5 246.15
# C 0.9210610506196356
# A R717
# B R23
# T5 247.15
# C 0.9203664813855514
# A R717
# B R23
# T5 248.15
# C 0.9195276139047656
# A R717
# B R23
# T5 249.15
# C 0.9185431939328307
# A R717
# B R23
# T5 250.15
# C 0.9174118968371853
# A R717
# B R23
# T5 251.15
# C 0.916132225404611
# A R717
# B R23
# T5 252.15
# C 0.9147026349165697
# A R717
# B R23
# T5 253.15
# C 0.9131215726648083
# A R717
# B R23
# T5 254.15
# C 0.9113873924892881
# A R717
# B R23
# T5 255.15
# C 0.9094983477060713
# A R717
# B R23
# T5 256.15
# C 0.9074525833586992
# A R717
# B R23
# T5 257.15
# C 0.9052481277425923
# A R717
# B R23
# T5 258.15
# C 0.9028828830834735
# A R717
# B R23
# T5 259.15
# C 0.9003546152512757
# A R717
# B R23
# T5 260.15
# C 0.8976609423719832
# A R717
# B R23
# T5 261.15
# C 0.8947993221868356
# A R717
# B R23
# T5 262.15
# C 0.8917670379558664
# A R717
# B R23
# T5 263.15
# C 0.88856118276571
# A R717
# B R23
# T5 264.15
# C 0.8851786415179125
# A R717
# B R23
# T5 265.15
# C 0.8816160715938496
# A R717
# B R23
# T5 266.15
# C 0.8778698796864055
# A R717
# B R23
# T5 267.15
# C 0.8739361964673724
# A R717
# B R23
# T5 268.15
# C 0.8698108472757505
# A R717
# B R23
# T5 269.15
# C 0.8654893185896843
# A R717
# B R23
# T5 270.15
# C 0.8609667194653285
# A R717
# B R23
# T5 271.15
# C 0.8562377368757818
# A R717
# B R23
# T5 272.15
# C 0.8512965836575089
# A R717
# B R23
# T5 273.15
# C 0.8461369378937053
# A R717
# B R23
# T5 274.15
# C 0.8407518713297804
# A R717
# B R23
# T5 275.15
# C 0.8351337647110298
# A R717
# B R23
# T5 276.15
# C 0.8292742068078514
# A R290
# B R23
# T5 243.15
# C 0.9136925154620905
# A R290
# B R23
# T5 244.15
# C 0.9131818804638423
# A R290
# B R23
# T5 245.15
# C 0.9125539054989629
# A R290
# B R23
# T5 246.15
# C 0.9118070268501154
# A R290
# B R23
# T5 247.15
# C 0.9109396130503412
# A R290
# B R23
# T5 248.15
# C 0.9099499614354403
# A R290
# B R23
# T5 249.15
# C 0.9088362944006869
# A R290
# B R23
# T5 250.15
# C 0.9075967553244079
# A R290
# B R23
# T5 251.15
# C 0.9062294041201093
# A R290
# B R23
# T5 252.15
# C 0.9047322123743226
# A R290
# B R23
# T5 253.15
# C 0.903103058015423
# A R290
# B R23
# T5 254.15
# C 0.9013397194591947
# A R290
# B R23
# T5 255.15
# C 0.8994398691631729
# A R290
# B R23
# T5 256.15
# C 0.8974010665141477
# A R290
# B R23
# T5 257.15
# C 0.8952207499581611
# A R290
# B R23
# T5 258.15
# C 0.8928962282765082
# A R290
# B R23
# T5 259.15
# C 0.8904246708821768
# A R290
# B R23
# T5 260.15
# C 0.8878031038601243
# A R290
# B R23
# T5 261.15
# C 0.885028966042528
# A R290
# B R23
# T5 262.15
# C 0.8820992713722089
# A R290
# B R23
# T5 263.15
# C 0.8790104537841678
# A R290
# B R23
# T5 264.15
# C 0.8757587397079919
# A R290
# B R23
# T5 265.15
# C 0.8723401286017651
# A R290
# B R23
# T5 266.15
# C 0.8687503708491304
# A R290
# B R23
# T5 267.15
# C 0.864984942564804
# A R290
# B R23
# T5 268.15
# C 0.8610390167725211
# A R290
# B R23
# T5 269.15
# C 0.8569074302784717
# A R290
# B R23
# T5 270.15
# C 0.8525846454984465
# A R290
# B R23
# T5 271.15
# C 0.8480647061618967
# A R290
# B R23
# T5 272.15
# C 0.843341185607858
# A R290
# B R23
# T5 273.15
# C 0.8384071264916526
# A R290
# B R23
# T5 274.15
# C 0.8332549695094906
# A R290
# B R23
# T5 275.15
# C 0.8278764690230023
# A R290
# B R23
# T5 276.15
# C 0.8222625923477422
# A R600
# B R23
# T5 243.15
# C 0.9451336557147461
# A R600
# B R23
# T5 244.15
# C 0.9439430615444485
# A R600
# B R23
# T5 245.15
# C 0.942638273074026
# A R600
# B R23
# T5 246.15
# C 0.9412178689409095
# A R600
# B R23
# T5 247.15
# C 0.939680356918547
# A R600
# B R23
# T5 248.15
# C 0.9380241705923451
# A R600
# B R23
# T5 249.15
# C 0.9362476658420459
# A R600
# B R23
# T5 250.15
# C 0.9343491168736486
# A R600
# B R23
# T5 251.15
# C 0.9323267119717963
# A R600
# B R23
# T5 252.15
# C 0.9301785488181198
# A R600
# B R23
# T5 253.15
# C 0.9279026292857339
# A R600
# B R23
# T5 254.15
# C 0.925496853805948
# A R600
# B R23
# T5 255.15
# C 0.9229590150618784
# A R600
# B R23
# T5 256.15
# C 0.9202867910640232
# A R600
# B R23
# T5 257.15
# C 0.9174777374601334
# A R600
# B R23
# T5 258.15
# C 0.9145292789693317
# A R600
# B R23
# T5 259.15
# C 0.9114386998850487
# A R600
# B R23
# T5 260.15
# C 0.9082031334142707
# A R600
# B R23
# T5 261.15
# C 0.9048195497765231
# A R600
# B R23
# T5 262.15
# C 0.9012847428398617
# A R600
# B R23
# T5 263.15
# C 0.8975953150633237
# A R600
# B R23
# T5 264.15
# C 0.8937476604847301
# A R600
# B R23
# T5 265.15
# C 0.8897379454609752
# A R600
# B R23
# T5 266.15
# C 0.885562086764758
# A R600
# B R23
# T5 267.15
# C 0.8812157265999345
# A R600
# B R23
# T5 268.15
# C 0.8766942039817579
# A R600
# B R23
# T5 269.15
# C 0.8719925219496171
# A R600
# B R23
# T5 270.15
# C 0.867105408453978
# A R600
# B R23
# T5 271.15
# C 0.8620271334500418
# A R600
# B R23
# T5 272.15
# C 0.8567514015074976
# A R600
# B R23
# T5 273.15
# C 0.8512713909853804
# A R600
# B R23
# T5 274.15
# C 0.8455796828971535
# A R600
# B R23
# T5 275.15
# C 0.8396681766374625
# A R600
# B R23
# T5 276.15
# C 0.8335279893798061
# A R404a
# B R23
# T5 243.15
# C 0.887274719416091
# A R404a
# B R23
# T5 244.15
# C 0.8874645411976282
# A R404a
# B R23
# T5 245.15
# C 0.8875312596845558
# A R404a
# B R23
# T5 246.15
# C 0.8874730668981411
# A R404a
# B R23
# T5 247.15
# C 0.8872880933782021
# A R404a
# B R23
# T5 248.15
# C 0.8869744047836758
# A R404a
# B R23
# T5 249.15
# C 0.8865299981978207
# A R404a
# B R23
# T5 250.15
# C 0.8859527980911611
# A R404a
# B R23
# T5 251.15
# C 0.8852406519110386
# A R404a
# B R23
# T5 252.15
# C 0.8843913252496888
# A R404a
# B R23
# T5 253.15
# C 0.8834024965402798
# A R404a
# B R23
# T5 254.15
# C 0.8822717512238163
# A R404a
# B R23
# T5 255.15
# C 0.8809965753186781
# A R404a
# B R23
# T5 256.15
# C 0.879574348317475
# A R404a
# B R23
# T5 257.15
# C 0.878002335323064
# A R404a
# B R23
# T5 258.15
# C 0.8762776783176419
# A R404a
# B R23
# T5 259.15
# C 0.8743973864591817
# A R404a
# B R23
# T5 260.15
# C 0.8723583252443807
# A R404a
# B R23
# T5 261.15
# C 0.8701572044024166
# A R404a
# B R23
# T5 262.15
# C 0.8677905643125023
# A R404a
# B R23
# T5 263.15
# C 0.8652547607298209
# A R404a
# B R23
# T5 264.15
# C 0.86254594755382
# A R404a
# B R23
# T5 265.15
# C 0.8596600573260175
# A R404a
# B R23
# T5 266.15
# C 0.8565927790821211
# A R404a
# B R23
# T5 267.15
# C 0.8533395331084375
# A R404a
# B R23
# T5 268.15
# C 0.8498954420613107
# A R404a
# B R23
# T5 269.15
# C 0.8462552977756403
# A R404a
# B R23
# T5 270.15
# C 0.8424135230200294
# A R404a
# B R23
# T5 271.15
# C 0.8383641271201836
# A R404a
# B R23
# T5 272.15
# C 0.8341006541690796
# A R404a
# B R23
# T5 273.15
# C 0.829616122637695
# A R404a
# B R23
# T5 274.15
# C 0.8249029539978037
# A R404a
# B R23
# T5 275.15
# C 0.8199528882361573
# A R404a
# B R23
# T5 276.15
# C 0.8147568830349197
# A R134a
# B R170
# T5 243.15
# C 0.92402312097563
# A R134a
# B R170
# T5 244.15
# C 0.9236188474515403
# A R134a
# B R170
# T5 245.15
# C 0.9231002556652953
# A R134a
# B R170
# T5 246.15
# C 0.9224659490796551
# A R134a
# B R170
# T5 247.15
# C 0.9217144805458932
# A R134a
# B R170
# T5 248.15
# C 0.9208443501223853
# A R134a
# B R170
# T5 249.15
# C 0.9198540027132206
# A R134a
# B R170
# T5 250.15
# C 0.9187418255064824
# A R134a
# B R170
# T5 251.15
# C 0.9175061452059984
# A R134a
# B R170
# T5 252.15
# C 0.9161452250062638
# A R134a
# B R170
# T5 253.15
# C 0.9146572613293842
# A R134a
# B R170
# T5 254.15
# C 0.9130403802367337
# A R134a
# B R170
# T5 255.15
# C 0.9112926335302342
# A R134a
# B R170
# T5 256.15
# C 0.9094119945464705
# A R134a
# B R170
# T5 257.15
# C 0.9073963533856483
# A R134a
# B R170
# T5 258.15
# C 0.9052435118937578
# A R134a
# B R170
# T5 259.15
# C 0.9029511778800305
# A R134a
# B R170
# T5 260.15
# C 0.9005169590769293
# A R134a
# B R170
# T5 261.15
# C 0.8979383561121084
# A R134a
# B R170
# T5 262.15
# C 0.8952127549136392
# A R134a
# B R170
# T5 263.15
# C 0.8923374182313044
# A R134a
# B R170
# T5 264.15
# C 0.8893094761984482
# A R134a
# B R170
# T5 265.15
# C 0.8861259158477045
# A R134a
# B R170
# T5 266.15
# C 0.8827835692541358
# A R134a
# B R170
# T5 267.15
# C 0.8792791005260072
# A R134a
# B R170
# T5 268.15
# C 0.8756089910076907
# A R134a
# B R170
# T5 269.15
# C 0.871769522765844
# A R134a
# B R170
# T5 270.15
# C 0.8677567599887834
# A R134a
# B R170
# T5 271.15
# C 0.8635665279992143
# A R134a
# B R170
# T5 272.15
# C 0.8591943894939099
# A R134a
# B R170
# T5 273.15
# C 0.8546356175437559
# A R134a
# B R170
# T5 274.15
# C 0.8498851647713872
# A R134a
# B R170
# T5 275.15
# C 0.8449376279445301
# A R134a
# B R170
# T5 276.15
# C 0.8397872073665508
# A R717
# B R170
# T5 243.15
# C 0.9248350805966996
# A R717
# B R170
# T5 244.15
# C 0.9248017851007885
# A R717
# B R170
# T5 245.15
# C 0.9246307468736622
# A R717
# B R170
# T5 246.15
# C 0.9243210531451075
# A R717
# B R170
# T5 247.15
# C 0.9238717530931277
# A R717
# B R170
# T5 248.15
# C 0.9232818548026775
# A R717
# B R170
# T5 249.15
# C 0.9225503220531065
# A R717
# B R170
# T5 250.15
# C 0.9216760709178146
# A R717
# B R170
# T5 251.15
# C 0.9206579661449814
# A R717
# B R170
# T5 252.15
# C 0.9194948173198285
# A R717
# B R170
# T5 253.15
# C 0.918185374767783
# A R717
# B R170
# T5 254.15
# C 0.9167283251682364
# A R717
# B R170
# T5 255.15
# C 0.9151222868587147
# A R717
# B R170
# T5 256.15
# C 0.9133658048363139
# A R717
# B R170
# T5 257.15
# C 0.9114573452169495
# A R717
# B R170
# T5 258.15
# C 0.9093952894387909
# A R717
# B R170
# T5 259.15
# C 0.9071779278465634
# A R717
# B R170
# T5 260.15
# C 0.9048034527326583
# A R717
# B R170
# T5 261.15
# C 0.9022699507409574
# A R717
# B R170
# T5 262.15
# C 0.899575394535007
# A R717
# B R170
# T5 263.15
# C 0.8967176337043921
# A R717
# B R170
# T5 264.15
# C 0.8936943843567974
# A R717
# B R170
# T5 265.15
# C 0.8905032186087575
# A R717
# B R170
# T5 266.15
# C 0.8871415514851803
# A R717
# B R170
# T5 267.15
# C 0.883606627622228
# A R717
# B R170
# T5 268.15
# C 0.8798955058204377
# A R717
# B R170
# T5 269.15
# C 0.8760050419733532
# A R717
# B R170
# T5 270.15
# C 0.8719318699247468
# A R717
# B R170
# T5 271.15
# C 0.867672369943785
# A R717
# B R170
# T5 272.15
# C 0.8632225882574462
# A R717
# B R170
# T5 273.15
# C 0.8585783453879
# A R717
# B R170
# T5 274.15
# C 0.8537351528473636
# A R717
# B R170
# T5 275.15
# C 0.8486881593486703
# A R717
# B R170
# T5 276.15
# C 0.8434321096334244
# A R290
# B R170
# T5 243.15
# C 0.9184489213290185
# A R290
# B R170
# T5 244.15
# C 0.9180938864109593
# A R290
# B R170
# T5 245.15
# C 0.9176267970403099
# A R290
# B R170
# T5 246.15
# C 0.91704623027277
# A R290
# B R170
# T5 247.15
# C 0.9163507123833348
# A R290
# B R170
# T5 248.15
# C 0.9155387165718383
# A R290
# B R170
# T5 249.15
# C 0.9146086604905925
# A R290
# B R170
# T5 250.15
# C 0.9135589035749953
# A R290
# B R170
# T5 251.15
# C 0.9123877441570084
# A R290
# B R170
# T5 252.15
# C 0.911093416342131
# A R290
# B R170
# T5 253.15
# C 0.9096740866205929
# A R290
# B R170
# T5 254.15
# C 0.9081278501868875
# A R290
# B R170
# T5 255.15
# C 0.9064527269227852
# A R290
# B R170
# T5 256.15
# C 0.9046466570870191
# A R290
# B R170
# T5 257.15
# C 0.9027074964369655
# A R290
# B R170
# T5 258.15
# C 0.9006330110824842
# A R290
# B R170
# T5 259.15
# C 0.8984208717087034
# A R290
# B R170
# T5 260.15
# C 0.8960686472473633
# A R290
# B R170
# T5 261.15
# C 0.8935737153994403
# A R290
# B R170
# T5 262.15
# C 0.890933130314099
# A R290
# B R170
# T5 263.15
# C 0.8881441058963914
# A R290
# B R170
# T5 264.15
# C 0.8852037492605273
# A R290
# B R170
# T5 265.15
# C 0.8821090222589244
# A R290
# B R170
# T5 266.15
# C 0.878856729516248
# A R290
# B R170
# T5 267.15
# C 0.8754435053067249
# A R290
# B R170
# T5 268.15
# C 0.8718657986497284
# A R290
# B R170
# T5 269.15
# C 0.8681198566868253
# A R290
# B R170
# T5 270.15
# C 0.8642017059726481
# A R290
# B R170
# T5 271.15
# C 0.8601071313803315
# A R290
# B R170
# T5 272.15
# C 0.855831652233157
# A R290
# B R170
# T5 273.15
# C 0.8513704951935641
# A R290
# B R170
# T5 274.15
# C 0.8467185633318886
# A R290
# B R170
# T5 275.15
# C 0.8418704006576981
# A R290
# B R170
# T5 276.15
# C 0.836820151214292
# A R600
# B R170
# T5 243.15
# C 0.9516915105747582
# A R600
# B R170
# T5 244.15
# C 0.9506127561262332
# A R600
# B R170
# T5 245.15
# C 0.9494250162977539
# A R600
# B R170
# T5 246.15
# C 0.9481270405264716
# A R600
# B R170
# T5 247.15
# C 0.9467175245783999
# A R600
# B R170
# T5 248.15
# C 0.9451951083342961
# A R600
# B R170
# T5 249.15
# C 0.943558373501518
# A R600
# B R170
# T5 250.15
# C 0.9418058410119668
# A R600
# B R170
# T5 251.15
# C 0.9399359682966447
# A R600
# B R170
# T5 252.15
# C 0.9379471463052445
# A R600
# B R170
# T5 253.15
# C 0.935837696206114
# A R600
# B R170
# T5 254.15
# C 0.9336058658922898
# A R600
# B R170
# T5 255.15
# C 0.9312498260696765
# A R600
# B R170
# T5 256.15
# C 0.9287676661048148
# A R600
# B R170
# T5 257.15
# C 0.9261573892931408
# A R600
# B R170
# T5 258.15
# C 0.9234169078447174
# A R600
# B R170
# T5 259.15
# C 0.9205440372861287
# A R600
# B R170
# T5 260.15
# C 0.9175364902588435
# A R600
# B R170
# T5 261.15
# C 0.9143918696947151
# A R600
# B R170
# T5 262.15
# C 0.9111076612480241
# A R600
# B R170
# T5 263.15
# C 0.9076812248772707
# A R600
# B R170
# T5 264.15
# C 0.9041097854685926
# A R600
# B R170
# T5 265.15
# C 0.9003904224306205
# A R600
# B R170
# T5 266.15
# C 0.8965200579146126
# A R600
# B R170
# T5 267.15
# C 0.8924954438957575
# A R600
# B R170
# T5 268.15
# C 0.8883131474629318
# A R600
# B R170
# T5 269.15
# C 0.883969534535819
# A R600
# B R170
# T5 270.15
# C 0.87946085228896
# A R600
# B R170
# T5 271.15
# C 0.8747830668260947
# A R600
# B R170
# T5 272.15
# C 0.8699317822646488
# A R600
# B R170
# T5 273.15
# C 0.8649023150527007
# A R600
# B R170
# T5 274.15
# C 0.8596896632132547
# A R600
# B R170
# T5 275.15
# C 0.854288471021382
# A R600
# B R170
# T5 276.15
# C 0.8486929882658687
# A R404a
# B R170
# T5 243.15
# C 0.8929835384004015
# A R404a
# B R170
# T5 244.15
# C 0.8932952212425663
# A R404a
# B R170
# T5 245.15
# C 0.8934879979898322
# A R404a
# B R170
# T5 246.15
# C 0.8935602793734199
# A R404a
# B R170
# T5 247.15
# C 0.8935104305379341
# A R404a
# B R170
# T5 248.15
# C 0.8933367688055299
# A R404a
# B R170
# T5 249.15
# C 0.8930375612634072
# A R404a
# B R170
# T5 250.15
# C 0.892611022145976
# A R404a
# B R170
# T5 251.15
# C 0.8920553099986568
# A R404a
# B R170
# T5 252.15
# C 0.8913685245985966
# A R404a
# B R170
# T5 253.15
# C 0.8905487036071935
# A R404a
# B R170
# T5 254.15
# C 0.8895938189256469
# A R404a
# B R170
# T5 255.15
# C 0.8885017727088073
# A R404a
# B R170
# T5 256.15
# C 0.887270393077896
# A R404a
# B R170
# T5 257.15
# C 0.8858962865052264
# A R404a
# B R170
# T5 258.15
# C 0.8843791644837996
# A R404a
# B R170
# T5 259.15
# C 0.8827168688128015
# A R404a
# B R170
# T5 260.15
# C 0.8809068201813063
# A R404a
# B R170
# T5 261.15
# C 0.8789463367602329
# A R404a
# B R170
# T5 262.15
# C 0.8768326264529842
# A R404a
# B R170
# T5 263.15
# C 0.8745627782953278
# A R404a
# B R170
# T5 264.15
# C 0.872133752891105
# A R404a
# B R170
# T5 265.15
# C 0.8695423717909652
# A R404a
# B R170
# T5 266.15
# C 0.8667853054969737
# A R404a
# B R170
# T5 267.15
# C 0.863859060296586
# A R404a
# B R170
# T5 268.15
# C 0.860759963306792
# A R404a
# B R170
# T5 269.15
# C 0.8574841457861958
# A R404a
# B R170
# T5 270.15
# C 0.854027524349918
# A R404a
# B R170
# T5 271.15
# C 0.8503857797838305
# A R404a
# B R170
# T5 272.15
# C 0.846554333071611
# A R404a
# B R170
# T5 273.15
# C 0.8425283181661327
# A R404a
# B R170
# T5 274.15
# C 0.8383025509224621
# A R404a
# B R170
# T5 275.15
# C 0.8338714934772192
# A R404a
# B R170
# T5 276.15
# C 0.8292292131824304
# A R134a
# B NitrousOxide
# T5 243.15
# C 0.9171471047549989
# A R134a
# B NitrousOxide
# T5 244.15
# C 0.9166313060468817
# A R134a
# B NitrousOxide
# T5 245.15
# C 0.9160135384059009
# A R134a
# B NitrousOxide
# T5 246.15
# C 0.9152931858622471
# A R134a
# B NitrousOxide
# T5 247.15
# C 0.9144695998120569
# A R134a
# B NitrousOxide
# T5 248.15
# C 0.913542098011067
# A R134a
# B NitrousOxide
# T5 249.15
# C 0.9125099634790178
# A R134a
# B NitrousOxide
# T5 250.15
# C 0.9113724433045949
# A R134a
# B NitrousOxide
# T5 251.15
# C 0.9101287473437101
# A R134a
# B NitrousOxide
# T5 252.15
# C 0.9087780467925614
# A R134a
# B NitrousOxide
# T5 253.15
# C 0.9073194726379579
# A R134a
# B NitrousOxide
# T5 254.15
# C 0.9057521139318532
# A R134a
# B NitrousOxide
# T5 255.15
# C 0.9040750159249944
# A R134a
# B NitrousOxide
# T5 256.15
# C 0.9022871780013255
# A R134a
# B NitrousOxide
# T5 257.15
# C 0.9003875514083669
# A R134a
# B NitrousOxide
# T5 258.15
# C 0.8983750367813882
# A R134a
# B NitrousOxide
# T5 259.15
# C 0.8962484812753285
# A R134a
# B NitrousOxide
# T5 260.15
# C 0.8940066757054411
# A R134a
# B NitrousOxide
# T5 261.15
# C 0.8916483510424118
# A R134a
# B NitrousOxide
# T5 262.15
# C 0.889172174726146
# A R134a
# B NitrousOxide
# T5 263.15
# C 0.8865767465347478
# A R134a
# B NitrousOxide
# T5 264.15
# C 0.8838605940152774
# A R134a
# B NitrousOxide
# T5 265.15
# C 0.8810221673712767
# A R134a
# B NitrousOxide
# T5 266.15
# C 0.8780598338055732
# A R134a
# B NitrousOxide
# T5 267.15
# C 0.874971871194585
# A R134a
# B NitrousOxide
# T5 268.15
# C 0.8717564610249736
# A R134a
# B NitrousOxide
# T5 269.15
# C 0.8684116804873285
# A R134a
# B NitrousOxide
# T5 270.15
# C 0.8649354936076964
# A R134a
# B NitrousOxide
# T5 271.15
# C 0.8613257412811808
# A R134a
# B NitrousOxide
# T5 272.15
# C 0.8575801300292125
# A R134a
# B NitrousOxide
# T5 273.15
# C 0.8536962193200895
# A R134a
# B NitrousOxide
# T5 274.15
# C 0.8496714071851652
# A R134a
# B NitrousOxide
# T5 275.15
# C 0.84550291383738
# A R134a
# B NitrousOxide
# T5 276.15
# C 0.8411877632297164
# A R717
# B NitrousOxide
# T5 243.15
# C 0.9164484209053575
# A R717
# B NitrousOxide
# T5 244.15
# C 0.9163281385967786
# A R717
# B NitrousOxide
# T5 245.15
# C 0.9160832195987586
# A R717
# B NitrousOxide
# T5 246.15
# C 0.9157135052996764
# A R717
# B NitrousOxide
# T5 247.15
# C 0.9152188163593166
# A R717
# B NitrousOxide
# T5 248.15
# C 0.9145989507929029
# A R717
# B NitrousOxide
# T5 249.15
# C 0.91385368198043
# A R717
# B NitrousOxide
# T5 250.15
# C 0.9129827565932823
# A R717
# B NitrousOxide
# T5 251.15
# C 0.9119858924147592
# A R717
# B NitrousOxide
# T5 252.15
# C 0.9108627760650667
# A R717
# B NitrousOxide
# T5 253.15
# C 0.909613060601549
# A R717
# B NitrousOxide
# T5 254.15
# C 0.9082363629774339
# A R717
# B NitrousOxide
# T5 255.15
# C 0.9067322613669965
# A R717
# B NitrousOxide
# T5 256.15
# C 0.9051002922997079
# A R717
# B NitrousOxide
# T5 257.15
# C 0.9033399476206609
# A R717
# B NitrousOxide
# T5 258.15
# C 0.9014506712372384
# A R717
# B NitrousOxide
# T5 259.15
# C 0.8994318556240278
# A R717
# B NitrousOxide
# T5 260.15
# C 0.8972828380579061
# A R717
# B NitrousOxide
# T5 261.15
# C 0.8950028965585235
# A R717
# B NitrousOxide
# T5 262.15
# C 0.8925912454847243
# A R717
# B NitrousOxide
# T5 263.15
# C 0.8900470308144088
# A R717
# B NitrousOxide
# T5 264.15
# C 0.8873693246230742
# A R717
# B NitrousOxide
# T5 265.15
# C 0.8845571199824956
# A R717
# B NitrousOxide
# T5 266.15
# C 0.8816093240959176
# A R717
# B NitrousOxide
# T5 267.15
# C 0.8785247517186681
# A R717
# B NitrousOxide
# T5 268.15
# C 0.8753021174758675
# A R717
# B NitrousOxide
# T5 269.15
# C 0.8719400274446567
# A R717
# B NitrousOxide
# T5 270.15
# C 0.868436969783249
# A R717
# B NitrousOxide
# T5 271.15
# C 0.8647913042920744
# A R717
# B NitrousOxide
# T5 272.15
# C 0.8610012507207475
# A R717
# B NitrousOxide
# T5 273.15
# C 0.8570648756619255
# A R717
# B NitrousOxide
# T5 274.15
# C 0.8529800777669946
# A R717
# B NitrousOxide
# T5 275.15
# C 0.848744571039153
# A R717
# B NitrousOxide
# T5 276.15
# C 0.8443558658647051
# A R290
# B NitrousOxide
# T5 243.15
# C 0.911589906479617
# A R290
# B NitrousOxide
# T5 244.15
# C 0.9111229562894579
# A R290
# B NitrousOxide
# T5 245.15
# C 0.9105562015107239
# A R290
# B NitrousOxide
# T5 246.15
# C 0.9098889966107653
# A R290
# B NitrousOxide
# T5 247.15
# C 0.909120663501894
# A R290
# B NitrousOxide
# T5 248.15
# C 0.9082504904404298
# A R290
# B NitrousOxide
# T5 249.15
# C 0.9072777308244
# A R290
# B NitrousOxide
# T5 250.15
# C 0.906201601922579
# A R290
# B NitrousOxide
# T5 251.15
# C 0.9050212834662971
# A R290
# B NitrousOxide
# T5 252.15
# C 0.9037359161362692
# A R290
# B NitrousOxide
# T5 253.15
# C 0.9023445999106189
# A R290
# B NitrousOxide
# T5 254.15
# C 0.9008463922644511
# A R290
# B NitrousOxide
# T5 255.15
# C 0.899240306204368
# A R290
# B NitrousOxide
# T5 256.15
# C 0.8975253081186854
# A R290
# B NitrousOxide
# T5 257.15
# C 0.8957003154201401
# A R290
# B NitrousOxide
# T5 258.15
# C 0.8937641939635775
# A R290
# B NitrousOxide
# T5 259.15
# C 0.8917157552033173
# A R290
# B NitrousOxide
# T5 260.15
# C 0.8895537530731817
# A R290
# B NitrousOxide
# T5 261.15
# C 0.8872768805364704
# A R290
# B NitrousOxide
# T5 262.15
# C 0.8848837657890003
# A R290
# B NitrousOxide
# T5 263.15
# C 0.8823729680530665
# A R290
# B NitrousOxide
# T5 264.15
# C 0.8797429729240024
# A R290
# B NitrousOxide
# T5 265.15
# C 0.8769921872052494
# A R290
# B NitrousOxide
# T5 266.15
# C 0.8741189331705581
# A R290
# B NitrousOxide
# T5 267.15
# C 0.8711214421716222
# A R290
# B NitrousOxide
# T5 268.15
# C 0.8679978475060689
# A R290
# B NitrousOxide
# T5 269.15
# C 0.8647461764601498
# A R290
# B NitrousOxide
# T5 270.15
# C 0.8613643413536235
# A R290
# B NitrousOxide
# T5 271.15
# C 0.8578501295244144
# A R290
# B NitrousOxide
# T5 272.15
# C 0.8542011920192089
# A R290
# B NitrousOxide
# T5 273.15
# C 0.8504150308481997
# A R290
# B NitrousOxide
# T5 274.15
# C 0.8464889845383597
# A R290
# B NitrousOxide
# T5 275.15
# C 0.8424202117363877
# A R290
# B NitrousOxide
# T5 276.15
# C 0.8382056725177496
# A R600
# B NitrousOxide
# T5 243.15
# C 0.9455424565038127
# A R600
# B NitrousOxide
# T5 244.15
# C 0.9443493660393653
# A R600
# B NitrousOxide
# T5 245.15
# C 0.9430596386046379
# A R600
# B NitrousOxide
# T5 246.15
# C 0.9416728027851624
# A R600
# B NitrousOxide
# T5 247.15
# C 0.9401883504272265
# A R600
# B NitrousOxide
# T5 248.15
# C 0.9386057356405109
# A R600
# B NitrousOxide
# T5 249.15
# C 0.9369243738148573
# A R600
# B NitrousOxide
# T5 250.15
# C 0.9351436404227955
# A R600
# B NitrousOxide
# T5 251.15
# C 0.9332628698032902
# A R600
# B NitrousOxide
# T5 252.15
# C 0.9312813538068626
# A R600
# B NitrousOxide
# T5 253.15
# C 0.9291983402494126
# A R600
# B NitrousOxide
# T5 254.15
# C 0.9270130313119461
# A R600
# B NitrousOxide
# T5 255.15
# C 0.9247245816933005
# A R600
# B NitrousOxide
# T5 256.15
# C 0.9223320966265679
# A R600
# B NitrousOxide
# T5 257.15
# C 0.9198346296794215
# A R600
# B NitrousOxide
# T5 258.15
# C 0.9172311803073535
# A R600
# B NitrousOxide
# T5 259.15
# C 0.9145206911945383
# A R600
# B NitrousOxide
# T5 260.15
# C 0.9117020452596388
# A R600
# B NitrousOxide
# T5 261.15
# C 0.9087740623754698
# A R600
# B NitrousOxide
# T5 262.15
# C 0.9057354957316798
# A R600
# B NitrousOxide
# T5 263.15
# C 0.9025850277879586
# A R600
# B NitrousOxide
# T5 264.15
# C 0.8993212657710004
# A R600
# B NitrousOxide
# T5 265.15
# C 0.8959427366779834
# A R600
# B NitrousOxide
# T5 266.15
# C 0.892447881699642
# A R600
# B NitrousOxide
# T5 267.15
# C 0.8888350499984867
# A R600
# B NitrousOxide
# T5 268.15
# C 0.8851024917432925
# A R600
# B NitrousOxide
# T5 269.15
# C 0.8812483504391494
# A R600
# B NitrousOxide
# T5 270.15
# C 0.8772707547184656
# A R600
# B NitrousOxide
# T5 271.15
# C 0.8731676678960026
# A R600
# B NitrousOxide
# T5 272.15
# C 0.8689368195395196
# A R600
# B NitrousOxide
# T5 273.15
# C 0.8645757935550937
# A R600
# B NitrousOxide
# T5 274.15
# C 0.8600820138517581
# A R600
# B NitrousOxide
# T5 275.15
# C 0.8554527280232989
# A R600
# B NitrousOxide
# T5 276.15
# C 0.85068498875186
# A R404a
# B NitrousOxide
# T5 243.15
# C 0.8868811842765153
# A R404a
# B NitrousOxide
# T5 244.15
# C 0.8870798995982944
# A R404a
# B NitrousOxide
# T5 245.15
# C 0.8871712574626895
# A R404a
# B NitrousOxide
# T5 246.15
# C 0.8871544588503505
# A R404a
# B NitrousOxide
# T5 247.15
# C 0.8870286785746525
# A R404a
# B NitrousOxide
# T5 248.15
# C 0.8867930641771742
# A R404a
# B NitrousOxide
# T5 249.15
# C 0.8864467347381855
# A R404a
# B NitrousOxide
# T5 250.15
# C 0.8859887795823213
# A R404a
# B NitrousOxide
# T5 251.15
# C 0.8854182568741413
# A R404a
# B NitrousOxide
# T5 252.15
# C 0.884734192089606
# A R404a
# B NitrousOxide
# T5 253.15
# C 0.8839355763497039
# A R404a
# B NitrousOxide
# T5 254.15
# C 0.8830213646012864
# A R404a
# B NitrousOxide
# T5 255.15
# C 0.881990473628221
# A R404a
# B NitrousOxide
# T5 256.15
# C 0.8808417798738406
# A R404a
# B NitrousOxide
# T5 257.15
# C 0.8795741170543177
# A R404a
# B NitrousOxide
# T5 258.15
# C 0.878186273535579
# A R404a
# B NitrousOxide
# T5 259.15
# C 0.8766769894587125
# A R404a
# B NitrousOxide
# T5 260.15
# C 0.8750449535622423
# A R404a
# B NitrousOxide
# T5 261.15
# C 0.87328879969152
# A R404a
# B NitrousOxide
# T5 262.15
# C 0.8714071029397584
# A R404a
# B NitrousOxide
# T5 263.15
# C 0.8693983753833532
# A R404a
# B NitrousOxide
# T5 264.15
# C 0.8672610613597621
# A R404a
# B NitrousOxide
# T5 265.15
# C 0.8649935322305162
# A R404a
# B NitrousOxide
# T5 266.15
# C 0.8625940805631692
# A R404a
# B NitrousOxide
# T5 267.15
# C 0.8600609136551725
# A R404a
# B NitrousOxide
# T5 268.15
# C 0.8573921463130989
# A R404a
# B NitrousOxide
# T5 269.15
# C 0.8545857927818905
# A R404a
# B NitrousOxide
# T5 270.15
# C 0.8516397577071314
# A R404a
# B NitrousOxide
# T5 271.15
# C 0.8485518259919697
# A R404a
# B NitrousOxide
# T5 272.15
# C 0.8453196513708865
# A R404a
# B NitrousOxide
# T5 273.15
# C 0.8419407435376975
# A R404a
# B NitrousOxide
# T5 274.15
# C 0.8384117381237874
# A R404a
# B NitrousOxide
# T5 275.15
# C 0.8347306728383872
# A R404a
# B NitrousOxide
# T5 276.15
# C 0.8308949973383234
