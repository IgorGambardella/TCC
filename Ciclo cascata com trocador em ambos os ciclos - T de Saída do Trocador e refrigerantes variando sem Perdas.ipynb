# %%
from CoolProp.CoolProp import PropsSI as COOLPROP
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import get_test_data

#Listas
registro_fluidos = []
COP_lista = []
lista_T4 = []
Wcomp_total_lista = []
cont = []

#Lista de Temperaturas
for T4 in range (-3000 + 27315, 400 + 27315, 100):
    T4 = T4 / 100
    cont.append(T4)
    
#Lista de características para as curvas do gráfico
lista_cor = ['r','g','b', 'c', 'm']
lista_ls = ['-', '-.', ':']
caracteristicas = []
for ls in lista_ls:
    for cor in lista_cor:
        caracteristicas.append((cor, ls))

#Dados do problema
Pfrig = 120 * 1000 #[W]
T1 = -80 + 273.15 #[K]
T10 = 28 + 273.15 #[K]
N = 0.7 #Eficiência isentrópica
fluid_high_lista = ['R134a', 'R717', 'R290', 'R600', 'R404a']
fluid_low_lista = ['R23', 'R170', 'NitrousOxide']
drop_suc = 0 #[Pa]
drop_desc = 0 #[Pa]
efet = 0.7 #efetividade do trocador intermediário
DeltaT = 0 #[°C]

#variação dos refrigerantes e do coeficiente politrópico
for fluid_low in fluid_low_lista:
    for fluid_high in fluid_high_lista:
        if fluid_low == 'NitrousOxide':
            par_fluido = ('Óxido nitroso', fluid_high)    
        else:
            par_fluido = (fluid_low, fluid_high)
        registro_fluidos.append(par_fluido)
        #Pressão crítica do fluido ciclo de alta pressão
        P_crit_high = COOLPROP('PCRIT', fluid_high)
        for T4 in cont:
            #Ciclo de baixa pressão
            cp1 = COOLPROP('CP0MASS', 'T', T1, 'Q', 1, fluid_low)
            cp4 = COOLPROP('CP0MASS', 'T', T4, 'Q', 0, fluid_low)
            P1 = COOLPROP('P', 'T', T1, 'Q', 1, fluid_low)
            P4 = COOLPROP('P', 'T', T4, 'Q', 0, fluid_low)
            h1 = COOLPROP('H', 'T', T1, 'Q', 1, fluid_low)
            h4 = COOLPROP('H', 'T', T4, 'Q', 0, fluid_low)
            P5 = P4
            P2 = P1
            
            #Comparação entre os calores específicos nos pontos 4 e 1
            if cp1 < cp4:
                
                T2 = efet * (T4 - T1) + T1
                h2 = COOLPROP('H', 'T', T2, 'P', P2, fluid_low)
                hw = h2
                Pw = P2 - drop_suc
                Tw = COOLPROP('T', 'H', hw, 'P', Pw, fluid_low)
                Px = Pw
                Tx = Tw + DeltaT
                hx = COOLPROP('H', 'P', Px, 'T', Tx, fluid_low)
                sx = COOLPROP('S', 'P', Px, 'T', Tx, fluid_low)
            
                P3 = P4
                Py = P3 + drop_desc
                sy_ideal = sx
                hy_ideal = COOLPROP('H', 'P', Py, 'S', sy_ideal, fluid_low)
                hy_real = (hy_ideal - hx)/N + hx
                h3 = hy_real
            
                h5 = h4 + h1 - h2
                T5 = COOLPROP('T', 'H', h5, 'P', P5, fluid_low)
                h6 = h5
                
            else:
                T5 = T4 - efet * (T4 - T1)
                h5 = COOLPROP('H', 'T', T5, 'P', P5, fluid_low)
                h2 = h4 + h1 - h5
                T2 = COOLPROP('T', 'H', h2, 'P', P2, fluid_low)
                
                hw = h2
                Pw = P2 - drop_suc
                Tw = COOLPROP('T', 'H', hw, 'P', Pw, fluid_low)
                Px = Pw
                Tx = Tw + DeltaT
                hx = COOLPROP('H', 'P', Px, 'T', Tx, fluid_low)
                sx = COOLPROP('S', 'P', Px, 'T', Tx, fluid_low)
                P3 = P4
                Py = P3 + drop_desc
                sy_ideal = sx
                hy_ideal = COOLPROP('H', 'P', Py, 'S', sy_ideal, fluid_low)
                hy_real = (hy_ideal - hx)/N + hx
                h3 = hy_real
            
                h6 = h5
                
            m_flow_low = Pfrig / (h1 - h6)
            w_low = hy_real - hx
            Wcomp_low = m_flow_low * w_low
            
            
            #Pressão crítica do fluido do ciclo de alta pressão
            P_crit_high = COOLPROP('PCRIT', fluid_high)
            h10 = COOLPROP('H', 'T', T10, 'Q', 0, fluid_high)
            P10 = COOLPROP('P', 'T', T10, 'Q', 0, fluid_high)

            T12 = T4 - 5
            #Q<>0, mas como o refrigerante se encontra em uma fase saturada a pressão é a mesma para qualquer Q com T=T10
            P12 = COOLPROP('P', 'Q', 0, 'T', T12, fluid_high) 
            P7 = P12
            T7 = COOLPROP('T', 'P', P7, 'Q', 1, fluid_high)
            P10 = COOLPROP('P', 'T', T10, 'Q', 0, fluid_high)
            cp7 = COOLPROP('CP0MASS', 'T', T7, 'Q', 1, fluid_high)
            cp10 = COOLPROP('CP0MASS', 'T', T10, 'Q', 0, fluid_high)
            h7 = COOLPROP('H', 'T', T7, 'Q', 1, fluid_high)
            h10 = COOLPROP('H', 'T', T10, 'Q', 0, fluid_high)
            P8 = P7
            P11 = P10
            
##############################################################################################

        #Comparação entre os calores específicos nos pontos 10 e 7
            if cp7 < cp10:
                T8 = efet * (T10 - T7) + T7
                h8 = COOLPROP('H', 'T', T8, 'P', P8, fluid_high)
                ha = h8
                Pa = P8 - drop_suc
                Ta = COOLPROP('T', 'H', ha, 'P', Pa, fluid_high)
                Pb = Pa
                Tb = Ta + DeltaT
                hb = COOLPROP('H', 'P', Pb, 'T', Tb, fluid_high)
                sb = COOLPROP('S', 'P', Pb, 'T', Tb, fluid_high)
            
                P9 = P10
                Pc = P9 + drop_desc
                sc_ideal = sb
                hc_ideal = COOLPROP('H', 'P', Pc, 'S', sc_ideal, fluid_high)
                hc_real = (hc_ideal - hb)/N + hb
                h9 = hc_real
            
                h11 = h10 + h7 - h8
                T11 = COOLPROP('T', 'H', h11, 'P', P11, fluid_high)
                h12 = h11
            else:
                T11 = T10 - efet * (T10 - T7)
                h11 = COOLPROP('H', 'T', T11, 'P', P11, fluid_high)
                h8 = h10 + h7 - h11
                T8 = COOLPROP('T', 'H', h8, 'P', P8, fluid_high)
                ha = h8
                Pa = P8 - drop_suc
                Ta = COOLPROP('T', 'H', ha, 'P', Pa, fluid_high)
                Pb = Pa
                Tb = Ta + DeltaT
                hb = COOLPROP('H', 'P', Pb, 'T', Tb, fluid_high)
                sb = COOLPROP('S', 'P', Pb, 'T', Tb, fluid_high)
            
                P9 = P10
                Py = P9 + drop_desc
                sc_ideal = sb
                hc_ideal = COOLPROP('H', 'P', Pc, 'S', sc_ideal, fluid_high)
                hc_real = (hc_ideal - hb)/N + hb
                h7 = hc_real
            
                h12 = h11
            
            #Registro dos graus de subresfriamento e superaquecimento
            grau_subresf = T10 - T11
            grau_superaq = T8 - T7
            #print('O grau de subresfriamento ({}, {}) é igual a {:0.2f}°C.'.format(fluid_low,fluid_high,grau_subresf))
            #print('O grau de superaquecimento ({}, {}) é igual a {:0.2f}°C.'.format(fluid_low,fluid_high,grau_superaq))

            #Calor trocado no trocador central
            Qcond_low =  m_flow_low * (h3 - h4)
            #Ciclo de alta pressão
            Qevap_high = Qcond_low
            m_flow_high = Qevap_high / (h7 - h12)
            #Verificação da pressão crítica
            if P_crit_high > P9:
                lista_T4.append(T4)
                #Trabalho específico do compressor do ciclo de alta pressão
                w_high = hc_real - hb
                #Trabalho no compressor do ciclo de alta pressão
                Wcomp_high = m_flow_high * w_high
                #Trabalho total do ciclo
                Wcomp_total = Wcomp_low + Wcomp_high
                Wcomp_total_lista.append(Wcomp_total / 1000)
                #COP
                COP = Pfrig / Wcomp_total
                COP_lista.append(COP)
                print("A", fluid_high)
                print("B", fluid_low)
                print("T4", T4)
                print("C", COP)

            else:
                print ('A pressão P9 = {:0.2f} kPa (T4 = {}, fluido inf = {}, fluido sup = {}) é maior do que a ' 
               'pressão crítica do {} logo o ponto não foi incluído no gráfico'.format(P9 / 1000,T4,fluid_low,
                                                                                               fluid_high, fluid_high))
COP_lista_max = []
for T4 in range (0, len(COP_lista), len(cont)):
    COP_lista_max.append(COP_lista[T4])

COP_lista_min = []
for T4 in range (len(cont)-1, len(COP_lista), len(cont)):
    COP_lista_min.append(COP_lista[T4])

if len(lista_T4) != 0:
    plt.rc('xtick', labelsize = 13)
    plt.rc('ytick', labelsize = 13)
    plt.figure(figsize = [13, 13], dpi = 300)
    for i in range (0, len(COP_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T4[j])
            eixo_y.append(COP_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1], 
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T4', size = 13)
        plt.ylabel('COP', size = 13)
    plt.legend(prop={'size' : 13})
    plt.show()
else:
    print('Todos os pontos são inválidos')
# Out:
# A R134a
# B R23
# T4 243.15
# C 0.7954746889298592
# A R134a
# B R23
# T4 244.15
# C 0.7941144574602562
# A R134a
# B R23
# T4 245.15
# C 0.7926283646642995
# A R134a
# B R23
# T4 246.15
# C 0.7910165817803757
# A R134a
# B R23
# T4 247.15
# C 0.7892792560763273
# A R134a
# B R23
# T4 248.15
# C 0.7874165085011187
# A R134a
# B R23
# T4 249.15
# C 0.7854284311547759
# A R134a
# B R23
# T4 250.15
# C 0.7833150845497305
# A R134a
# B R23
# T4 251.15
# C 0.7810764946415691
# A R134a
# B R23
# T4 252.15
# C 0.778712649593588
# A R134a
# B R23
# T4 253.15
# C 0.7762234962394114
# A R134a
# B R23
# T4 254.15
# C 0.7736089362080532
# A R134a
# B R23
# T4 255.15
# C 0.7708688216620823
# A R134a
# B R23
# T4 256.15
# C 0.7680029505982856
# A R134a
# B R23
# T4 257.15
# C 0.765011061651263
# A R134a
# B R23
# T4 258.15
# C 0.7618928283368
# A R134a
# B R23
# T4 259.15
# C 0.7586478526104247
# A R134a
# B R23
# T4 260.15
# C 0.7552756577729122
# A R134a
# B R23
# T4 261.15
# C 0.7517756804332664
# A R134a
# B R23
# T4 262.15
# C 0.7481472615484792
# A R134a
# B R23
# T4 263.15
# C 0.7443896363291331
# A R134a
# B R23
# T4 264.15
# C 0.7405019228407572
# A R134a
# B R23
# T4 265.15
# C 0.7364831090950131
# A R134a
# B R23
# T4 266.15
# C 0.7323320383747588
# A R134a
# B R23
# T4 267.15
# C 0.7280473924932718
# A R134a
# B R23
# T4 268.15
# C 0.7236276726213937
# A R134a
# B R23
# T4 269.15
# C 0.7190711772383244
# A R134a
# B R23
# T4 270.15
# C 0.7143759766558331
# A R134a
# B R23
# T4 271.15
# C 0.7095398834985562
# A R134a
# B R23
# T4 272.15
# C 0.7045604181718156
# A R134a
# B R23
# T4 273.15
# C 0.6994347684907517
# A R134a
# B R23
# T4 274.15
# C 0.694159741990818
# A R134a
# B R23
# T4 275.15
# C 0.688731709332235
# A R134a
# B R23
# T4 276.15
# C 0.6831465367320939
# A R717
# B R23
# T4 243.15
# C 0.7517501215917536
# A R717
# B R23
# T4 244.15
# C 0.7521990158229019
# A R717
# B R23
# T4 245.15
# C 0.7524836285824996
# A R717
# B R23
# T4 246.15
# C 0.7526035651520656
# A R717
# B R23
# T4 247.15
# C 0.7525584676232662
# A R717
# B R23
# T4 248.15
# C 0.7523480114431961
# A R717
# B R23
# T4 249.15
# C 0.7519719017310634
# A R717
# B R23
# T4 250.15
# C 0.75142986934704
# A R717
# B R23
# T4 251.15
# C 0.750721666679604
# A R717
# B R23
# T4 252.15
# C 0.7498470631444584
# A R717
# B R23
# T4 253.15
# C 0.7488058403490101
# A R717
# B R23
# T4 254.15
# C 0.7475977868867376
# A R717
# B R23
# T4 255.15
# C 0.7462226927358573
# A R717
# B R23
# T4 256.15
# C 0.7446803431900074
# A R717
# B R23
# T4 257.15
# C 0.7429705122852758
# A R717
# B R23
# T4 258.15
# C 0.7410929556517671
# A R717
# B R23
# T4 259.15
# C 0.739047402708233
# A R717
# B R23
# T4 260.15
# C 0.7368335481108965
# A R717
# B R23
# T4 261.15
# C 0.734451042359483
# A R717
# B R23
# T4 262.15
# C 0.7318994814246358
# A R717
# B R23
# T4 263.15
# C 0.7291783952589472
# A R717
# B R23
# T4 264.15
# C 0.726287235008192
# A R717
# B R23
# T4 265.15
# C 0.7232253587131866
# A R717
# B R23
# T4 266.15
# C 0.7199920152702359
# A R717
# B R23
# T4 267.15
# C 0.7165863263209495
# A R717
# B R23
# T4 268.15
# C 0.7130072657302301
# A R717
# B R23
# T4 269.15
# C 0.7092536362017223
# A R717
# B R23
# T4 270.15
# C 0.7053240424772569
# A R717
# B R23
# T4 271.15
# C 0.7012168605116558
# A R717
# B R23
# T4 272.15
# C 0.6969302016519118
# A R717
# B R23
# T4 273.15
# C 0.6924618709929735
# A R717
# B R23
# T4 274.15
# C 0.6878093184359806
# A R717
# B R23
# T4 275.15
# C 0.682969580873891
# A R717
# B R23
# T4 276.15
# C 0.6779392133634295
# A R290
# B R23
# T4 243.15
# C 0.7947333561499608
# A R290
# B R23
# T4 244.15
# C 0.7932325311365575
# A R290
# B R23
# T4 245.15
# C 0.7916136224167085
# A R290
# B R23
# T4 246.15
# C 0.7898767189968523
# A R290
# B R23
# T4 247.15
# C 0.7880218798206483
# A R290
# B R23
# T4 248.15
# C 0.7860491316558789
# A R290
# B R23
# T4 249.15
# C 0.7839584667983638
# A R290
# B R23
# T4 250.15
# C 0.7817498405655368
# A R290
# B R23
# T4 251.15
# C 0.7794231685527347
# A R290
# B R23
# T4 252.15
# C 0.7769783236224708
# A R290
# B R23
# T4 253.15
# C 0.7744151325878599
# A R290
# B R23
# T4 254.15
# C 0.7717333725534335
# A R290
# B R23
# T4 255.15
# C 0.7689327668665713
# A R290
# B R23
# T4 256.15
# C 0.766012980627842
# A R290
# B R23
# T4 257.15
# C 0.7629736156981789
# A R290
# B R23
# T4 258.15
# C 0.7598142051385189
# A R290
# B R23
# T4 259.15
# C 0.7565342069953462
# A R290
# B R23
# T4 260.15
# C 0.7531329973491375
# A R290
# B R23
# T4 261.15
# C 0.7496098625019656
# A R290
# B R23
# T4 262.15
# C 0.7459639901948144
# A R290
# B R23
# T4 263.15
# C 0.7421944596896977
# A R290
# B R23
# T4 264.15
# C 0.7383002305488647
# A R290
# B R23
# T4 265.15
# C 0.7342801298949349
# A R290
# B R23
# T4 266.15
# C 0.7301328379038275
# A R290
# B R23
# T4 267.15
# C 0.7258568712233753
# A R290
# B R23
# T4 268.15
# C 0.7214505639580427
# A R290
# B R23
# T4 269.15
# C 0.7169120457705687
# A R290
# B R23
# T4 270.15
# C 0.7122392165520314
# A R290
# B R23
# T4 271.15
# C 0.7074297170436625
# A R290
# B R23
# T4 272.15
# C 0.7024808944410948
# A R290
# B R23
# T4 273.15
# C 0.6973897621524083
# A R290
# B R23
# T4 274.15
# C 0.6921529522354662
# A R290
# B R23
# T4 275.15
# C 0.6867666589365505
# A R290
# B R23
# T4 276.15
# C 0.6812265711877793
# A R600
# B R23
# T4 243.15
# C 0.8236096507185552
# A R600
# B R23
# T4 244.15
# C 0.8214595042468785
# A R600
# B R23
# T4 245.15
# C 0.819190735894678
# A R600
# B R23
# T4 246.15
# C 0.816803842224394
# A R600
# B R23
# T4 247.15
# C 0.8142992850311311
# A R600
# B R23
# T4 248.15
# C 0.8116774890704282
# A R600
# B R23
# T4 249.15
# C 0.8089388397010803
# A R600
# B R23
# T4 250.15
# C 0.8060836802162417
# A R600
# B R23
# T4 251.15
# C 0.803112309025402
# A R600
# B R23
# T4 252.15
# C 0.8000249765559164
# A R600
# B R23
# T4 253.15
# C 0.796821881804157
# A R600
# B R23
# T4 254.15
# C 0.7935031686340206
# A R600
# B R23
# T4 255.15
# C 0.7900689216171223
# A R600
# B R23
# T4 256.15
# C 0.7865191614797696
# A R600
# B R23
# T4 257.15
# C 0.7828538400435336
# A R600
# B R23
# T4 258.15
# C 0.7790728345834237
# A R600
# B R23
# T4 259.15
# C 0.7751759415788193
# A R600
# B R23
# T4 260.15
# C 0.7711628696806375
# A R600
# B R23
# T4 261.15
# C 0.7670332318611522
# A R600
# B R23
# T4 262.15
# C 0.7627865365884147
# A R600
# B R23
# T4 263.15
# C 0.758422177869473
# A R600
# B R23
# T4 264.15
# C 0.7539394239870684
# A R600
# B R23
# T4 265.15
# C 0.7493374047365735
# A R600
# B R23
# T4 266.15
# C 0.7446150968927783
# A R600
# B R23
# T4 267.15
# C 0.739771307613765
# A R600
# B R23
# T4 268.15
# C 0.7348046554070595
# A R600
# B R23
# T4 269.15
# C 0.7297135482249573
# A R600
# B R23
# T4 270.15
# C 0.7244961581331031
# A R600
# B R23
# T4 271.15
# C 0.7191503919184392
# A R600
# B R23
# T4 272.15
# C 0.7136738567465377
# A R600
# B R23
# T4 273.15
# C 0.7080638198629035
# A R600
# B R23
# T4 274.15
# C 0.7023171610887123
# A R600
# B R23
# T4 275.15
# C 0.6964303163575598
# A R600
# B R23
# T4 276.15
# C 0.6903992102413412
# A R404a
# B R23
# T4 243.15
# C 0.7707238054543408
# A R404a
# B R23
# T4 244.15
# C 0.7698171097306865
# A R404a
# B R23
# T4 245.15
# C 0.76878949899758
# A R404a
# B R23
# T4 246.15
# C 0.7676407802456677
# A R404a
# B R23
# T4 247.15
# C 0.7663707373719364
# A R404a
# B R23
# T4 248.15
# C 0.7649791290554013
# A R404a
# B R23
# T4 249.15
# C 0.7634656864380374
# A R404a
# B R23
# T4 250.15
# C 0.7618301105849604
# A R404a
# B R23
# T4 251.15
# C 0.7600720696978338
# A R404a
# B R23
# T4 252.15
# C 0.7581911960497454
# A R404a
# B R23
# T4 253.15
# C 0.7561870826065112
# A R404a
# B R23
# T4 254.15
# C 0.7540592792957089
# A R404a
# B R23
# T4 255.15
# C 0.7518072888767687
# A R404a
# B R23
# T4 256.15
# C 0.7494305623612754
# A R404a
# B R23
# T4 257.15
# C 0.7469284939236277
# A R404a
# B R23
# T4 258.15
# C 0.7443004152327385
# A R404a
# B R23
# T4 259.15
# C 0.7415455891261022
# A R404a
# B R23
# T4 260.15
# C 0.7386632025283024
# A R404a
# B R23
# T4 261.15
# C 0.7356523585294079
# A R404a
# B R23
# T4 262.15
# C 0.7325120674401538
# A R404a
# B R23
# T4 263.15
# C 0.729241236746464
# A R404a
# B R23
# T4 264.15
# C 0.72583865973297
# A R404a
# B R23
# T4 265.15
# C 0.7223030025858298
# A R404a
# B R23
# T4 266.15
# C 0.718632789719094
# A R404a
# B R23
# T4 267.15
# C 0.7148263870222623
# A R404a
# B R23
# T4 268.15
# C 0.7108819826635354
# A R404a
# B R23
# T4 269.15
# C 0.7067975650040949
# A R404a
# B R23
# T4 270.15
# C 0.7025708970734293
# A R404a
# B R23
# T4 271.15
# C 0.6981994869858819
# A R404a
# B R23
# T4 272.15
# C 0.6936805533345349
# A R404a
# B R23
# T4 273.15
# C 0.6890109847283898
# A R404a
# B R23
# T4 274.15
# C 0.6841872920002399
# A R404a
# B R23
# T4 275.15
# C 0.679205551505944
# A R404a
# B R23
# T4 276.15
# C 0.6740613373792036
# A R134a
# B R170
# T4 243.15
# C 0.8115621613323097
# A R134a
# B R170
# T4 244.15
# C 0.8107444771308966
# A R134a
# B R170
# T4 245.15
# C 0.809805313138653
# A R134a
# B R170
# T4 246.15
# C 0.8087447057987978
# A R134a
# B R170
# T4 247.15
# C 0.8075626792065986
# A R134a
# B R170
# T4 248.15
# C 0.8062592433586426
# A R134a
# B R170
# T4 249.15
# C 0.8048343922912642
# A R134a
# B R170
# T4 250.15
# C 0.8032881021249422
# A R134a
# B R170
# T4 251.15
# C 0.8016203289951737
# A R134a
# B R170
# T4 252.15
# C 0.7998310068528776
# A R134a
# B R170
# T4 253.15
# C 0.797920045116684
# A R134a
# B R170
# T4 254.15
# C 0.7958873261605235
# A R134a
# B R170
# T4 255.15
# C 0.7937327026011631
# A R134a
# B R170
# T4 256.15
# C 0.7914559944264631
# A R134a
# B R170
# T4 257.15
# C 0.789056985745048
# A R134a
# B R170
# T4 258.15
# C 0.7865354214127708
# A R134a
# B R170
# T4 259.15
# C 0.7838910032019141
# A R134a
# B R170
# T4 260.15
# C 0.7811233857118102
# A R134a
# B R170
# T4 261.15
# C 0.7782321717555261
# A R134a
# B R170
# T4 262.15
# C 0.7752169073177461
# A R134a
# B R170
# T4 263.15
# C 0.7720770759537214
# A R134a
# B R170
# T4 264.15
# C 0.7688120925653826
# A R134a
# B R170
# T4 265.15
# C 0.765421296506648
# A R134a
# B R170
# T4 266.15
# C 0.7619039437822073
# A R134a
# B R170
# T4 267.15
# C 0.7582591985455001
# A R134a
# B R170
# T4 268.15
# C 0.7544861234235506
# A R134a
# B R170
# T4 269.15
# C 0.7505836687657874
# A R134a
# B R170
# T4 270.15
# C 0.7465506605670555
# A R134a
# B R170
# T4 271.15
# C 0.7423857868771954
# A R134a
# B R170
# T4 272.15
# C 0.7380875824465903
# A R134a
# B R170
# T4 273.15
# C 0.7336544113009887
# A R134a
# B R170
# T4 274.15
# C 0.7290844468548857
# A R134a
# B R170
# T4 275.15
# C 0.724375649067673
# A R134a
# B R170
# T4 276.15
# C 0.7195257381127402
# A R717
# B R170
# T4 243.15
# C 0.7665757799307572
# A R717
# B R170
# T4 244.15
# C 0.7675757207059563
# A R717
# B R170
# T4 245.15
# C 0.7684176886576477
# A R717
# B R170
# T4 246.15
# C 0.7691010919523893
# A R717
# B R170
# T4 247.15
# C 0.7696253832453432
# A R717
# B R170
# T4 248.15
# C 0.7699900571511513
# A R717
# B R170
# T4 249.15
# C 0.7701946475521628
# A R717
# B R170
# T4 250.15
# C 0.7702387247660434
# A R717
# B R170
# T4 251.15
# C 0.7701218925416413
# A R717
# B R170
# T4 252.15
# C 0.7698437848953296
# A R717
# B R170
# T4 253.15
# C 0.7694040627593303
# A R717
# B R170
# T4 254.15
# C 0.7688024104252126
# A R717
# B R170
# T4 255.15
# C 0.7680385317721369
# A R717
# B R170
# T4 256.15
# C 0.7671121462949724
# A R717
# B R170
# T4 257.15
# C 0.7660229847465223
# A R717
# B R170
# T4 258.15
# C 0.7647707846268699
# A R717
# B R170
# T4 259.15
# C 0.7633552852424643
# A R717
# B R170
# T4 260.15
# C 0.7617762224017867
# A R717
# B R170
# T4 261.15
# C 0.7600333226846313
# A R717
# B R170
# T4 262.15
# C 0.758126297217645
# A R717
# B R170
# T4 263.15
# C 0.7560548349022721
# A R717
# B R170
# T4 264.15
# C 0.7538185950169071
# A R717
# B R170
# T4 265.15
# C 0.7514171991403238
# A R717
# B R170
# T4 266.15
# C 0.7488502221892679
# A R717
# B R170
# T4 267.15
# C 0.746117182736237
# A R717
# B R170
# T4 268.15
# C 0.7432175321709483
# A R717
# B R170
# T4 269.15
# C 0.7401506427892577
# A R717
# B R170
# T4 270.15
# C 0.7369157945585572
# A R717
# B R170
# T4 271.15
# C 0.7335121603820884
# A R717
# B R170
# T4 272.15
# C 0.7299387896068186
# A R717
# B R170
# T4 273.15
# C 0.7261945894711072
# A R717
# B R170
# T4 274.15
# C 0.7222783041049614
# A R717
# B R170
# T4 275.15
# C 0.7181884906027051
# A R717
# B R170
# T4 276.15
# C 0.7139234915584531
# A R290
# B R170
# T4 243.15
# C 0.8107990657210432
# A R290
# B R170
# T4 244.15
# C 0.8098357452712727
# A R290
# B R170
# T4 245.15
# C 0.8087586594180868
# A R290
# B R170
# T4 246.15
# C 0.807567777761212
# A R290
# B R170
# T4 247.15
# C 0.806263051457746
# A R290
# B R170
# T4 248.15
# C 0.804844411664964
# A R290
# B R170
# T4 249.15
# C 0.8033117678729875
# A R290
# B R170
# T4 250.15
# C 0.8016650061434989
# A R290
# B R170
# T4 251.15
# C 0.7999039872298294
# A R290
# B R170
# T4 252.15
# C 0.7980285445674622
# A R290
# B R170
# T4 253.15
# C 0.7960384821140466
# A R290
# B R170
# T4 254.15
# C 0.7939335720210664
# A R290
# B R170
# T4 255.15
# C 0.7917135521044496
# A R290
# B R170
# T4 256.15
# C 0.7893781231534596
# A R290
# B R170
# T4 257.15
# C 0.786926945856572
# A R290
# B R170
# T4 258.15
# C 0.784359637597352
# A R290
# B R170
# T4 259.15
# C 0.7816757688269746
# A R290
# B R170
# T4 260.15
# C 0.778874859091502
# A R290
# B R170
# T4 261.15
# C 0.7759563726220285
# A R290
# B R170
# T4 262.15
# C 0.7729197134481286
# A R290
# B R170
# T4 263.15
# C 0.769764219952526
# A R290
# B R170
# T4 264.15
# C 0.7664891588055389
# A R290
# B R170
# T4 265.15
# C 0.7630937182203753
# A R290
# B R170
# T4 266.15
# C 0.7595770003022655
# A R290
# B R170
# T4 267.15
# C 0.7559380126878703
# A R290
# B R170
# T4 268.15
# C 0.752175659010994
# A R290
# B R170
# T4 269.15
# C 0.7482887282852847
# A R290
# B R170
# T4 270.15
# C 0.744275882956025
# A R290
# B R170
# T4 271.15
# C 0.7401356454339619
# A R290
# B R170
# T4 272.15
# C 0.735866382858856
# A R290
# B R170
# T4 273.15
# C 0.731466289784042
# A R290
# B R170
# T4 274.15
# C 0.7269333683959341
# A R290
# B R170
# T4 275.15
# C 0.7222654057827274
# A R290
# B R170
# T4 276.15
# C 0.7174599476400111
# A R600
# B R170
# T4 243.15
# C 0.8405324858216391
# A R600
# B R170
# T4 244.15
# C 0.8389299438957724
# A R600
# B R170
# T4 245.15
# C 0.8372121508054077
# A R600
# B R170
# T4 246.15
# C 0.8353794726902313
# A R600
# B R170
# T4 247.15
# C 0.8334322544063948
# A R600
# B R170
# T4 248.15
# C 0.8313708177755073
# A R600
# B R170
# T4 249.15
# C 0.8291954598242458
# A R600
# B R170
# T4 250.15
# C 0.8269064508262294
# A R600
# B R170
# T4 251.15
# C 0.8245040323169669
# A R600
# B R170
# T4 252.15
# C 0.8219884149661069
# A R600
# B R170
# T4 253.15
# C 0.8193597762535368
# A R600
# B R170
# T4 254.15
# C 0.8166182580711898
# A R600
# B R170
# T4 255.15
# C 0.813763964052305
# A R600
# B R170
# T4 256.15
# C 0.810796956791462
# A R600
# B R170
# T4 257.15
# C 0.8077172546732206
# A R600
# B R170
# T4 258.15
# C 0.8045248285615754
# A R600
# B R170
# T4 259.15
# C 0.8012195981112086
# A R600
# B R170
# T4 260.15
# C 0.797801427685455
# A R600
# B R170
# T4 261.15
# C 0.7942701218823522
# A R600
# B R170
# T4 262.15
# C 0.7906254205784462
# A R600
# B R170
# T4 263.15
# C 0.786866993417848
# A R600
# B R170
# T4 264.15
# C 0.7829944336773179
# A R600
# B R170
# T4 265.15
# C 0.7790072514737609
# A R600
# B R170
# T4 266.15
# C 0.7749048660598762
# A R600
# B R170
# T4 267.15
# C 0.7706865974294117
# A R600
# B R170
# T4 268.15
# C 0.7663516567417011
# A R600
# B R170
# T4 269.15
# C 0.7618991356810793
# A R600
# B R170
# T4 270.15
# C 0.7573279944936833
# A R600
# B R170
# T4 271.15
# C 0.7526370484959206
# A R600
# B R170
# T4 272.15
# C 0.7478249528909987
# A R600
# B R170
# T4 273.15
# C 0.7428901853914451
# A R600
# B R170
# T4 274.15
# C 0.7378310265064716
# A R600
# B R170
# T4 275.15
# C 0.7326455368199984
# A R600
# B R170
# T4 276.15
# C 0.7273315307452772
# A R404a
# B R170
# T4 243.15
# C 0.7860915701652502
# A R404a
# B R170
# T4 244.15
# C 0.7857154691536092
# A R404a
# B R170
# T4 245.15
# C 0.7852235486136563
# A R404a
# B R170
# T4 246.15
# C 0.7846155002594257
# A R404a
# B R170
# T4 247.15
# C 0.783891002916226
# A R404a
# B R170
# T4 248.15
# C 0.7830497209964626
# A R404a
# B R170
# T4 249.15
# C 0.7820913028529651
# A R404a
# B R170
# T4 250.15
# C 0.7810153790260542
# A R404a
# B R170
# T4 251.15
# C 0.7798215603610718
# A R404a
# B R170
# T4 252.15
# C 0.7785094359831756
# A R404a
# B R170
# T4 253.15
# C 0.7770785711123973
# A R404a
# B R170
# T4 254.15
# C 0.7755285046991781
# A R404a
# B R170
# T4 255.15
# C 0.7738587468480626
# A R404a
# B R170
# T4 256.15
# C 0.7720687760677393
# A R404a
# B R170
# T4 257.15
# C 0.7701580361346201
# A R404a
# B R170
# T4 258.15
# C 0.7681259328086854
# A R404a
# B R170
# T4 259.15
# C 0.7659718301245616
# A R404a
# B R170
# T4 260.15
# C 0.7636950463166464
# A R404a
# B R170
# T4 261.15
# C 0.7612948493282541
# A R404a
# B R170
# T4 262.15
# C 0.7587704517879769
# A R404a
# B R170
# T4 263.15
# C 0.7561210054627634
# A R404a
# B R170
# T4 264.15
# C 0.7533455950604179
# A R404a
# B R170
# T4 265.15
# C 0.7504432313493927
# A R404a
# B R170
# T4 266.15
# C 0.7474128433638629
# A R404a
# B R170
# T4 267.15
# C 0.7442532698877612
# A R404a
# B R170
# T4 268.15
# C 0.7409632497556098
# A R404a
# B R170
# T4 269.15
# C 0.7375414110593898
# A R404a
# B R170
# T4 270.15
# C 0.7339862590133985
# A R404a
# B R170
# T4 271.15
# C 0.730296162286956
# A R404a
# B R170
# T4 272.15
# C 0.726469337555187
# A R404a
# B R170
# T4 273.15
# C 0.7225038319573082
# A R404a
# B R170
# T4 274.15
# C 0.7183975030744271
# A R404a
# B R170
# T4 275.15
# C 0.7141479959408653
# A R404a
# B R170
# T4 276.15
# C 0.7097527164827556
# A R134a
# B NitrousOxide
# T4 243.15
# C 0.7820050345374626
# A R134a
# B NitrousOxide
# T4 244.15
# C 0.78033653440656
# A R134a
# B NitrousOxide
# T4 245.15
# C 0.7785545838093652
# A R134a
# B NitrousOxide
# T4 246.15
# C 0.7766603608522245
# A R134a
# B NitrousOxide
# T4 247.15
# C 0.774655032851761
# A R134a
# B NitrousOxide
# T4 248.15
# C 0.7725397545348663
# A R134a
# B NitrousOxide
# T4 249.15
# C 0.7703156662156864
# A R134a
# B NitrousOxide
# T4 250.15
# C 0.7679838919421235
# A R134a
# B NitrousOxide
# T4 251.15
# C 0.7655455376073478
# A R134a
# B NitrousOxide
# T4 252.15
# C 0.7630016890146543
# A R134a
# B NitrousOxide
# T4 253.15
# C 0.7603534098851709
# A R134a
# B NitrousOxide
# T4 254.15
# C 0.7576017398011797
# A R134a
# B NitrousOxide
# T4 255.15
# C 0.754747692071011
# A R134a
# B NitrousOxide
# T4 256.15
# C 0.7517922515028529
# A R134a
# B NitrousOxide
# T4 257.15
# C 0.748736372073583
# A R134a
# B NitrousOxide
# T4 258.15
# C 0.7455809744826525
# A R134a
# B NitrousOxide
# T4 259.15
# C 0.7423269435285714
# A R134a
# B NitrousOxide
# T4 260.15
# C 0.7389751254098067
# A R134a
# B NitrousOxide
# T4 261.15
# C 0.7355263247505696
# A R134a
# B NitrousOxide
# T4 262.15
# C 0.7319813014686931
# A R134a
# B NitrousOxide
# T4 263.15
# C 0.7283407673960383
# A R134a
# B NitrousOxide
# T4 264.15
# C 0.7246053826256763
# A R134a
# B NitrousOxide
# T4 265.15
# C 0.7207757515518017
# A R134a
# B NitrousOxide
# T4 266.15
# C 0.7168524185548699
# A R134a
# B NitrousOxide
# T4 267.15
# C 0.712835863283974
# A R134a
# B NitrousOxide
# T4 268.15
# C 0.7087264954772754
# A R134a
# B NitrousOxide
# T4 269.15
# C 0.7045246492528592
# A R134a
# B NitrousOxide
# T4 270.15
# C 0.7002305767911762
# A R134a
# B NitrousOxide
# T4 271.15
# C 0.6958444413175564
# A R134a
# B NitrousOxide
# T4 272.15
# C 0.6913663092754808
# A R134a
# B NitrousOxide
# T4 273.15
# C 0.6867961415652737
# A R134a
# B NitrousOxide
# T4 274.15
# C 0.682133783694102
# A R134a
# B NitrousOxide
# T4 275.15
# C 0.6773789546472534
# A R134a
# B NitrousOxide
# T4 276.15
# C 0.6725312343359412
# A R717
# B NitrousOxide
# T4 243.15
# C 0.7393257169887969
# A R717
# B NitrousOxide
# T4 244.15
# C 0.7394480590348764
# A R717
# B NitrousOxide
# T4 245.15
# C 0.7394166656611927
# A R717
# B NitrousOxide
# T4 246.15
# C 0.7392322543143987
# A R717
# B NitrousOxide
# T4 247.15
# C 0.7388955978654255
# A R717
# B NitrousOxide
# T4 248.15
# C 0.7384075210880751
# A R717
# B NitrousOxide
# T4 249.15
# C 0.7377688970629432
# A R717
# B NitrousOxide
# T4 250.15
# C 0.7369806435094077
# A R717
# B NitrousOxide
# T4 251.15
# C 0.7360437190327523
# A R717
# B NitrousOxide
# T4 252.15
# C 0.7349591193052774
# A R717
# B NitrousOxide
# T4 253.15
# C 0.7337278731634844
# A R717
# B NitrousOxide
# T4 254.15
# C 0.7323510386165226
# A R717
# B NitrousOxide
# T4 255.15
# C 0.7308296987771622
# A R717
# B NitrousOxide
# T4 256.15
# C 0.729164957683774
# A R717
# B NitrousOxide
# T4 257.15
# C 0.7273579360246207
# A R717
# B NitrousOxide
# T4 258.15
# C 0.7254097667479283
# A R717
# B NitrousOxide
# T4 259.15
# C 0.723321590538833
# A R717
# B NitrousOxide
# T4 260.15
# C 0.7210945511495872
# A R717
# B NitrousOxide
# T4 261.15
# C 0.7187297905715724
# A R717
# B NitrousOxide
# T4 262.15
# C 0.7162284440171481
# A R717
# B NitrousOxide
# T4 263.15
# C 0.7135916346938751
# A R717
# B NitrousOxide
# T4 264.15
# C 0.7108204683333966
# A R717
# B NitrousOxide
# T4 265.15
# C 0.7079160274382483
# A R717
# B NitrousOxide
# T4 266.15
# C 0.7048793652229843
# A R717
# B NitrousOxide
# T4 267.15
# C 0.7017114991736007
# A R717
# B NitrousOxide
# T4 268.15
# C 0.698413404190807
# A R717
# B NitrousOxide
# T4 269.15
# C 0.694986005243588
# A R717
# B NitrousOxide
# T4 270.15
# C 0.6914301694511508
# A R717
# B NitrousOxide
# T4 271.15
# C 0.6877466975111377
# A R717
# B NitrousOxide
# T4 272.15
# C 0.683936314359978
# A R717
# B NitrousOxide
# T4 273.15
# C 0.6799996589420212
# A R717
# B NitrousOxide
# T4 274.15
# C 0.6759372729356298
# A R717
# B NitrousOxide
# T4 275.15
# C 0.671749588259367
# A R717
# B NitrousOxide
# T4 276.15
# C 0.6674369131398429
# A R290
# B NitrousOxide
# T4 243.15
# C 0.7812817168862336
# A R290
# B NitrousOxide
# T4 244.15
# C 0.7794765574672233
# A R290
# B NitrousOxide
# T4 245.15
# C 0.7775656744261965
# A R290
# B NitrousOxide
# T4 246.15
# C 0.7755501436569623
# A R290
# B NitrousOxide
# T4 247.15
# C 0.7734310244870487
# A R290
# B NitrousOxide
# T4 248.15
# C 0.771209358200605
# A R290
# B NitrousOxide
# T4 249.15
# C 0.7688861665339205
# A R290
# B NitrousOxide
# T4 250.15
# C 0.7664624501353856
# A R290
# B NitrousOxide
# T4 251.15
# C 0.7639391869803992
# A R290
# B NitrousOxide
# T4 252.15
# C 0.7613173307350911
# A R290
# B NitrousOxide
# T4 253.15
# C 0.7585978090552229
# A R290
# B NitrousOxide
# T4 254.15
# C 0.7557815218117818
# A R290
# B NitrousOxide
# T4 255.15
# C 0.7528693392316228
# A R290
# B NitrousOxide
# T4 256.15
# C 0.7498620999393352
# A R290
# B NitrousOxide
# T4 257.15
# C 0.7467606088839333
# A R290
# B NitrousOxide
# T4 258.15
# C 0.7435656351391756
# A R290
# B NitrousOxide
# T4 259.15
# C 0.7402779095518902
# A R290
# B NitrousOxide
# T4 260.15
# C 0.7368981222288267
# A R290
# B NitrousOxide
# T4 261.15
# C 0.7334269198231882
# A R290
# B NitrousOxide
# T4 262.15
# C 0.72986490261321
# A R290
# B NitrousOxide
# T4 263.15
# C 0.7262126213278793
# A R290
# B NitrousOxide
# T4 264.15
# C 0.7224705736963594
# A R290
# B NitrousOxide
# T4 265.15
# C 0.7186392006771933
# A R290
# B NitrousOxide
# T4 266.15
# C 0.7147188823274016
# A R290
# B NitrousOxide
# T4 267.15
# C 0.7107099332563585
# A R290
# B NitrousOxide
# T4 268.15
# C 0.7066125976117744
# A R290
# B NitrousOxide
# T4 269.15
# C 0.7024270435254237
# A R290
# B NitrousOxide
# T4 270.15
# C 0.698153356941458
# A R290
# B NitrousOxide
# T4 271.15
# C 0.6937915347366408
# A R290
# B NitrousOxide
# T4 272.15
# C 0.6893414770218658
# A R290
# B NitrousOxide
# T4 273.15
# C 0.6848029784980211
# A R290
# B NitrousOxide
# T4 274.15
# C 0.6801757187165222
# A R290
# B NitrousOxide
# T4 275.15
# C 0.6754592510637453
# A R290
# B NitrousOxide
# T4 276.15
# C 0.6706529902497051
# A R600
# B NitrousOxide
# T4 243.15
# C 0.8094488148284592
# A R600
# B NitrousOxide
# T4 244.15
# C 0.8069937409282059
# A R600
# B NitrousOxide
# T4 245.15
# C 0.8044336728878905
# A R600
# B NitrousOxide
# T4 246.15
# C 0.8017700937897445
# A R600
# B NitrousOxide
# T4 247.15
# C 0.7990044616044315
# A R600
# B NitrousOxide
# T4 248.15
# C 0.7961382075974887
# A R600
# B NitrousOxide
# T4 249.15
# C 0.7931727348132998
# A R600
# B NitrousOxide
# T4 250.15
# C 0.7901094164341117
# A R600
# B NitrousOxide
# T4 251.15
# C 0.7869495941885255
# A R600
# B NitrousOxide
# T4 252.15
# C 0.7836945767041595
# A R600
# B NitrousOxide
# T4 253.15
# C 0.780345637760313
# A R600
# B NitrousOxide
# T4 254.15
# C 0.7769040145623118
# A R600
# B NitrousOxide
# T4 255.15
# C 0.7733709058712653
# A R600
# B NitrousOxide
# T4 256.15
# C 0.7697474700883671
# A R600
# B NitrousOxide
# T4 257.15
# C 0.7660348232273381
# A R600
# B NitrousOxide
# T4 258.15
# C 0.7622340367522047
# A R600
# B NitrousOxide
# T4 259.15
# C 0.7583461353141859
# A R600
# B NitrousOxide
# T4 260.15
# C 0.7543720942872352
# A R600
# B NitrousOxide
# T4 261.15
# C 0.7503128371503842
# A R600
# B NitrousOxide
# T4 262.15
# C 0.7461692326618237
# A R600
# B NitrousOxide
# T4 263.15
# C 0.7419420917882977
# A R600
# B NitrousOxide
# T4 264.15
# C 0.7376321643587207
# A R600
# B NitrousOxide
# T4 265.15
# C 0.7332401354200121
# A R600
# B NitrousOxide
# T4 266.15
# C 0.7287666212334607
# A R600
# B NitrousOxide
# T4 267.15
# C 0.7242121648702169
# A R600
# B NitrousOxide
# T4 268.15
# C 0.7195772313383165
# A R600
# B NitrousOxide
# T4 269.15
# C 0.7148622021844007
# A R600
# B NitrousOxide
# T4 270.15
# C 0.7100673694859739
# A R600
# B NitrousOxide
# T4 271.15
# C 0.7051929291257248
# A R600
# B NitrousOxide
# T4 272.15
# C 0.7002389733179992
# A R600
# B NitrousOxide
# T4 273.15
# C 0.6952054820841622
# A R600
# B NitrousOxide
# T4 274.15
# C 0.6900923137508236
# A R600
# B NitrousOxide
# T4 275.15
# C 0.6848991941188102
# A R600
# B NitrousOxide
# T4 276.15
# C 0.679625704173418
# A R404a
# B NitrousOxide
# T4 243.15
# C 0.7578501528684856
# A R404a
# B NitrousOxide
# T4 244.15
# C 0.7566385329098266
# A R404a
# B NitrousOxide
# T4 245.15
# C 0.7553173442400074
# A R404a
# B NitrousOxide
# T4 246.15
# C 0.7538873865304971
# A R404a
# B NitrousOxide
# T4 247.15
# C 0.7523494527737368
# A R404a
# B NitrousOxide
# T4 248.15
# C 0.7507043277341209
# A R404a
# B NitrousOxide
# T4 249.15
# C 0.7489527863541126
# A R404a
# B NitrousOxide
# T4 250.15
# C 0.747095592108984
# A R404a
# B NitrousOxide
# T4 251.15
# C 0.7451334953020663
# A R404a
# B NitrousOxide
# T4 252.15
# C 0.7430672312927696
# A R404a
# B NitrousOxide
# T4 253.15
# C 0.7408975186478338
# A R404a
# B NitrousOxide
# T4 254.15
# C 0.7386250572058733
# A R404a
# B NitrousOxide
# T4 255.15
# C 0.7362505260440084
# A R404a
# B NitrousOxide
# T4 256.15
# C 0.733774581334019
# A R404a
# B NitrousOxide
# T4 257.15
# C 0.731197854074125
# A R404a
# B NitrousOxide
# T4 258.15
# C 0.7285209476807418
# A R404a
# B NitrousOxide
# T4 259.15
# C 0.7257444354226087
# A R404a
# B NitrousOxide
# T4 260.15
# C 0.7228688576736161
# A R404a
# B NitrousOxide
# T4 261.15
# C 0.7198947189838298
# A R404a
# B NitrousOxide
# T4 262.15
# C 0.7168224848898996
# A R404a
# B NitrousOxide
# T4 263.15
# C 0.7136525785050407
# A R404a
# B NitrousOxide
# T4 264.15
# C 0.7103853768046353
# A R404a
# B NitrousOxide
# T4 265.15
# C 0.707021206589389
# A R404a
# B NitrousOxide
# T4 266.15
# C 0.7035603400789291
# A R404a
# B NitrousOxide
# T4 267.15
# C 0.700002990085463
# A R404a
# B NitrousOxide
# T4 268.15
# C 0.6963493047091495
# A R404a
# B NitrousOxide
# T4 269.15
# C 0.6925993614872101
# A R404a
# B NitrousOxide
# T4 270.15
# C 0.6887531609179752
# A R404a
# B NitrousOxide
# T4 271.15
# C 0.684810619266908
# A R404a
# B NitrousOxide
# T4 272.15
# C 0.6807715605463593
# A R404a
# B NitrousOxide
# T4 273.15
# C 0.6766357075402774
# A R404a
# B NitrousOxide
# T4 274.15
# C 0.6724026717220885
# A R404a
# B NitrousOxide
# T4 275.15
# C 0.6680719418842542
# A R404a
# B NitrousOxide
# T4 276.15
# C 0.6636428712646462
