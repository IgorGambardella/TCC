# %%
from CoolProp.CoolProp import PropsSI as COOLPROP
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import get_test_data

#Listas
registro_fluidos = []
COP_lista = []
lista_T5 = []
Wcomp_total_lista = []
cont = []

#Lista de Temperaturas
for T5 in range (-3000 + 27315, 400 + 27315, 100):
    T5 = T5 / 100
    cont.append(T5)

#Lista de características para as curvas do gráfico
lista_cor = ['r','g','b', 'c', 'm']
lista_ls = ['-', '-.', ':']
caracteristicas = []
for ls in lista_ls:
    for cor in lista_cor:
        caracteristicas.append((cor, ls))   
    
#Dados do problema
Pfrig = 120 * 1000
T1 = -80 + 273.15
T11 = 28 + 273.15
N = 0.7 #Eficiência isentrópica
fluid_high_lista = ['R134a', 'R717', 'R290', 'R600', 'R404a']
fluid_low_lista = ['R23', 'R170', 'NitrousOxide']
drop_suc = 0 #[Pa]
drop_desc = 0 #[Pa]
DeltaT = 0 #[°C]

#Loop nos dois ciclos - variação dos refrigerantes e do coeficiente politrópico
for fluid_low in fluid_low_lista:
    for fluid_high in fluid_high_lista:
        if fluid_low == 'NitrousOxide':
            par_fluido = ('Óxido nitroso', fluid_high)    
        else:
            par_fluido = (fluid_low, fluid_high)
        registro_fluidos.append(par_fluido)
         #Temperatura T5
        for T5 in cont:
            #Pressão crítica do fluido superior
            P_crit_high = COOLPROP('PCRIT', fluid_high)
            #Ciclo inferior
            P1 = COOLPROP('P', 'T', T1, 'Q', 1, fluid_low)
            P5 = COOLPROP('P', 'T', T5, 'Q', 0, fluid_low)
            P4 = P5
            h5 = COOLPROP('H', 'T', T5, 'Q', 0, fluid_low)
            h6 = h5
            #Pressão intermediária
            P_int =  (P1 * P5) ** 0.5
            P6 = P_int
            P3 = P_int
            P7 = P_int
            P2 = P_int
            h7 = COOLPROP('H', 'P', P7, 'Q', 0, fluid_low)
            h8 = h7
            h3 = COOLPROP('H', 'P', P3, 'Q', 1, fluid_low)
            h1 = COOLPROP('H', 'T', T1, 'Q', 1, fluid_low)
            #CBP
            S1 = COOLPROP('S', 'T', T1, 'Q', 1, fluid_low)
            S2_ideal = S1     
            h2_ideal = COOLPROP('H', 'S', S2_ideal , 'P', P2, fluid_low)
            h2_real = (h2_ideal - h1)/N + h1            
            m_CBP = Pfrig / (h1 - h8)
            #CAP
            s3 = COOLPROP('S', 'P', P3, 'Q', 1, fluid_low)
            s4_ideal = s3
            h4_ideal = COOLPROP('H', 'P', P4, 'S', s4_ideal, fluid_low)
            h4_real = (h4_ideal - h3)/N + h3
            
            #Ciclo superior
            h11 = COOLPROP('H', 'T', T11, 'Q', 0, fluid_high)
            P11 = COOLPROP('P', 'T', T11, 'Q', 0, fluid_high)
            T12 = T5 - 5
            h12 = h11 
            P12 = COOLPROP('P', 'T', T12, 'Q', 0, fluid_high)
            P10 = P11
            P9 = P12
            h9 = COOLPROP('H', 'P', P9, 'Q', 1, fluid_high)
            s9 = COOLPROP('S', 'P', P9, 'H', h9, fluid_high)
            s10_ideal = s9
            h10_ideal = COOLPROP('H', 'P', P10, 'S', s10_ideal, fluid_high)
            h10_real = (h10_ideal - h9)/N + h9
            

            #Trabalho específico do CBP
            w_CBP = h2_real - h1
            #Trabalho do CBP
            W_CBP = m_CBP * w_CBP
            #CAP
            m_CAP = m_CBP * (h7 - h2_real) / (h6 - h3)
            #Trabalho específico do CAP
            w_CAP = h4_real - h3
            #Trabalho do CAP
            W_CAP = m_CAP * w_CAP
            #Trabalho total no ciclo inferior
            W_low_total = W_CAP + W_CBP
            #Calor trocado no trocador central
            Qcond_low =  m_CAP * (h4_real - h5)
            #Ciclo superior
            Qevap_high = Qcond_low
            m_flow_high = Qevap_high / (h9 - h12)
            #Verificação da pressão crítica
            if P_crit_high > P10:
                lista_T5.append(T5)
                #Trabalho específico do compressor do ciclo superior
                w_high = h10_real - h9
                #Trabalho do compressor do ciclo superior
                Wcomp_high = m_flow_high * w_high
                #Trabalho total
                Wcomp_total = Wcomp_high + W_low_total
                Wcomp_total_lista.append(Wcomp_total / 1000)
                #COP
                COP = Pfrig / Wcomp_total
                COP_lista.append(COP)
                print("A", fluid_high)
                print("B", fluid_low)
                print("T5", T5)
                print("C", COP)
            else:
                print ('A pressão P10 = {:0.2f} kPa (T5 = {}, fluido inf = {}, fluido sup = {}) é maior do que a ' 
               'pressão crítica do {} e, por isso, o ponto não foi incluído no gráfico'.format(P10 / 1000,T5,fluid_low,
                                                                                               fluid_high, fluid_high))               

               
if len(lista_T5) != 0:
    plt.figure(figsize = [15, 15], dpi = 300)
    for i in range (0, len(COP_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T5[j])
            eixo_y.append(COP_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1], 
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T5', size = 15)
        plt.ylabel('COP', size = 15)
    plt.legend(prop={'size' : 15})
    plt.show()
   
else:
    print('Todos os pontos são inválidos')
# Out:
# A R134a
# B R23
# T5 243.15
# C 0.8492394652071239
# A R134a
# B R23
# T5 244.15
# C 0.8510816848971652
# A R134a
# B R23
# T5 245.15
# C 0.8527723375587133
# A R134a
# B R23
# T5 246.15
# C 0.8543087054785617
# A R134a
# B R23
# T5 247.15
# C 0.8556880463907256
# A R134a
# B R23
# T5 248.15
# C 0.8569075908440413
# A R134a
# B R23
# T5 249.15
# C 0.8579645392363355
# A R134a
# B R23
# T5 250.15
# C 0.8588560584775056
# A R134a
# B R23
# T5 251.15
# C 0.8595792782484545
# A R134a
# B R23
# T5 252.15
# C 0.8601312868057129
# A R134a
# B R23
# T5 253.15
# C 0.8605091262798283
# A R134a
# B R23
# T5 254.15
# C 0.8607097874143405
# A R134a
# B R23
# T5 255.15
# C 0.860730203673909
# A R134a
# B R23
# T5 256.15
# C 0.8605672446468662
# A R134a
# B R23
# T5 257.15
# C 0.8602177086539203
# A R134a
# B R23
# T5 258.15
# C 0.8596783144684447
# A R134a
# B R23
# T5 259.15
# C 0.8589456919739663
# A R134a
# B R23
# T5 260.15
# C 0.8580163717768893
# A R134a
# B R23
# T5 261.15
# C 0.8568867733871259
# A R134a
# B R23
# T5 262.15
# C 0.8555531919607828
# A R134a
# B R23
# T5 263.15
# C 0.8540117833057159
# A R134a
# B R23
# T5 264.15
# C 0.8522585468957637
# A R134a
# B R23
# T5 265.15
# C 0.8502893065863014
# A R134a
# B R23
# T5 266.15
# C 0.8480996886520142
# A R134a
# B R23
# T5 267.15
# C 0.8456850967013594
# A R134a
# B R23
# T5 268.15
# C 0.843040682924468
# A R134a
# B R23
# T5 269.15
# C 0.8401613150045125
# A R134a
# B R23
# T5 270.15
# C 0.8370415379478761
# A R134a
# B R23
# T5 271.15
# C 0.8336755297595317
# A R134a
# B R23
# T5 272.15
# C 0.8300570496815894
# A R134a
# B R23
# T5 273.15
# C 0.82617937781008
# A R134a
# B R23
# T5 274.15
# C 0.8220352437045629
# A R134a
# B R23
# T5 275.15
# C 0.8176167418538206
# A R134a
# B R23
# T5 276.15
# C 0.8129152308700602
# A R717
# B R23
# T5 243.15
# C 0.867235883170556
# A R717
# B R23
# T5 244.15
# C 0.8687844813448643
# A R717
# B R23
# T5 245.15
# C 0.8701705517351054
# A R717
# B R23
# T5 246.15
# C 0.8713920140008351
# A R717
# B R23
# T5 247.15
# C 0.8724467685217768
# A R717
# B R23
# T5 248.15
# C 0.8733326927015405
# A R717
# B R23
# T5 249.15
# C 0.8740476369469931
# A R717
# B R23
# T5 250.15
# C 0.8745894202651269
# A R717
# B R23
# T5 251.15
# C 0.8749558254603651
# A R717
# B R23
# T5 252.15
# C 0.8751445938836313
# A R717
# B R23
# T5 253.15
# C 0.8751534196781123
# A R717
# B R23
# T5 254.15
# C 0.8749799434619172
# A R717
# B R23
# T5 255.15
# C 0.874621745400932
# A R717
# B R23
# T5 256.15
# C 0.874076337569386
# A R717
# B R23
# T5 257.15
# C 0.8733411555343659
# A R717
# B R23
# T5 258.15
# C 0.8724135490573813
# A R717
# B R23
# T5 259.15
# C 0.8712907717909787
# A R717
# B R23
# T5 260.15
# C 0.8699699698350764
# A R717
# B R23
# T5 261.15
# C 0.8684481690045034
# A R717
# B R23
# T5 262.15
# C 0.8667222606076659
# A R717
# B R23
# T5 263.15
# C 0.8647889855845191
# A R717
# B R23
# T5 264.15
# C 0.8626449163312749
# A R717
# B R23
# T5 265.15
# C 0.8602864371049829
# A R717
# B R23
# T5 266.15
# C 0.857709720644916
# A R717
# B R23
# T5 267.15
# C 0.8549107025520916
# A R717
# B R23
# T5 268.15
# C 0.8518850516882801
# A R717
# B R23
# T5 269.15
# C 0.848628136336143
# A R717
# B R23
# T5 270.15
# C 0.8451349853082063
# A R717
# B R23
# T5 271.15
# C 0.8414002429430776
# A R717
# B R23
# T5 272.15
# C 0.8374181167011087
# A R717
# B R23
# T5 273.15
# C 0.8331823161819452
# A R717
# B R23
# T5 274.15
# C 0.8286859811760173
# A R717
# B R23
# T5 275.15
# C 0.8239215966349502
# A R717
# B R23
# T5 276.15
# C 0.8188808913338794
# A R290
# B R23
# T5 243.15
# C 0.8456516522451734
# A R290
# B R23
# T5 244.15
# C 0.8474282637411735
# A R290
# B R23
# T5 245.15
# C 0.849058959455772
# A R290
# B R23
# T5 246.15
# C 0.8505410478224857
# A R290
# B R23
# T5 247.15
# C 0.8518718050695463
# A R290
# B R23
# T5 248.15
# C 0.8530484725454387
# A R290
# B R23
# T5 249.15
# C 0.8540682537249423
# A R290
# B R23
# T5 250.15
# C 0.8549283108573622
# A R290
# B R23
# T5 251.15
# C 0.8556257612162993
# A R290
# B R23
# T5 252.15
# C 0.8561576729159349
# A R290
# B R23
# T5 253.15
# C 0.8565210602210935
# A R290
# B R23
# T5 254.15
# C 0.8567128783143537
# A R290
# B R23
# T5 255.15
# C 0.8567300174419444
# A R290
# B R23
# T5 256.15
# C 0.8565692963670227
# A R290
# B R23
# T5 257.15
# C 0.8562274550242603
# A R290
# B R23
# T5 258.15
# C 0.8557011463142445
# A R290
# B R23
# T5 259.15
# C 0.8549869268660295
# A R290
# B R23
# T5 260.15
# C 0.8540812466743899
# A R290
# B R23
# T5 261.15
# C 0.8529804374188956
# A R290
# B R23
# T5 262.15
# C 0.8516806993000957
# A R290
# B R23
# T5 263.15
# C 0.8501780861506256
# A R290
# B R23
# T5 264.15
# C 0.848468488569818
# A R290
# B R23
# T5 265.15
# C 0.8465476147613452
# A R290
# B R23
# T5 266.15
# C 0.8444109687043653
# A R290
# B R23
# T5 267.15
# C 0.8420538252027574
# A R290
# B R23
# T5 268.15
# C 0.8394712012775328
# A R290
# B R23
# T5 269.15
# C 0.8366578232256406
# A R290
# B R23
# T5 270.15
# C 0.8336080886020649
# A R290
# B R23
# T5 271.15
# C 0.8303160220528286
# A R290
# B R23
# T5 272.15
# C 0.8267752237150516
# A R290
# B R23
# T5 273.15
# C 0.8229788089947029
# A R290
# B R23
# T5 274.15
# C 0.8189193373451574
# A R290
# B R23
# T5 275.15
# C 0.8145887279204317
# A R290
# B R23
# T5 276.15
# C 0.8099781588760349
# A R600
# B R23
# T5 243.15
# C 0.8713985251850879
# A R600
# B R23
# T5 244.15
# C 0.8727035275743915
# A R600
# B R23
# T5 245.15
# C 0.8738577926538681
# A R600
# B R23
# T5 246.15
# C 0.8748589375696859
# A R600
# B R23
# T5 247.15
# C 0.8757045515754427
# A R600
# B R23
# T5 248.15
# C 0.8763921930877423
# A R600
# B R23
# T5 249.15
# C 0.8769193865271663
# A R600
# B R23
# T5 250.15
# C 0.8772836186660341
# A R600
# B R23
# T5 251.15
# C 0.8774823346738313
# A R600
# B R23
# T5 252.15
# C 0.8775129336951298
# A R600
# B R23
# T5 253.15
# C 0.8773728027554154
# A R600
# B R23
# T5 254.15
# C 0.877059880242369
# A R600
# B R23
# T5 255.15
# C 0.8765715237283844
# A R600
# B R23
# T5 256.15
# C 0.8759047660985847
# A R600
# B R23
# T5 257.15
# C 0.8750565705740748
# A R600
# B R23
# T5 258.15
# C 0.8740238222198011
# A R600
# B R23
# T5 259.15
# C 0.8728033184740995
# A R600
# B R23
# T5 260.15
# C 0.8713917584578394
# A R600
# B R23
# T5 261.15
# C 0.8697857309958963
# A R600
# B R23
# T5 262.15
# C 0.8679817011248934
# A R600
# B R23
# T5 263.15
# C 0.8659759948566165
# A R600
# B R23
# T5 264.15
# C 0.8637647819369173
# A R600
# B R23
# T5 265.15
# C 0.861344056309842
# A R600
# B R23
# T5 266.15
# C 0.8587096138899535
# A R600
# B R23
# T5 267.15
# C 0.8558570272068288
# A R600
# B R23
# T5 268.15
# C 0.8527816163681672
# A R600
# B R23
# T5 269.15
# C 0.849478415686383
# A R600
# B R23
# T5 270.15
# C 0.8459421352187033
# A R600
# B R23
# T5 271.15
# C 0.842167116123394
# A R600
# B R23
# T5 272.15
# C 0.8381472786568765
# A R600
# B R23
# T5 273.15
# C 0.8338760613924623
# A R600
# B R23
# T5 274.15
# C 0.8293463495729466
# A R600
# B R23
# T5 275.15
# C 0.8245503902645092
# A R600
# B R23
# T5 276.15
# C 0.8194796911561767
# A R404a
# B R23
# T5 243.15
# C 0.7974747947516163
# A R404a
# B R23
# T5 244.15
# C 0.8005776667323586
# A R404a
# B R23
# T5 245.15
# C 0.8035276446013049
# A R404a
# B R23
# T5 246.15
# C 0.8063211785962238
# A R404a
# B R23
# T5 247.15
# C 0.8089546997215842
# A R404a
# B R23
# T5 248.15
# C 0.8114246180934354
# A R404a
# B R23
# T5 249.15
# C 0.8137273209391475
# A R404a
# B R23
# T5 250.15
# C 0.8158591702124602
# A R404a
# B R23
# T5 251.15
# C 0.8178164997841121
# A R404a
# B R23
# T5 252.15
# C 0.8195956121597928
# A R404a
# B R23
# T5 253.15
# C 0.8211927746725961
# A R404a
# B R23
# T5 254.15
# C 0.8226042150905234
# A R404a
# B R23
# T5 255.15
# C 0.8238261165691797
# A R404a
# B R23
# T5 256.15
# C 0.8248546118724484
# A R404a
# B R23
# T5 257.15
# C 0.8256857767708753
# A R404a
# B R23
# T5 258.15
# C 0.8263156225136895
# A R404a
# B R23
# T5 259.15
# C 0.8267400872561294
# A R404a
# B R23
# T5 260.15
# C 0.8269550263009501
# A R404a
# B R23
# T5 261.15
# C 0.8269562009939442
# A R404a
# B R23
# T5 262.15
# C 0.8267392660818664
# A R404a
# B R23
# T5 263.15
# C 0.8262997553103455
# A R404a
# B R23
# T5 264.15
# C 0.8256330649966751
# A R404a
# B R23
# T5 265.15
# C 0.8247344352643686
# A R404a
# B R23
# T5 266.15
# C 0.8235989285688339
# A R404a
# B R23
# T5 267.15
# C 0.8222214050372038
# A R404a
# B R23
# T5 268.15
# C 0.8205964941522034
# A R404a
# B R23
# T5 269.15
# C 0.8187185620102856
# A R404a
# B R23
# T5 270.15
# C 0.816581673485596
# A R404a
# B R23
# T5 271.15
# C 0.8141795481963264
# A R404a
# B R23
# T5 272.15
# C 0.8115055090009877
# A R404a
# B R23
# T5 273.15
# C 0.8085524218259718
# A R404a
# B R23
# T5 274.15
# C 0.8053126244607708
# A R404a
# B R23
# T5 275.15
# C 0.8017778421887425
# A R404a
# B R23
# T5 276.15
# C 0.7979390870381875
# A R134a
# B R170
# T5 243.15
# C 0.853045498174912
# A R134a
# B R170
# T5 244.15
# C 0.8550600928696699
# A R134a
# B R170
# T5 245.15
# C 0.8569278486139916
# A R134a
# B R170
# T5 246.15
# C 0.8586462166145582
# A R134a
# B R170
# T5 247.15
# C 0.8602126396751031
# A R134a
# B R170
# T5 248.15
# C 0.8616245507723969
# A R134a
# B R170
# T5 249.15
# C 0.8628793714147578
# A R134a
# B R170
# T5 250.15
# C 0.86397450976343
# A R134a
# B R170
# T5 251.15
# C 0.8649073585017296
# A R134a
# B R170
# T5 252.15
# C 0.8656752924249513
# A R134a
# B R170
# T5 253.15
# C 0.8662756657244055
# A R134a
# B R170
# T5 254.15
# C 0.8667058089407002
# A R134a
# B R170
# T5 255.15
# C 0.8669630255385293
# A R134a
# B R170
# T5 256.15
# C 0.8670445881420332
# A R134a
# B R170
# T5 257.15
# C 0.8669477341727876
# A R134a
# B R170
# T5 258.15
# C 0.8666696611710728
# A R134a
# B R170
# T5 259.15
# C 0.8662075214066378
# A R134a
# B R170
# T5 260.15
# C 0.8655584159999002
# A R134a
# B R170
# T5 261.15
# C 0.8647193882222883
# A R134a
# B R170
# T5 262.15
# C 0.8636874160746155
# A R134a
# B R170
# T5 263.15
# C 0.8624594039668225
# A R134a
# B R170
# T5 264.15
# C 0.8610321733975764
# A R134a
# B R170
# T5 265.15
# C 0.8594024525460707
# A R134a
# B R170
# T5 266.15
# C 0.8575668644569062
# A R134a
# B R170
# T5 267.15
# C 0.8555219140217776
# A R134a
# B R170
# T5 268.15
# C 0.8532639731422216
# A R134a
# B R170
# T5 269.15
# C 0.85078926413197
# A R134a
# B R170
# T5 270.15
# C 0.848093840994204
# A R134a
# B R170
# T5 271.15
# C 0.8451735682743797
# A R134a
# B R170
# T5 272.15
# C 0.8420240971036185
# A R134a
# B R170
# T5 273.15
# C 0.838640837968452
# A R134a
# B R170
# T5 274.15
# C 0.8350189296261781
# A R134a
# B R170
# T5 275.15
# C 0.8311532034388698
# A R134a
# B R170
# T5 276.15
# C 0.8270381423358195
# A R717
# B R170
# T5 243.15
# C 0.8711605662268699
# A R717
# B R170
# T5 244.15
# C 0.8728846637463702
# A R717
# B R170
# T5 245.15
# C 0.8744508570574142
# A R717
# B R170
# T5 246.15
# C 0.8758572292135258
# A R717
# B R170
# T5 247.15
# C 0.8771018605275197
# A R717
# B R170
# T5 248.15
# C 0.8781828260841278
# A R717
# B R170
# T5 249.15
# C 0.8790981930426564
# A R717
# B R170
# T5 250.15
# C 0.8798460176895445
# A R717
# B R170
# T5 251.15
# C 0.8804243422419427
# A R717
# B R170
# T5 252.15
# C 0.8808311913770024
# A R717
# B R170
# T5 253.15
# C 0.8810645684571927
# A R717
# B R170
# T5 254.15
# C 0.8811224514201884
# A R717
# B R170
# T5 255.15
# C 0.8810027883104353
# A R717
# B R170
# T5 256.15
# C 0.8807034924653303
# A R717
# B R170
# T5 257.15
# C 0.8802224371177813
# A R717
# B R170
# T5 258.15
# C 0.8795574496911689
# A R717
# B R170
# T5 259.15
# C 0.8787063054392743
# A R717
# B R170
# T5 260.15
# C 0.87766672050013
# A R717
# B R170
# T5 261.15
# C 0.8764363442735665
# A R717
# B R170
# T5 262.15
# C 0.8750127510249449
# A R717
# B R170
# T5 263.15
# C 0.8733934306878027
# A R717
# B R170
# T5 264.15
# C 0.8715757783396493
# A R717
# B R170
# T5 265.15
# C 0.8695570834821037
# A R717
# B R170
# T5 266.15
# C 0.8673345167906241
# A R717
# B R170
# T5 267.15
# C 0.864905116560276
# A R717
# B R170
# T5 268.15
# C 0.862265773011773
# A R717
# B R170
# T5 269.15
# C 0.8594132109396225
# A R717
# B R170
# T5 270.15
# C 0.8563439702667671
# A R717
# B R170
# T5 271.15
# C 0.8530543842206864
# A R717
# B R170
# T5 272.15
# C 0.8495405547410965
# A R717
# B R170
# T5 273.15
# C 0.8457983246582992
# A R717
# B R170
# T5 274.15
# C 0.8418232460658682
# A R717
# B R170
# T5 275.15
# C 0.837610544179036
# A R717
# B R170
# T5 276.15
# C 0.8331550757890819
# A R290
# B R170
# T5 243.15
# C 0.8494342197356226
# A R290
# B R170
# T5 244.15
# C 0.851381738856338
# A R290
# B R170
# T5 245.15
# C 0.853188042779564
# A R290
# B R170
# T5 246.15
# C 0.8548506110242162
# A R290
# B R170
# T5 247.15
# C 0.8563669070872572
# A R290
# B R170
# T5 248.15
# C 0.8577343769716449
# A R290
# B R170
# T5 249.15
# C 0.8589504475111657
# A R290
# B R170
# T5 250.15
# C 0.8600125244718388
# A R290
# B R170
# T5 251.15
# C 0.860917990407131
# A R290
# B R170
# T5 252.15
# C 0.8616642022552544
# A R290
# B R170
# T5 253.15
# C 0.8622484886308925
# A R290
# B R170
# T5 254.15
# C 0.8626681468030819
# A R290
# B R170
# T5 255.15
# C 0.8629204393046547
# A R290
# B R170
# T5 256.15
# C 0.8630025902151629
# A R290
# B R170
# T5 257.15
# C 0.862911780842784
# A R290
# B R170
# T5 258.15
# C 0.8626451451170715
# A R290
# B R170
# T5 259.15
# C 0.8621997643034669
# A R290
# B R170
# T5 260.15
# C 0.861572661146775
# A R290
# B R170
# T5 261.15
# C 0.8607607933092158
# A R290
# B R170
# T5 262.15
# C 0.8597610460411982
# A R290
# B R170
# T5 263.15
# C 0.858570223965746
# A R290
# B R170
# T5 264.15
# C 0.8571850418778063
# A R290
# B R170
# T5 265.15
# C 0.8556021144571592
# A R290
# B R170
# T5 266.15
# C 0.8538179445864642
# A R290
# B R170
# T5 267.15
# C 0.8518289104655438
# A R290
# B R170
# T5 268.15
# C 0.8496312509171218
# A R290
# B R170
# T5 269.15
# C 0.8472210489334209
# A R290
# B R170
# T5 270.15
# C 0.8445942131011467
# A R290
# B R170
# T5 271.15
# C 0.8417464566056823
# A R290
# B R170
# T5 272.15
# C 0.8386732734268653
# A R290
# B R170
# T5 273.15
# C 0.8353699112590776
# A R290
# B R170
# T5 274.15
# C 0.8318313405801685
# A R290
# B R170
# T5 275.15
# C 0.8280522191542588
# A R290
# B R170
# T5 276.15
# C 0.8240268510746847
# A R600
# B R170
# T5 243.15
# C 0.8753508775052722
# A R600
# B R170
# T5 244.15
# C 0.8768308838767582
# A R600
# B R170
# T5 245.15
# C 0.8781647518528815
# A R600
# B R170
# T5 246.15
# C 0.879350265869549
# A R600
# B R170
# T5 247.15
# C 0.880385198924126
# A R600
# B R170
# T5 248.15
# C 0.8812673108233626
# A R600
# B R170
# T5 249.15
# C 0.8819943463333768
# A R600
# B R170
# T5 250.15
# C 0.8825640329693766
# A R600
# B R170
# T5 251.15
# C 0.8829740786357723
# A R600
# B R170
# T5 252.15
# C 0.8832221689739416
# A R600
# B R170
# T5 253.15
# C 0.8833060036246901
# A R600
# B R170
# T5 254.15
# C 0.8832238678650735
# A R600
# B R170
# T5 255.15
# C 0.8829734920250847
# A R600
# B R170
# T5 256.15
# C 0.8825523123800393
# A R600
# B R170
# T5 257.15
# C 0.8819577317033607
# A R600
# B R170
# T5 258.15
# C 0.8811871143686013
# A R600
# B R170
# T5 259.15
# C 0.8802377808242672
# A R600
# B R170
# T5 260.15
# C 0.8791070014028024
# A R600
# B R170
# T5 261.15
# C 0.8777919894555299
# A R600
# B R170
# T5 262.15
# C 0.8762898936897487
# A R600
# B R170
# T5 263.15
# C 0.8745977896007647
# A R600
# B R170
# T5 264.15
# C 0.8727126698914351
# A R600
# B R170
# T5 265.15
# C 0.870631433809792
# A R600
# B R170
# T5 266.15
# C 0.8683508750644302
# A R600
# B R170
# T5 267.15
# C 0.8658676685385871
# A R600
# B R170
# T5 268.15
# C 0.8631783551687289
# A R600
# B R170
# T5 269.15
# C 0.8602793250675147
# A R600
# B R170
# T5 270.15
# C 0.8571667985185358
# A R600
# B R170
# T5 271.15
# C 0.85383680452157
# A R600
# B R170
# T5 272.15
# C 0.850285156613391
# A R600
# B R170
# T5 273.15
# C 0.8465074252563239
# A R600
# B R170
# T5 274.15
# C 0.8424989065251243
# A R600
# B R170
# T5 275.15
# C 0.8382545861614643
# A R600
# B R170
# T5 276.15
# C 0.8337690981792724
# A R404a
# B R170
# T5 243.15
# C 0.8009483524617809
# A R404a
# B R170
# T5 244.15
# C 0.8042174240885742
# A R404a
# B R170
# T5 245.15
# C 0.8073386245280073
# A R404a
# B R170
# T5 246.15
# C 0.8103085777755503
# A R404a
# B R170
# T5 247.15
# C 0.8131239040171367
# A R404a
# B R170
# T5 248.15
# C 0.815781219212795
# A R404a
# B R170
# T5 249.15
# C 0.8182771344520056
# A R404a
# B R170
# T5 250.15
# C 0.8206082550588656
# A R404a
# B R170
# T5 251.15
# C 0.8227711794250999
# A R404a
# B R170
# T5 252.15
# C 0.8247624975455334
# A R404a
# B R170
# T5 253.15
# C 0.8265787892282785
# A R404a
# B R170
# T5 254.15
# C 0.8282166219483179
# A R404a
# B R170
# T5 255.15
# C 0.8296725482987671
# A R404a
# B R170
# T5 256.15
# C 0.8309431030715899
# A R404a
# B R170
# T5 257.15
# C 0.832024799721074
# A R404a
# B R170
# T5 258.15
# C 0.8329141264607917
# A R404a
# B R170
# T5 259.15
# C 0.8336075416744824
# A R404a
# B R170
# T5 260.15
# C 0.834101468692462
# A R404a
# B R170
# T5 261.15
# C 0.8343922898336743
# A R404a
# B R170
# T5 262.15
# C 0.8344763396241386
# A R404a
# B R170
# T5 263.15
# C 0.8343498970925456
# A R404a
# B R170
# T5 264.15
# C 0.8340091770299866
# A R404a
# B R170
# T5 265.15
# C 0.8334503201183082
# A R404a
# B R170
# T5 266.15
# C 0.8326693816233698
# A R404a
# B R170
# T5 267.15
# C 0.8316623188077641
# A R404a
# B R170
# T5 268.15
# C 0.8304249765396402
# A R404a
# B R170
# T5 269.15
# C 0.8289530710405587
# A R404a
# B R170
# T5 270.15
# C 0.8272421714908074
# A R404a
# B R170
# T5 271.15
# C 0.8252876791572141
# A R404a
# B R170
# T5 272.15
# C 0.8230848036656689
# A R404a
# B R170
# T5 273.15
# C 0.8206285359506246
# A R404a
# B R170
# T5 274.15
# C 0.8179136173053926
# A R404a
# B R170
# T5 275.15
# C 0.8149345038206343
# A R404a
# B R170
# T5 276.15
# C 0.8116853253250285
# A R134a
# B NitrousOxide
# T5 243.15
# C 0.8465876992826187
# A R134a
# B NitrousOxide
# T5 244.15
# C 0.8484877246524751
# A R134a
# B NitrousOxide
# T5 245.15
# C 0.8502516556382231
# A R134a
# B NitrousOxide
# T5 246.15
# C 0.8518777822409269
# A R134a
# B NitrousOxide
# T5 247.15
# C 0.8533644096081174
# A R134a
# B NitrousOxide
# T5 248.15
# C 0.854709857430144
# A R134a
# B NitrousOxide
# T5 249.15
# C 0.8559124592015586
# A R134a
# B NitrousOxide
# T5 250.15
# C 0.8569705613371864
# A R134a
# B NitrousOxide
# T5 251.15
# C 0.8578825221363342
# A R134a
# B NitrousOxide
# T5 252.15
# C 0.858646710579339
# A R134a
# B NitrousOxide
# T5 253.15
# C 0.8592615049419522
# A R134a
# B NitrousOxide
# T5 254.15
# C 0.8597252912169268
# A R134a
# B NitrousOxide
# T5 255.15
# C 0.8600364613232058
# A R134a
# B NitrousOxide
# T5 256.15
# C 0.8601934110848566
# A R134a
# B NitrousOxide
# T5 257.15
# C 0.8601945379596067
# A R134a
# B NitrousOxide
# T5 258.15
# C 0.8600382385018243
# A R134a
# B NitrousOxide
# T5 259.15
# C 0.8597229054765194
# A R134a
# B NitrousOxide
# T5 260.15
# C 0.8592469247524104
# A R134a
# B NitrousOxide
# T5 261.15
# C 0.8586086717129414
# A R134a
# B NitrousOxide
# T5 262.15
# C 0.857806507331625
# A R134a
# B NitrousOxide
# T5 263.15
# C 0.8568387737910966
# A R134a
# B NitrousOxide
# T5 264.15
# C 0.8557037896064658
# A R134a
# B NitrousOxide
# T5 265.15
# C 0.854399844201672
# A R134a
# B NitrousOxide
# T5 266.15
# C 0.8529251918692075
# A R134a
# B NitrousOxide
# T5 267.15
# C 0.8512780450413369
# A R134a
# B NitrousOxide
# T5 268.15
# C 0.849456566784799
# A R134a
# B NitrousOxide
# T5 269.15
# C 0.8474588624180741
# A R134a
# B NitrousOxide
# T5 270.15
# C 0.8452829701334524
# A R134a
# B NitrousOxide
# T5 271.15
# C 0.8429268504893924
# A R134a
# B NitrousOxide
# T5 272.15
# C 0.8403883745967267
# A R134a
# B NitrousOxide
# T5 273.15
# C 0.8376653108391696
# A R134a
# B NitrousOxide
# T5 274.15
# C 0.8347553098632144
# A R134a
# B NitrousOxide
# T5 275.15
# C 0.8316558875771655
# A R134a
# B NitrousOxide
# T5 276.15
# C 0.8283644059244714
# A R717
# B NitrousOxide
# T5 243.15
# C 0.8645016528751525
# A R717
# B NitrousOxide
# T5 244.15
# C 0.8661113204310114
# A R717
# B NitrousOxide
# T5 245.15
# C 0.8675743620150783
# A R717
# B NitrousOxide
# T5 246.15
# C 0.8688897026925384
# A R717
# B NitrousOxide
# T5 247.15
# C 0.8700562859853435
# A R717
# B NitrousOxide
# T5 248.15
# C 0.8710730721938809
# A R717
# B NitrousOxide
# T5 249.15
# C 0.871939036601104
# A R717
# B NitrousOxide
# T5 250.15
# C 0.8726531675285194
# A R717
# B NitrousOxide
# T5 251.15
# C 0.8732144642533812
# A R717
# B NitrousOxide
# T5 252.15
# C 0.8736219347728645
# A R717
# B NitrousOxide
# T5 253.15
# C 0.8738745933975346
# A R717
# B NitrousOxide
# T5 254.15
# C 0.8739714581568163
# A R717
# B NitrousOxide
# T5 255.15
# C 0.8739115480214813
# A R717
# B NitrousOxide
# T5 256.15
# C 0.8736938798974621
# A R717
# B NitrousOxide
# T5 257.15
# C 0.8733174653951614
# A R717
# B NitrousOxide
# T5 258.15
# C 0.8727813073466131
# A R717
# B NitrousOxide
# T5 259.15
# C 0.8720843960392389
# A R717
# B NitrousOxide
# T5 260.15
# C 0.8712257051405795
# A R717
# B NitrousOxide
# T5 261.15
# C 0.8702041872914767
# A R717
# B NitrousOxide
# T5 262.15
# C 0.8690187693195038
# A R717
# B NitrousOxide
# T5 263.15
# C 0.8676683470993524
# A R717
# B NitrousOxide
# T5 264.15
# C 0.8661517796000465
# A R717
# B NitrousOxide
# T5 265.15
# C 0.8644678832736233
# A R717
# B NitrousOxide
# T5 266.15
# C 0.8626154247215966
# A R717
# B NitrousOxide
# T5 267.15
# C 0.8605931135634575
# A R717
# B NitrousOxide
# T5 268.15
# C 0.858399594217511
# A R717
# B NitrousOxide
# T5 269.15
# C 0.8560334369065465
# A R717
# B NitrousOxide
# T5 270.15
# C 0.853493127701271
# A R717
# B NitrousOxide
# T5 271.15
# C 0.8507770574801419
# A R717
# B NitrousOxide
# T5 272.15
# C 0.8478835096234453
# A R717
# B NitrousOxide
# T5 273.15
# C 0.8448106462850714
# A R717
# B NitrousOxide
# T5 274.15
# C 0.8415564929805013
# A R717
# B NitrousOxide
# T5 275.15
# C 0.8381189212490189
# A R717
# B NitrousOxide
# T5 276.15
# C 0.834495629055326
# A R290
# B NitrousOxide
# T5 243.15
# C 0.8430161964707606
# A R290
# B NitrousOxide
# T5 244.15
# C 0.8448505206711173
# A R290
# B NitrousOxide
# T5 245.15
# C 0.8465542689722981
# A R290
# B NitrousOxide
# T5 246.15
# C 0.8481257488996138
# A R290
# B NitrousOxide
# T5 247.15
# C 0.8495632757400462
# A R290
# B NitrousOxide
# T5 248.15
# C 0.8508651719462716
# A R290
# B NitrousOxide
# T5 249.15
# C 0.8520297664200834
# A R290
# B NitrousOxide
# T5 250.15
# C 0.8530553936640741
# A R290
# B NitrousOxide
# T5 251.15
# C 0.8539403927873351
# A R290
# B NitrousOxide
# T5 252.15
# C 0.8546831063643356
# A R290
# B NitrousOxide
# T5 253.15
# C 0.8552818791115843
# A R290
# B NitrousOxide
# T5 254.15
# C 0.8557350563877181
# A R290
# B NitrousOxide
# T5 255.15
# C 0.8560409824904569
# A R290
# B NitrousOxide
# T5 256.15
# C 0.8561979987357654
# A R290
# B NitrousOxide
# T5 257.15
# C 0.8562044412811534
# A R290
# B NitrousOxide
# T5 258.15
# C 0.8560586387108453
# A R290
# B NitrousOxide
# T5 259.15
# C 0.8557589093020747
# A R290
# B NitrousOxide
# T5 260.15
# C 0.85530355798881
# A R290
# B NitrousOxide
# T5 261.15
# C 0.8546908729562126
# A R290
# B NitrousOxide
# T5 262.15
# C 0.8539191218531584
# A R290
# B NitrousOxide
# T5 263.15
# C 0.8529865475590774
# A R290
# B NitrousOxide
# T5 264.15
# C 0.8518913634683435
# A R290
# B NitrousOxide
# T5 265.15
# C 0.850631748227646
# A R290
# B NitrousOxide
# T5 266.15
# C 0.8492058398661659
# A R290
# B NitrousOxide
# T5 267.15
# C 0.847611729236602
# A R290
# B NitrousOxide
# T5 268.15
# C 0.8458474526872538
# A R290
# B NitrousOxide
# T5 269.15
# C 0.843910983857136
# A R290
# B NitrousOxide
# T5 270.15
# C 0.8418002244780827
# A R290
# B NitrousOxide
# T5 271.15
# C 0.839512994049738
# A R290
# B NitrousOxide
# T5 272.15
# C 0.8370470182086387
# A R290
# B NitrousOxide
# T5 273.15
# C 0.8343999156287685
# A R290
# B NitrousOxide
# T5 274.15
# C 0.8315691831942459
# A R290
# B NitrousOxide
# T5 275.15
# C 0.828552179195886
# A R290
# B NitrousOxide
# T5 276.15
# C 0.8253461042133249
# A R600
# B NitrousOxide
# T5 243.15
# C 0.8686450655254516
# A R600
# B NitrousOxide
# T5 244.15
# C 0.8700126943193954
# A R600
# B NitrousOxide
# T5 245.15
# C 0.8712454769101943
# A R600
# B NitrousOxide
# T5 246.15
# C 0.8723420297432741
# A R600
# B NitrousOxide
# T5 247.15
# C 0.8733009796325814
# A R600
# B NitrousOxide
# T5 248.15
# C 0.8741209628595651
# A R600
# B NitrousOxide
# T5 249.15
# C 0.8748006242587969
# A R600
# B NitrousOxide
# T5 250.15
# C 0.8753386160399704
# A R600
# B NitrousOxide
# T5 251.15
# C 0.8757335965626765
# A R600
# B NitrousOxide
# T5 252.15
# C 0.8759842289336627
# A R600
# B NitrousOxide
# T5 253.15
# C 0.8760892181759761
# A R600
# B NitrousOxide
# T5 254.15
# C 0.8760478775517836
# A R600
# B NitrousOxide
# T5 255.15
# C 0.8758590034035849
# A R600
# B NitrousOxide
# T5 256.15
# C 0.875521134627363
# A R600
# B NitrousOxide
# T5 257.15
# C 0.875032812167708
# A R600
# B NitrousOxide
# T5 258.15
# C 0.8743925762946647
# A R600
# B NitrousOxide
# T5 259.15
# C 0.8735989636195927
# A R600
# B NitrousOxide
# T5 260.15
# C 0.8726505037180414
# A R600
# B NitrousOxide
# T5 261.15
# C 0.8715457154187413
# A R600
# B NitrousOxide
# T5 262.15
# C 0.8702831026850104
# A R600
# B NitrousOxide
# T5 263.15
# C 0.8688611500366242
# A R600
# B NitrousOxide
# T5 264.15
# C 0.8672783174668312
# A R600
# B NitrousOxide
# T5 265.15
# C 0.8655330348205119
# A R600
# B NitrousOxide
# T5 266.15
# C 0.8636236955459897
# A R600
# B NitrousOxide
# T5 267.15
# C 0.8615486497583159
# A R600
# B NitrousOxide
# T5 268.15
# C 0.8593061965157667
# A R600
# B NitrousOxide
# T5 269.15
# C 0.8568945752239802
# A R600
# B NitrousOxide
# T5 270.15
# C 0.8543119560438834
# A R600
# B NitrousOxide
# T5 271.15
# C 0.8515564291465869
# A R600
# B NitrousOxide
# T5 272.15
# C 0.8486259927480764
# A R600
# B NitrousOxide
# T5 273.15
# C 0.8455185395220474
# A R600
# B NitrousOxide
# T5 274.15
# C 0.8422318414355028
# A R600
# B NitrousOxide
# T5 275.15
# C 0.8387635325447561
# A R600
# B NitrousOxide
# T5 276.15
# C 0.8351110894902044
# A R404a
# B NitrousOxide
# T5 243.15
# C 0.7950541581225338
# A R404a
# B NitrousOxide
# T5 244.15
# C 0.7982040098950005
# A R404a
# B NitrousOxide
# T5 245.15
# C 0.8012154699698169
# A R404a
# B NitrousOxide
# T5 246.15
# C 0.8040860145714939
# A R404a
# B NitrousOxide
# T5 247.15
# C 0.8068131438848339
# A R404a
# B NitrousOxide
# T5 248.15
# C 0.809394382401923
# A R404a
# B NitrousOxide
# T5 249.15
# C 0.8118272791129366
# A R404a
# B NitrousOxide
# T5 250.15
# C 0.8141094075283585
# A R404a
# B NitrousOxide
# T5 251.15
# C 0.8162383655196189
# A R404a
# B NitrousOxide
# T5 252.15
# C 0.8182117749642207
# A R404a
# B NitrousOxide
# T5 253.15
# C 0.820027281180053
# A R404a
# B NitrousOxide
# T5 254.15
# C 0.8216825521322108
# A R404a
# B NitrousOxide
# T5 255.15
# C 0.8231752773943126
# A R404a
# B NitrousOxide
# T5 256.15
# C 0.8245031668442407
# A R404a
# B NitrousOxide
# T5 257.15
# C 0.8256639490723272
# A R404a
# B NitrousOxide
# T5 258.15
# C 0.8266553694774867
# A R404a
# B NitrousOxide
# T5 259.15
# C 0.8274751880242684
# A R404a
# B NitrousOxide
# T5 260.15
# C 0.8281211766297766
# A R404a
# B NitrousOxide
# T5 261.15
# C 0.8285911161469165
# A R404a
# B NitrousOxide
# T5 262.15
# C 0.8288827929047212
# A R404a
# B NitrousOxide
# T5 263.15
# C 0.8289939947622152
# A R404a
# B NitrousOxide
# T5 264.15
# C 0.828922506625692
# A R404a
# B NitrousOxide
# T5 265.15
# C 0.8286661053725836
# A R404a
# B NitrousOxide
# T5 266.15
# C 0.8282225541209685
# A R404a
# B NitrousOxide
# T5 267.15
# C 0.8275895957413385
# A R404a
# B NitrousOxide
# T5 268.15
# C 0.8267649455963837
# A R404a
# B NitrousOxide
# T5 269.15
# C 0.8257462833068823
# A R404a
# B NitrousOxide
# T5 270.15
# C 0.8245312435048329
# A R404a
# B NitrousOxide
# T5 271.15
# C 0.8231174054054128
# A R404a
# B NitrousOxide
# T5 272.15
# C 0.8215022810294894
# A R404a
# B NitrousOxide
# T5 273.15
# C 0.8196833019129526
# A R404a
# B NitrousOxide
# T5 274.15
# C 0.8176578040436522
# A R404a
# B NitrousOxide
# T5 275.15
# C 0.8154230107789426
# A R404a
# B NitrousOxide
# T5 276.15
# C 0.8129760134128764
