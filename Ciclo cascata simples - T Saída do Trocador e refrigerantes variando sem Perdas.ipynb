# %%
#Bibliotecas
from CoolProp.CoolProp import PropsSI as COOLPROP
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import get_test_data

#Listas
registro_fluidos = []
COP_lista = []
lista_T3 = []
Wcomp_total_lista = []
cont = []

#Lista de Temperaturas
for T3 in range (-3000 + 27315, 400 + 27315, 100):
    T3 = T3 / 100
    cont.append(T3)

#Características para as curvas do gráfico
lista_cor = ['r','g','b', 'c', 'm']
lista_ls = ['-', '-.', ':']
caracteristicas = []
for ls in lista_ls:
    for cor in lista_cor:
        caracteristicas.append((cor, ls))

#Parâmetros
Pfrig = 120 * 1000 #[W]
T1 = -80 + 273.15 #[K]
T7 = 28 + 273.15 #[K]
N = 0.7 #Eficiência isentrópica
fluid_high_lista = ['R134a', 'R717', 'R290', 'R600', 'R404a']
fluid_low_lista = ['R23', 'R170', 'NitrousOxide']
drop_suc = 12000 #[Pa]
drop_desc = 24000 #[Pa]
DeltaT = 4 #[°C]

#Variação dos refrigerantes e do da Pressão de saída do compressor
for fluid_low in fluid_low_lista:
    for fluid_high in fluid_high_lista:      
        if fluid_low == 'NitrousOxide':
            par_fluido = ('Óxido nitroso', fluid_high)    
        else:
            par_fluido = (fluid_low, fluid_high)
        
        registro_fluidos.append(par_fluido)
         #Temperatura T3
        for T3 in cont:
            P1 = COOLPROP('P', 'T', T1, 'Q', 1, fluid_low) 
            h1 = COOLPROP('H', 'T', T1, 'Q', 1, fluid_low)
            S1 = COOLPROP('S', 'T', T1, 'Q', 1, fluid_low)
            P3 = COOLPROP('P', 'T', T3, 'Q', 0 , fluid_low)
            P2 = P3
    
            S2_ideal = S1    
            h2_ideal = COOLPROP('H', 'S', S2_ideal , 'P', P2, fluid_low)
            h2_real = (h2_ideal - h1)/N + h1

            h3 = COOLPROP('H', 'T', T3, 'Q', 0, fluid_low)
            h4 = h3
            m_flow_low = Pfrig / (h1 - h4)
        
            w_low = h2_real - h1
            Wcomp_low = m_flow_low * w_low

            #Pressão crítica do fluido do ciclo de alta pressão
            P_crit_high = COOLPROP('PCRIT', fluid_high)
            #Ciclo de alta pressão
            h7 = COOLPROP('H', 'T', T7, 'Q', 0, fluid_high)
            P7 = COOLPROP('P', 'T', T7, 'Q', 0, fluid_high)

            T8 = T3 - 5
            h8 = h7
            #Q<>0, mas como o refrigerante se encontra em uma fase saturada a pressão é a mesma para qualquer Q com T=T8
            P8 = COOLPROP('P', 'Q', 0, 'T', T8, fluid_high) 
            P5 = P8
            h5 = COOLPROP('H', 'P', P5, 'Q', 1, fluid_high)
            T5 = COOLPROP('T', 'P', P5, 'Q', 1, fluid_high)           
            s5 = COOLPROP('S', 'P', P5, 'Q', 1, fluid_high)
            s6_ideal = s5
            P6 = P7
            h6_ideal = COOLPROP('H', 'P', P6, 'S', s6_ideal, fluid_high)
            h6_real = (h6_ideal - h5)/N + h5
            
            #Calor trocado no trocador central
            Qcond_low =  m_flow_low * (h2_real - h3)
            #Ciclo superior
            Qevap_high = Qcond_low
            m_flow_high = Qevap_high / (h5 - h8)
            w_high = h6_real - h5
            Wcomp_high = m_flow_high * w_high
            
            Wcomp_total = Wcomp_low + Wcomp_high
            
            if P_crit_high > P6:
                lista_T3.append(T3)
                Wcomp_total_lista.append(Wcomp_total / 1000)
                #COP
                COP = Pfrig / Wcomp_total
                COP_lista.append(COP)
                print("A", fluid_high)
                print("B", fluid_low)
                print("T3", T3)
                print("C", COP)
            else:
                print ('A pressão P6 = {:0.2f} kPa (T3 = {}, fluido inf = {}, fluido sup = {}) é maior do que a ' 
                'pressão crítica do {} logo o ponto não foi incluído no gráfico'.format(P6 / 1000,T3,fluid_low,
                                                                                               fluid_high, fluid_high))

if len(lista_T3) != 0:
    plt.rc('xtick', labelsize = 13)
    plt.rc('ytick', labelsize = 13)
    plt.figure(figsize = [13, 13], dpi = 300)
    for i in range (0, len(Wcomp_total_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T3[j])
            eixo_y.append(Wcomp_total_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1],
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T3', size = 15)
        plt.ylabel('Trabalho total [kW]', size = 15)
    plt.legend(prop={'size' : 13})
    plt.figure(figsize = [13, 13], dpi = 300)
    for i in range (0, len(COP_lista), len(cont)):
        eixo_x = []
        eixo_y = []
        for j in range (i, i + len(cont), 1):
            eixo_x.append(lista_T3[j])
            eixo_y.append(COP_lista[j])
        plt.plot(eixo_x, eixo_y, color = caracteristicas[int(i/len(cont))][0], 
                 linestyle = caracteristicas [int(i/len(cont))][1], 
                 label=registro_fluidos[int(i/len(cont))])
        plt.xlabel('T3', size = 13)
        plt.ylabel('COP', size = 13)
    plt.legend(prop={'size' : 13})
    plt.show()
else:
    print('Todos os pontos são inválidos')
# Out:
# A R134a
# B R23
# T3 243.15
# C 0.801988885843771
# A R134a
# B R23
# T3 244.15
# C 0.8017010457077932
# A R134a
# B R23
# T3 245.15
# C 0.8012125369861909
# A R134a
# B R23
# T3 246.15
# C 0.8005210679716712
# A R134a
# B R23
# T3 247.15
# C 0.7996243836470287
# A R134a
# B R23
# T3 248.15
# C 0.7985202646028234
# A R134a
# B R23
# T3 249.15
# C 0.7972065255957839
# A R134a
# B R23
# T3 250.15
# C 0.7956810136980519
# A R134a
# B R23
# T3 251.15
# C 0.7939416060294158
# A R134a
# B R23
# T3 252.15
# C 0.7919862069905991
# A R134a
# B R23
# T3 253.15
# C 0.7898127449686498
# A R134a
# B R23
# T3 254.15
# C 0.7874191684534864
# A R134a
# B R23
# T3 255.15
# C 0.7848034414977999
# A R134a
# B R23
# T3 256.15
# C 0.7819635384478671
# A R134a
# B R23
# T3 257.15
# C 0.778897437860617
# A R134a
# B R23
# T3 258.15
# C 0.7756031155157889
# A R134a
# B R23
# T3 259.15
# C 0.7720785363622662
# A R134a
# B R23
# T3 260.15
# C 0.7683216454022727
# A R134a
# B R23
# T3 261.15
# C 0.7643303571658071
# A R134a
# B R23
# T3 262.15
# C 0.7601025437550403
# A R134a
# B R23
# T3 263.15
# C 0.7556360211825534
# A R134a
# B R23
# T3 264.15
# C 0.7509285337633506
# A R134a
# B R23
# T3 265.15
# C 0.7459777362707015
# A R134a
# B R23
# T3 266.15
# C 0.7407811734994695
# A R134a
# B R23
# T3 267.15
# C 0.7353362568170323
# A R134a
# B R23
# T3 268.15
# C 0.7296402371901974
# A R134a
# B R23
# T3 269.15
# C 0.723690174067583
# A R134a
# B R23
# T3 270.15
# C 0.7174828993516009
# A R134a
# B R23
# T3 271.15
# C 0.7110149755768795
# A R134a
# B R23
# T3 272.15
# C 0.7042826469987641
# A R134a
# B R23
# T3 273.15
# C 0.6972817823531191
# A R134a
# B R23
# T3 274.15
# C 0.6900078072889639
# A R134a
# B R23
# T3 275.15
# C 0.682455624232342
# A R134a
# B R23
# T3 276.15
# C 0.6746195167656992
# A R717
# B R23
# T3 243.15
# C 0.8185407958370492
# A R717
# B R23
# T3 244.15
# C 0.8179228557667981
# A R717
# B R23
# T3 245.15
# C 0.8170949214726719
# A R717
# B R23
# T3 246.15
# C 0.816055459745191
# A R717
# B R23
# T3 247.15
# C 0.8148029749193053
# A R717
# B R23
# T3 248.15
# C 0.8133360062485208
# A R717
# B R23
# T3 249.15
# C 0.8116531249419195
# A R717
# B R23
# T3 250.15
# C 0.809752930797481
# A R717
# B R23
# T3 251.15
# C 0.8076340484412537
# A R717
# B R23
# T3 252.15
# C 0.8052951230930078
# A R717
# B R23
# T3 253.15
# C 0.8027348158292684
# A R717
# B R23
# T3 254.15
# C 0.7999517982789051
# A R717
# B R23
# T3 255.15
# C 0.7969447467074382
# A R717
# B R23
# T3 256.15
# C 0.7937123353951129
# A R717
# B R23
# T3 257.15
# C 0.7902532292476498
# A R717
# B R23
# T3 258.15
# C 0.7865660755395608
# A R717
# B R23
# T3 259.15
# C 0.782649494675961
# A R717
# B R23
# T3 260.15
# C 0.7785020698461136
# A R717
# B R23
# T3 261.15
# C 0.7741223354286149
# A R717
# B R23
# T3 262.15
# C 0.7695087639615912
# A R717
# B R23
# T3 263.15
# C 0.7646597515287791
# A R717
# B R23
# T3 264.15
# C 0.7595736009719508
# A R717
# B R23
# T3 265.15
# C 0.7542485036452918
# A R717
# B R23
# T3 266.15
# C 0.7486825176960259
# A R717
# B R23
# T3 267.15
# C 0.7428735441143981
# A R717
# B R23
# T3 268.15
# C 0.7368192990416752
# A R717
# B R23
# T3 269.15
# C 0.7305172820601563
# A R717
# B R23
# T3 270.15
# C 0.7239647396420708
# A R717
# B R23
# T3 271.15
# C 0.7171586228854987
# A R717
# B R23
# T3 272.15
# C 0.7100955382344765
# A R717
# B R23
# T3 273.15
# C 0.702771689948777
# A R717
# B R23
# T3 274.15
# C 0.6951828123248173
# A R717
# B R23
# T3 275.15
# C 0.6873240894393767
# A R717
# B R23
# T3 276.15
# C 0.6791900594229422
# A R290
# B R23
# T3 243.15
# C 0.7986869105871104
# A R290
# B R23
# T3 244.15
# C 0.7983510224105618
# A R290
# B R23
# T3 245.15
# C 0.7978203534830861
# A R290
# B R23
# T3 246.15
# C 0.7970925920830924
# A R290
# B R23
# T3 247.15
# C 0.7961654533287956
# A R290
# B R23
# T3 248.15
# C 0.7950366781666421
# A R290
# B R23
# T3 249.15
# C 0.793704032024149
# A R290
# B R23
# T3 250.15
# C 0.7921653030765219
# A R290
# B R23
# T3 251.15
# C 0.7904183001119893
# A R290
# B R23
# T3 252.15
# C 0.7884608499274542
# A R290
# B R23
# T3 253.15
# C 0.7862907942063905
# A R290
# B R23
# T3 254.15
# C 0.7839059858325228
# A R290
# B R23
# T3 255.15
# C 0.781304284564941
# A R290
# B R23
# T3 256.15
# C 0.7784835520046864
# A R290
# B R23
# T3 257.15
# C 0.7754416457521787
# A R290
# B R23
# T3 258.15
# C 0.772176412692753
# A R290
# B R23
# T3 259.15
# C 0.7686856812506025
# A R290
# B R23
# T3 260.15
# C 0.7649672525184831
# A R290
# B R23
# T3 261.15
# C 0.7610188900826551
# A R290
# B R23
# T3 262.15
# C 0.7568383083848176
# A R290
# B R23
# T3 263.15
# C 0.7524231593937254
# A R290
# B R23
# T3 264.15
# C 0.7477710173478929
# A R290
# B R23
# T3 265.15
# C 0.7428793612675942
# A R290
# B R23
# T3 266.15
# C 0.7377455548871229
# A R290
# B R23
# T3 267.15
# C 0.732366823578399
# A R290
# B R23
# T3 268.15
# C 0.7267402277604768
# A R290
# B R23
# T3 269.15
# C 0.7208626321679381
# A R290
# B R23
# T3 270.15
# C 0.7147306702131534
# A R290
# B R23
# T3 271.15
# C 0.7083407025587367
# A R290
# B R23
# T3 272.15
# C 0.7016887686020279
# A R290
# B R23
# T3 273.15
# C 0.6947705296290492
# A R290
# B R23
# T3 274.15
# C 0.68758120164424
# A R290
# B R23
# T3 275.15
# C 0.6801154756426537
# A R290
# B R23
# T3 276.15
# C 0.6723674223308517
# A R600
# B R23
# T3 243.15
# C 0.822366766693782
# A R600
# B R23
# T3 244.15
# C 0.8215116089506529
# A R600
# B R23
# T3 245.15
# C 0.8204585948707849
# A R600
# B R23
# T3 246.15
# C 0.8192058446063782
# A R600
# B R23
# T3 247.15
# C 0.8177515073480462
# A R600
# B R23
# T3 248.15
# C 0.816093759732943
# A R600
# B R23
# T3 249.15
# C 0.814230804009434
# A R600
# B R23
# T3 250.15
# C 0.8121608656904644
# A R600
# B R23
# T3 251.15
# C 0.8098821908919376
# A R600
# B R23
# T3 252.15
# C 0.8073930431693748
# A R600
# B R23
# T3 253.15
# C 0.8046917340756803
# A R600
# B R23
# T3 254.15
# C 0.8017771173672626
# A R600
# B R23
# T3 255.15
# C 0.7986475878626589
# A R600
# B R23
# T3 256.15
# C 0.7953013149806867
# A R600
# B R23
# T3 257.15
# C 0.7917364688909749
# A R600
# B R23
# T3 258.15
# C 0.7879512131491105
# A R600
# B R23
# T3 259.15
# C 0.7839436963450587
# A R600
# B R23
# T3 260.15
# C 0.7797120425448875
# A R600
# B R23
# T3 261.15
# C 0.7752543404556251
# A R600
# B R23
# T3 262.15
# C 0.7705686311034078
# A R600
# B R23
# T3 263.15
# C 0.7656528938093782
# A R600
# B R23
# T3 264.15
# C 0.7605050302191663
# A R600
# B R23
# T3 265.15
# C 0.7551228461112163
# A R600
# B R23
# T3 266.15
# C 0.7495040306133725
# A R600
# B R23
# T3 267.15
# C 0.7436461324166783
# A R600
# B R23
# T3 268.15
# C 0.7375465324671614
# A R600
# B R23
# T3 269.15
# C 0.7312024125282869
# A R600
# B R23
# T3 270.15
# C 0.7246107188435839
# A R600
# B R23
# T3 271.15
# C 0.7177681199999846
# A R600
# B R23
# T3 272.15
# C 0.7106709577798703
# A R600
# B R23
# T3 273.15
# C 0.7033151895756978
# A R600
# B R23
# T3 274.15
# C 0.6956963206098944
# A R600
# B R23
# T3 275.15
# C 0.6878093235592313
# A R600
# B R23
# T3 276.15
# C 0.6796485426496226
# A R404a
# B R23
# T3 243.15
# C 0.7542790948456424
# A R404a
# B R23
# T3 244.15
# C 0.7553230126965474
# A R404a
# B R23
# T3 245.15
# C 0.7561603953003154
# A R404a
# B R23
# T3 246.15
# C 0.7567879273101302
# A R404a
# B R23
# T3 247.15
# C 0.7572023455444122
# A R404a
# B R23
# T3 248.15
# C 0.7574004394578729
# A R404a
# B R23
# T3 249.15
# C 0.7573790512205265
# A R404a
# B R23
# T3 250.15
# C 0.7571350753513152
# A R404a
# B R23
# T3 251.15
# C 0.7566654578881131
# A R404a
# B R23
# T3 252.15
# C 0.7559671950138621
# A R404a
# B R23
# T3 253.15
# C 0.7550373311050895
# A R404a
# B R23
# T3 254.15
# C 0.7538729561346688
# A R404a
# B R23
# T3 255.15
# C 0.7524712023602433
# A R404a
# B R23
# T3 256.15
# C 0.7508292402216727
# A R404a
# B R23
# T3 257.15
# C 0.7489442733592444
# A R404a
# B R23
# T3 258.15
# C 0.7468135326515845
# A R404a
# B R23
# T3 259.15
# C 0.7444342691590959
# A R404a
# B R23
# T3 260.15
# C 0.7418037458379897
# A R404a
# B R23
# T3 261.15
# C 0.738919227872115
# A R404a
# B R23
# T3 262.15
# C 0.7357779714408472
# A R404a
# B R23
# T3 263.15
# C 0.7323772107125311
# A R404a
# B R23
# T3 264.15
# C 0.728714142813267
# A R404a
# B R23
# T3 265.15
# C 0.7247859104758171
# A R404a
# B R23
# T3 266.15
# C 0.7205895820191188
# A R404a
# B R23
# T3 267.15
# C 0.7161221282125013
# A R404a
# B R23
# T3 268.15
# C 0.7113803955736968
# A R404a
# B R23
# T3 269.15
# C 0.7063610753976066
# A R404a
# B R23
# T3 270.15
# C 0.7010606678158073
# A R404a
# B R23
# T3 271.15
# C 0.6954754399753099
# A R404a
# B R23
# T3 272.15
# C 0.6896013770524835
# A R404a
# B R23
# T3 273.15
# C 0.6834341248561497
# A R404a
# B R23
# T3 274.15
# C 0.6769689220331704
# A R404a
# B R23
# T3 275.15
# C 0.6702005196459324
# A R404a
# B R23
# T3 276.15
# C 0.6631230851379981
# A R134a
# B R170
# T3 243.15
# C 0.809904778285052
# A R134a
# B R170
# T3 244.15
# C 0.8098658542673896
# A R134a
# B R170
# T3 245.15
# C 0.8096256785310748
# A R134a
# B R170
# T3 246.15
# C 0.8091817740665685
# A R134a
# B R170
# T3 247.15
# C 0.8085317142525433
# A R134a
# B R170
# T3 248.15
# C 0.8076731231897305
# A R134a
# B R170
# T3 249.15
# C 0.8066036757910465
# A R134a
# B R170
# T3 250.15
# C 0.8053210976076041
# A R134a
# B R170
# T3 251.15
# C 0.8038231643743932
# A R134a
# B R170
# T3 252.15
# C 0.8021077012481226
# A R134a
# B R170
# T3 253.15
# C 0.8001725817103132
# A R134a
# B R170
# T3 254.15
# C 0.7980157261092737
# A R134a
# B R170
# T3 255.15
# C 0.7956350997943158
# A R134a
# B R170
# T3 256.15
# C 0.7930287108705166
# A R134a
# B R170
# T3 257.15
# C 0.7901946073415588
# A R134a
# B R170
# T3 258.15
# C 0.7871308738796818
# A R134a
# B R170
# T3 259.15
# C 0.7838356278697274
# A R134a
# B R170
# T3 260.15
# C 0.7803070149125202
# A R134a
# B R170
# T3 261.15
# C 0.7765432034902545
# A R134a
# B R170
# T3 262.15
# C 0.7725423788725126
# A R134a
# B R170
# T3 263.15
# C 0.7683027361017837
# A R134a
# B R170
# T3 264.15
# C 0.7638224719647496
# A R134a
# B R170
# T3 265.15
# C 0.7590997758673644
# A R134a
# B R170
# T3 266.15
# C 0.7541328193444983
# A R134a
# B R170
# T3 267.15
# C 0.7489197443511858
# A R134a
# B R170
# T3 268.15
# C 0.7434586498477479
# A R134a
# B R170
# T3 269.15
# C 0.737747576682943
# A R134a
# B R170
# T3 270.15
# C 0.7317844904838882
# A R134a
# B R170
# T3 271.15
# C 0.7255672622767769
# A R134a
# B R170
# T3 272.15
# C 0.7190936464918355
# A R134a
# B R170
# T3 273.15
# C 0.7123612559251654
# A R134a
# B R170
# T3 274.15
# C 0.7053675331157093
# A R134a
# B R170
# T3 275.15
# C 0.6981097174523258
# A R134a
# B R170
# T3 276.15
# C 0.6905848072399976
# A R717
# B R170
# T3 243.15
# C 0.8266950112510817
# A R717
# B R170
# T3 244.15
# C 0.8263286439961206
# A R717
# B R170
# T3 245.15
# C 0.8257512919852382
# A R717
# B R170
# T3 246.15
# C 0.8249612333150604
# A R717
# B R170
# T3 247.15
# C 0.823956799124932
# A R717
# B R170
# T3 248.15
# C 0.8227363723643745
# A R717
# B R170
# T3 249.15
# C 0.8212983863306714
# A R717
# B R170
# T3 250.15
# C 0.8196413229398651
# A R717
# B R170
# T3 251.15
# C 0.8177637107322219
# A R717
# B R170
# T3 252.15
# C 0.8156641225885072
# A R717
# B R170
# T3 253.15
# C 0.8133411731297697
# A R717
# B R170
# T3 254.15
# C 0.8107935157708439
# A R717
# B R170
# T3 255.15
# C 0.8080198394054817
# A R717
# B R170
# T3 256.15
# C 0.8050188647303094
# A R717
# B R170
# T3 257.15
# C 0.8017893399952671
# A R717
# B R170
# T3 258.15
# C 0.7983300364172436
# A R717
# B R170
# T3 259.15
# C 0.7946397429465276
# A R717
# B R170
# T3 260.15
# C 0.7907172604411087
# A R717
# B R170
# T3 261.15
# C 0.7865613951633738
# A R717
# B R170
# T3 262.15
# C 0.7821709515084957
# A R717
# B R170
# T3 263.15
# C 0.7775447239337921
# A R717
# B R170
# T3 264.15
# C 0.7726814876381338
# A R717
# B R170
# T3 265.15
# C 0.7675799889405768
# A R717
# B R170
# T3 266.15
# C 0.7622389333879694
# A R717
# B R170
# T3 267.15
# C 0.7566569734475981
# A R717
# B R170
# T3 268.15
# C 0.7508326942687095
# A R717
# B R170
# T3 269.15
# C 0.7447645978741892
# A R717
# B R170
# T3 270.15
# C 0.7384510854324121
# A R717
# B R170
# T3 271.15
# C 0.7318904373450786
# A R717
# B R170
# T3 272.15
# C 0.7250807908003444
# A R717
# B R170
# T3 273.15
# C 0.7180201143661379
# A R717
# B R170
# T3 274.15
# C 0.7107061790846888
# A R717
# B R170
# T3 275.15
# C 0.7031365253964477
# A R717
# B R170
# T3 276.15
# C 0.6953084250434732
# A R290
# B R170
# T3 243.15
# C 0.8065556237284157
# A R290
# B R170
# T3 244.15
# C 0.8064664415270055
# A R290
# B R170
# T3 245.15
# C 0.8061819328117078
# A R290
# B R170
# T3 246.15
# C 0.8056996080285518
# A R290
# B R170
# T3 247.15
# C 0.8050170179430156
# A R290
# B R170
# T3 248.15
# C 0.8041317540082645
# A R290
# B R170
# T3 249.15
# C 0.8030414485148009
# A R290
# B R170
# T3 250.15
# C 0.801743774500411
# A R290
# B R170
# T3 251.15
# C 0.8002364453971702
# A R290
# B R170
# T3 252.15
# C 0.7985172144016537
# A R290
# B R170
# T3 253.15
# C 0.7965838735222703
# A R290
# B R170
# T3 254.15
# C 0.7944342522921295
# A R290
# B R170
# T3 255.15
# C 0.7920662160943224
# A R290
# B R170
# T3 256.15
# C 0.7894776641301399
# A R290
# B R170
# T3 257.15
# C 0.7866665267827849
# A R290
# B R170
# T3 258.15
# C 0.7836307626428872
# A R290
# B R170
# T3 259.15
# C 0.7803683548457883
# A R290
# B R170
# T3 260.15
# C 0.7768773068067749
# A R290
# B R170
# T3 261.15
# C 0.773155637227823
# A R290
# B R170
# T3 262.15
# C 0.769201374313646
# A R290
# B R170
# T3 263.15
# C 0.7650125490857644
# A R290
# B R170
# T3 264.15
# C 0.76058718770235
# A R290
# B R170
# T3 265.15
# C 0.7559233026895146
# A R290
# B R170
# T3 266.15
# C 0.7510188828229843
# A R290
# B R170
# T3 267.15
# C 0.7458718817960232
# A R290
# B R170
# T3 268.15
# C 0.7404802051938731
# A R290
# B R170
# T3 269.15
# C 0.7348416957707173
# A R290
# B R170
# T3 270.15
# C 0.728954116738763
# A R290
# B R170
# T3 271.15
# C 0.7228151327928402
# A R290
# B R170
# T3 272.15
# C 0.7164222885209586
# A R290
# B R170
# T3 273.15
# C 0.7097729837703393
# A R290
# B R170
# T3 274.15
# C 0.7028644454306627
# A R290
# B R170
# T3 275.15
# C 0.6956936949580644
# A R290
# B R170
# T3 276.15
# C 0.6882575107875605
# A R600
# B R170
# T3 243.15
# C 0.8305765036663995
# A R600
# B R170
# T3 244.15
# C 0.829971117035046
# A R600
# B R170
# T3 245.15
# C 0.8291668611983213
# A R600
# B R170
# T3 246.15
# C 0.8281616773404765
# A R600
# B R170
# T3 247.15
# C 0.8269535506621877
# A R600
# B R170
# T3 248.15
# C 0.8255405101474911
# A R600
# B R170
# T3 249.15
# C 0.8239206282019695
# A R600
# B R170
# T3 250.15
# C 0.8220920199209476
# A R600
# B R170
# T3 251.15
# C 0.82005284217834
# A R600
# B R170
# T3 252.15
# C 0.8178012924034469
# A R600
# B R170
# T3 253.15
# C 0.815335641927734
# A R600
# B R170
# T3 254.15
# C 0.8126547424442344
# A R600
# B R170
# T3 255.15
# C 0.8097570086725564
# A R600
# B R170
# T3 256.15
# C 0.8066406586815704
# A R600
# B R170
# T3 257.15
# C 0.8033039475659123
# A R600
# B R170
# T3 258.15
# C 0.7997451637864776
# A R600
# B R170
# T3 259.15
# C 0.7959626248622298
# A R600
# B R170
# T3 260.15
# C 0.7919546723731645
# A R600
# B R170
# T3 261.15
# C 0.7877196662598726
# A R600
# B R170
# T3 262.15
# C 0.7832559783049141
# A R600
# B R170
# T3 263.15
# C 0.7785619846968869
# A R600
# B R170
# T3 264.15
# C 0.7736360575795764
# A R600
# B R170
# T3 265.15
# C 0.7684765555206654
# A R600
# B R170
# T3 266.15
# C 0.7630818126141963
# A R600
# B R170
# T3 267.15
# C 0.7574501263786839
# A R600
# B R170
# T3 268.15
# C 0.7515797439499905
# A R600
# B R170
# T3 269.15
# C 0.7454688465909105
# A R600
# B R170
# T3 270.15
# C 0.7391155322209896
# A R600
# B R170
# T3 271.15
# C 0.7325177956736614
# A R600
# B R170
# T3 272.15
# C 0.7256735064233657
# A R600
# B R170
# T3 273.15
# C 0.7185803831598485
# A R600
# B R170
# T3 274.15
# C 0.7112359649188893
# A R600
# B R170
# T3 275.15
# C 0.7036375779198943
# A R600
# B R170
# T3 276.15
# C 0.6957822973211291
# A R404a
# B R170
# T3 243.15
# C 0.7615250677760282
# A R404a
# B R170
# T3 244.15
# C 0.7628155126688159
# A R404a
# B R170
# T3 245.15
# C 0.7638998356234086
# A R404a
# B R170
# T3 246.15
# C 0.7647745239645352
# A R404a
# B R170
# T3 247.15
# C 0.7654361277347521
# A R404a
# B R170
# T3 248.15
# C 0.7658812617002175
# A R404a
# B R170
# T3 249.15
# C 0.7661066070882568
# A R404a
# B R170
# T3 250.15
# C 0.7661089130313473
# A R404a
# B R170
# T3 251.15
# C 0.7658849976922334
# A R404a
# B R170
# T3 252.15
# C 0.7654317490414229
# A R404a
# B R170
# T3 253.15
# C 0.7647461252564322
# A R404a
# B R170
# T3 254.15
# C 0.7638251547080795
# A R404a
# B R170
# T3 255.15
# C 0.7626659354865284
# A R404a
# B R170
# T3 256.15
# C 0.7612656344868334
# A R404a
# B R170
# T3 257.15
# C 0.759621485828603
# A R404a
# B R170
# T3 258.15
# C 0.7577307888214211
# A R404a
# B R170
# T3 259.15
# C 0.755590905185008
# A R404a
# B R170
# T3 260.15
# C 0.7531992555604187
# A R404a
# B R170
# T3 261.15
# C 0.7505533152147568
# A R404a
# B R170
# T3 262.15
# C 0.7476506088523914
# A R404a
# B R170
# T3 263.15
# C 0.7444887044376785
# A R404a
# B R170
# T3 264.15
# C 0.7410652059239772
# A R404a
# B R170
# T3 265.15
# C 0.7373777447991938
# A R404a
# B R170
# T3 266.15
# C 0.7334239701898515
# A R404a
# B R170
# T3 267.15
# C 0.7292015376304536
# A R404a
# B R170
# T3 268.15
# C 0.7247080960845423
# A R404a
# B R170
# T3 269.15
# C 0.7199412731270293
# A R404a
# B R170
# T3 270.15
# C 0.7148986580649224
# A R404a
# B R170
# T3 271.15
# C 0.7095777826916146
# A R404a
# B R170
# T3 272.15
# C 0.7039760993350958
# A R404a
# B R170
# T3 273.15
# C 0.6980909557712898
# A R404a
# B R170
# T3 274.15
# C 0.6919195664662151
# A R404a
# B R170
# T3 275.15
# C 0.6854589794751931
# A R404a
# B R170
# T3 276.15
# C 0.6787060381558145
# A R134a
# B NitrousOxide
# T3 243.15
# C 0.7984824190894824
# A R134a
# B NitrousOxide
# T3 244.15
# C 0.7983970817939476
# A R134a
# B NitrousOxide
# T3 245.15
# C 0.798141289475899
# A R134a
# B NitrousOxide
# T3 246.15
# C 0.7977141694914206
# A R134a
# B NitrousOxide
# T3 247.15
# C 0.7971149050679419
# A R134a
# B NitrousOxide
# T3 248.15
# C 0.7963427345813766
# A R134a
# B NitrousOxide
# T3 249.15
# C 0.7953969506399822
# A R134a
# B NitrousOxide
# T3 250.15
# C 0.7942768989832695
# A R134a
# B NitrousOxide
# T3 251.15
# C 0.792981977183272
# A R134a
# B NitrousOxide
# T3 252.15
# C 0.7915116331350321
# A R134a
# B NitrousOxide
# T3 253.15
# C 0.7898653633234644
# A R134a
# B NitrousOxide
# T3 254.15
# C 0.7880427108572905
# A R134a
# B NitrousOxide
# T3 255.15
# C 0.7860432632528747
# A R134a
# B NitrousOxide
# T3 256.15
# C 0.7838666499524086
# A R134a
# B NitrousOxide
# T3 257.15
# C 0.7815125395589904
# A R134a
# B NitrousOxide
# T3 258.15
# C 0.7789806367753916
# A R134a
# B NitrousOxide
# T3 259.15
# C 0.776270678974201
# A R134a
# B NitrousOxide
# T3 260.15
# C 0.7733824325102252
# A R134a
# B NitrousOxide
# T3 261.15
# C 0.7703156885484297
# A R134a
# B NitrousOxide
# T3 262.15
# C 0.7670702585342654
# A R134a
# B NitrousOxide
# T3 263.15
# C 0.7636459692010095
# A R134a
# B NitrousOxide
# T3 264.15
# C 0.7600426570792764
# A R134a
# B NitrousOxide
# T3 265.15
# C 0.7562601624630075
# A R134a
# B NitrousOxide
# T3 266.15
# C 0.7522983227700343
# A R134a
# B NitrousOxide
# T3 267.15
# C 0.7481569652327504
# A R134a
# B NitrousOxide
# T3 268.15
# C 0.7438358988397265
# A R134a
# B NitrousOxide
# T3 269.15
# C 0.7393349054372726
# A R134a
# B NitrousOxide
# T3 270.15
# C 0.7346537298839683
# A R134a
# B NitrousOxide
# T3 271.15
# C 0.7297920691334949
# A R134a
# B NitrousOxide
# T3 272.15
# C 0.7247495600964673
# A R134a
# B NitrousOxide
# T3 273.15
# C 0.7195257661084926
# A R134a
# B NitrousOxide
# T3 274.15
# C 0.7141201617929281
# A R134a
# B NitrousOxide
# T3 275.15
# C 0.7085321160582791
# A R134a
# B NitrousOxide
# T3 276.15
# C 0.7027608730089067
# A R717
# B NitrousOxide
# T3 243.15
# C 0.8149292327606625
# A R717
# B NitrousOxide
# T3 244.15
# C 0.8145218153411161
# A R717
# B NitrousOxide
# T3 245.15
# C 0.8139352817371169
# A R717
# B NitrousOxide
# T3 246.15
# C 0.8131694926456724
# A R717
# B NitrousOxide
# T3 247.15
# C 0.8122243617991199
# A R717
# B NitrousOxide
# T3 248.15
# C 0.8110998538314788
# A R717
# B NitrousOxide
# T3 249.15
# C 0.8097959819937024
# A R717
# B NitrousOxide
# T3 250.15
# C 0.8083128057095398
# A R717
# B NitrousOxide
# T3 251.15
# C 0.8066504279747089
# A R717
# B NitrousOxide
# T3 252.15
# C 0.8048089925886429
# A R717
# B NitrousOxide
# T3 253.15
# C 0.8027886812040437
# A R717
# B NitrousOxide
# T3 254.15
# C 0.8005897101799437
# A R717
# B NitrousOxide
# T3 255.15
# C 0.7982123272436772
# A R717
# B NitrousOxide
# T3 256.15
# C 0.7956568079222119
# A R717
# B NitrousOxide
# T3 257.15
# C 0.7929234517474203
# A R717
# B NitrousOxide
# T3 258.15
# C 0.7900125782115083
# A R717
# B NitrousOxide
# T3 259.15
# C 0.7869245224457536
# A R717
# B NitrousOxide
# T3 260.15
# C 0.7836596306004715
# A R717
# B NitrousOxide
# T3 261.15
# C 0.7802182549064522
# A R717
# B NitrousOxide
# T3 262.15
# C 0.7766007483757073
# A R717
# B NitrousOxide
# T3 263.15
# C 0.7728074591625019
# A R717
# B NitrousOxide
# T3 264.15
# C 0.7688387241933868
# A R717
# B NitrousOxide
# T3 265.15
# C 0.764694863039667
# A R717
# B NitrousOxide
# T3 266.15
# C 0.7603761702839036
# A R717
# B NitrousOxide
# T3 267.15
# C 0.7558829080027815
# A R717
# B NitrousOxide
# T3 268.15
# C 0.7512152972704512
# A R717
# B NitrousOxide
# T3 269.15
# C 0.74637350893968
# A R717
# B NitrousOxide
# T3 270.15
# C 0.7413576535342783
# A R717
# B NitrousOxide
# T3 271.15
# C 0.7361677701377566
# A R717
# B NitrousOxide
# T3 272.15
# C 0.7308038141229489
# A R717
# B NitrousOxide
# T3 273.15
# C 0.7252656435505357
# A R717
# B NitrousOxide
# T3 274.15
# C 0.7195530040265316
# A R717
# B NitrousOxide
# T3 275.15
# C 0.7136655117712268
# A R717
# B NitrousOxide
# T3 276.15
# C 0.7076026345970288
# A R290
# B NitrousOxide
# T3 243.15
# C 0.7952012516645633
# A R290
# B NitrousOxide
# T3 244.15
# C 0.7950669570312456
# A R290
# B NitrousOxide
# T3 245.15
# C 0.7947678465457377
# A R290
# B NitrousOxide
# T3 246.15
# C 0.7943030182641077
# A R290
# B NitrousOxide
# T3 247.15
# C 0.7936716173698205
# A R290
# B NitrousOxide
# T3 248.15
# C 0.7928728356020355
# A R290
# B NitrousOxide
# T3 249.15
# C 0.7919059105098709
# A R290
# B NitrousOxide
# T3 250.15
# C 0.7907701245396008
# A R290
# B NitrousOxide
# T3 251.15
# C 0.7894648039347243
# A R290
# B NitrousOxide
# T3 252.15
# C 0.787989317448662
# A R290
# B NitrousOxide
# T3 253.15
# C 0.7863430748379712
# A R290
# B NitrousOxide
# T3 254.15
# C 0.7845255251408345
# A R290
# B NitrousOxide
# T3 255.15
# C 0.7825361547168381
# A R290
# B NitrousOxide
# T3 256.15
# C 0.7803744850347212
# A R290
# B NitrousOxide
# T3 257.15
# C 0.7780400701743897
# A R290
# B NitrousOxide
# T3 258.15
# C 0.7755324940582882
# A R290
# B NitrousOxide
# T3 259.15
# C 0.772851367341043
# A R290
# B NitrousOxide
# T3 260.15
# C 0.7699963239711354
# A R290
# B NitrousOxide
# T3 261.15
# C 0.7669670173658871
# A R290
# B NitrousOxide
# T3 262.15
# C 0.7637631161878726
# A R290
# B NitrousOxide
# T3 263.15
# C 0.7603842996663848
# A R290
# B NitrousOxide
# T3 264.15
# C 0.7568302524306826
# A R290
# B NitrousOxide
# T3 265.15
# C 0.7531006587974212
# A R290
# B NitrousOxide
# T3 266.15
# C 0.7491951964578675
# A R290
# B NitrousOxide
# T3 267.15
# C 0.7451135294913966
# A R290
# B NitrousOxide
# T3 268.15
# C 0.7408553006325252
# A R290
# B NitrousOxide
# T3 269.15
# C 0.736420122694039
# A R290
# B NitrousOxide
# T3 270.15
# C 0.731807569040225
# A R290
# B NitrousOxide
# T3 271.15
# C 0.7270171629854809
# A R290
# B NitrousOxide
# T3 272.15
# C 0.7220483659665168
# A R290
# B NitrousOxide
# T3 273.15
# C 0.7169005643127172
# A R290
# B NitrousOxide
# T3 274.15
# C 0.711573054407104
# A R290
# B NitrousOxide
# T3 275.15
# C 0.7060650259870453
# A R290
# B NitrousOxide
# T3 276.15
# C 0.700375543280713
# A R600
# B NitrousOxide
# T3 243.15
# C 0.8187307226639003
# A R600
# B NitrousOxide
# T3 244.15
# C 0.8180889306334729
# A R600
# B NitrousOxide
# T3 245.15
# C 0.8172800978634175
# A R600
# B NitrousOxide
# T3 246.15
# C 0.8163037282941591
# A R600
# B NitrousOxide
# T3 247.15
# C 0.8151593716485
# A R600
# B NitrousOxide
# T3 248.15
# C 0.8138466223472034
# A R600
# B NitrousOxide
# T3 249.15
# C 0.8123651183541202
# A R600
# B NitrousOxide
# T3 250.15
# C 0.8107145397427261
# A R600
# B NitrousOxide
# T3 251.15
# C 0.8088946071728628
# A R600
# B NitrousOxide
# T3 252.15
# C 0.8069050801607468
# A R600
# B NitrousOxide
# T3 253.15
# C 0.8047457893830541
# A R600
# B NitrousOxide
# T3 254.15
# C 0.8024171337428194
# A R600
# B NitrousOxide
# T3 255.15
# C 0.7999190825351682
# A R600
# B NitrousOxide
# T3 256.15
# C 0.7972514104748617
# A R600
# B NitrousOxide
# T3 257.15
# C 0.7944139271257769
# A R600
# B NitrousOxide
# T3 258.15
# C 0.791406473631383
# A R600
# B NitrousOxide
# T3 259.15
# C 0.788228919160248
# A R600
# B NitrousOxide
# T3 260.15
# C 0.7848811569521263
# A R600
# B NitrousOxide
# T3 261.15
# C 0.7813631000163009
# A R600
# B NitrousOxide
# T3 262.15
# C 0.7776746764180266
# A R600
# B NitrousOxide
# T3 263.15
# C 0.7738158241079357
# A R600
# B NitrousOxide
# T3 264.15
# C 0.7697864852548376
# A R600
# B NitrousOxide
# T3 265.15
# C 0.7655866000510694
# A R600
# B NitrousOxide
# T3 266.15
# C 0.7612160999135027
# A R600
# B NitrousOxide
# T3 267.15
# C 0.7566749000241407
# A R600
# B NitrousOxide
# T3 268.15
# C 0.751962891122759
# A R600
# B NitrousOxide
# T3 269.15
# C 0.7470799304735493
# A R600
# B NitrousOxide
# T3 270.15
# C 0.7420258318936991
# A R600
# B NitrousOxide
# T3 271.15
# C 0.7368003547011617
# A R600
# B NitrousOxide
# T3 272.15
# C 0.7314031915213954
# A R600
# B NitrousOxide
# T3 273.15
# C 0.7258339545829229
# A R600
# B NitrousOxide
# T3 274.15
# C 0.7200921605425349
# A R600
# B NitrousOxide
# T3 275.15
# C 0.7141772134145602
# A R600
# B NitrousOxide
# T3 276.15
# C 0.7080883853632028
# A R404a
# B NitrousOxide
# T3 243.15
# C 0.7510681687944479
# A R404a
# B NitrousOxide
# T3 244.15
# C 0.7522899879602835
# A R404a
# B NitrousOxide
# T3 245.15
# C 0.7533340718174916
# A R404a
# B NitrousOxide
# T3 246.15
# C 0.7541986041599565
# A R404a
# B NitrousOxide
# T3 247.15
# C 0.7548818462021825
# A R404a
# B NitrousOxide
# T3 248.15
# C 0.7553821370658932
# A R404a
# B NitrousOxide
# T3 249.15
# C 0.7556978940179472
# A R404a
# B NitrousOxide
# T3 250.15
# C 0.7558276124635872
# A R404a
# B NitrousOxide
# T3 251.15
# C 0.7557698656762096
# A R404a
# B NitrousOxide
# T3 252.15
# C 0.7555233042514278
# A R404a
# B NitrousOxide
# T3 253.15
# C 0.7550866552713192
# A R404a
# B NitrousOxide
# T3 254.15
# C 0.7544587211637649
# A R404a
# B NitrousOxide
# T3 255.15
# C 0.7536383782409437
# A R404a
# B NitrousOxide
# T3 256.15
# C 0.7526245748994072
# A R404a
# B NitrousOxide
# T3 257.15
# C 0.7514163294627876
# A R404a
# B NitrousOxide
# T3 258.15
# C 0.7500127276461216
# A R404a
# B NitrousOxide
# T3 259.15
# C 0.7484129196187812
# A R404a
# B NitrousOxide
# T3 260.15
# C 0.7466161166395766
# A R404a
# B NitrousOxide
# T3 261.15
# C 0.7446215872355201
# A R404a
# B NitrousOxide
# T3 262.15
# C 0.7424286528908624
# A R404a
# B NitrousOxide
# T3 263.15
# C 0.740036683209134
# A R404a
# B NitrousOxide
# T3 264.15
# C 0.7374450905052033
# A R404a
# B NitrousOxide
# T3 265.15
# C 0.7346533237783147
# A R404a
# B NitrousOxide
# T3 266.15
# C 0.7316608620130213
# A R404a
# B NitrousOxide
# T3 267.15
# C 0.7284672067187579
# A R404a
# B NitrousOxide
# T3 268.15
# C 0.725071873692459
# A R404a
# B NitrousOxide
# T3 269.15
# C 0.7214743838303868
# A R404a
# B NitrousOxide
# T3 270.15
# C 0.717674252950352
# A R404a
# B NitrousOxide
# T3 271.15
# C 0.7136709804733152
# A R404a
# B NitrousOxide
# T3 272.15
# C 0.7094640368236294
# A R404a
# B NitrousOxide
# T3 273.15
# C 0.7050528493747512
# A R404a
# B NitrousOxide
# T3 274.15
# C 0.7004367867347978
# A R404a
# B NitrousOxide
# T3 275.15
# C 0.6956151411253191
# A R404a
# B NitrousOxide
# T3 276.15
# C 0.6905871085575841
